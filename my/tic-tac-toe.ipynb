# %%
import os
import json
import time
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import EarlyStopping, Callback

# %% [markdown]
# **MiniMax engine**

# %%
class TicTacToe:
    moves = []
    player = None
    game_status = None
    engine_X = None
    engine_0 = None
    RULES = [
        [0, 1, 2], [3, 4, 5], [6, 7, 8],  # horizontal
        [0, 3, 6], [1, 4, 7], [2, 5, 8],  # vertical
        [0, 4, 8], [2, 4, 6]  # diagonal
    ]

    def __init__(self):
        pass

    def new(self, engine_X, engine_0):
        self.player = 1
        self.moves = []
        self.game_status = None
        self.engine_X = engine_X
        self.engine_0 = engine_0

    # 1 if won <X>, -1 if won <0>, 0 if draw, None if game is not finished
    def status(self, board=None):
        if board is None:
            return self.game_status

        is_draw = True
        for rule in self.RULES:
            abs_sum = abs(board[rule[0]] + board[rule[1]] + board[rule[2]])
            if abs_sum == 3:
                return board[rule[0]]  # return player won (1, -1)
            if is_draw:
                sum_abs = abs(board[rule[0]]) + abs(board[rule[1]]) + abs(board[rule[2]])
                is_draw = False if abs_sum == sum_abs else is_draw
        return 0 if is_draw else None  # return draw or game is not finished

    def board(self, pos=None):
        board = 9 * [0.]
        pos = len(self.moves) if pos is None else pos
        last = pos if pos >= 0 else len(self.moves) + pos
        turn = 1
        for idx in self.moves[0:last]:
            board[idx] = float(turn)
            turn = -turn
        return board

    def timeseries(self):
        moves = 9 * [0.]
        time_series = [moves.copy()]
        turn = 1
        for move_idx in self.moves:
            moves[move_idx] = 1. if turn == 1 else -1.
            time_series.append(moves.copy())
            turn = -turn
        return time_series

    def is_tie(self, status=None):
        status = status if status else self.game_status
        return status is None

    def is_game_over(self, status=None):
        return not self.is_tie(status)

    def remove_illegal_moves(self, Y, moves = None):
        moves = moves if moves else self.moves
        for pos in moves:
            Y[pos] = -1
        return Y

    def auto_play(self, player_X, player_0):
        self.new(player_X, player_0)
        for i in range(0, 9):
            self.auto_move()
            self.engine_X.train(self)
            self.engine_0.train(self)
            if self.is_game_over():
                break

    def auto_move(self):
        if self.is_tie():  # game is not finished
            best_move = self.engine_X.move(self) if self.player == 1 else self.engine_0.move(self)
            if best_move in self.moves:
                print('!!!!!!!!!! Wrong move')
                exit(0)
            self.moves.append(best_move)
        # update status
        self.game_status = self.status(self.board())
        if self.is_tie():  # game is continue we change player, else left winner or last moved as is
            self.player = -self.player

    def print(self):
        board = self.board()
        print(board)
        print("\n", self.engine_X.code, self.engine_0.code)
        for r in range(0, 3):
            for c in range(0, 3):
                mark = ' '
                mark = 'X' if board[3*r + c] == 1 else mark
                mark = '0' if board[3 * r + c] == -1 else mark
                print(mark, end='')
            print()

# %%
class Stats:
    STEP = 10
    WINDOW = 100

    def __init__(self, engines):
        self.counter = 0
        self.start_time = int(time.time() * 1000)
        self.engines = engines
        self.statuses = []

    def add(self, game):
        self.counter += 1

        won = game.status()
        code_x = game.engine_X.code
        code_0 = game.engine_0.code

        stats = {
            code_x: {'g': 1, 'w': 0, 'd': 0, 'l': 0},
            code_0: {'g': 1, 'w': 0, 'd': 0, 'l': 0}
        }

        if won:
            win, lost = (code_x, code_0) if won == 1 else (code_0, code_x)
            stats[win]['w'] = 1
            stats[lost]['l'] = 1
        else:
            stats[code_x]['d'] = 1
            stats[code_0]['d'] = 1

        self.statuses.append(stats)
        self.pop()

        if self.counter == 1:
            self.header()
        if self.counter % self.STEP == 0:
            self.print()

    def pop(self):
        if len(self.statuses) > self.WINDOW:
            self.statuses.pop(0)

    def header(self):
        print(f"Stats config: STEP = {self.STEP}, WINDOW = {self.WINDOW}")

    def print(self):
        loop = int(time.time() * 1000)
        p = lambda x, c: round(100*x/c)
        print(f"Game {self.counter:>5} | {int((loop - self.start_time) / 1000):>5}sec", end=' | ')
        stats_str = []
        for item in self.engines:
            engine = item.code
            cnt = win = drw = lst = 0
            for row in self.statuses:
                if engine in row:
                    cnt += row[engine]['g']
                    win += row[engine]['w']
                    drw += row[engine]['d']
                    lst += row[engine]['l']
            stats_str.append(
                f"{engine.upper()}: {p(win,cnt):>2}% wins, {p(drw,cnt):>2}% draws, {p(lst,cnt):>2}% losts")
        print(' | '.join(stats_str))

# %%
class EngineMiniMax:
    INF = 1000

    def __init__(self, code='MinMax', max_depth=5):
        self.code = f"{code}-{max_depth}"
        self.max_depth = max_depth
        
    def move(self, game):
        best_moves = self.__minimax(game, game.board())
        moves = self.__legal_moves(best_moves)
        return moves.index(max(moves))

    def train(self, game):
        pass

    def __legal_moves(self, best_moves):
        y = 9 * [0]
        for move in best_moves:
            y[move] = 1 + random.uniform(-0.5, 0.5)
        y = game.remove_illegal_moves(y)
        #print('MM legal', y)
        return y

    def __minimax(self, game, board, turn=1, depth=0):
        if depth:
            status = game.status(board)
            if game.is_game_over(status):
                return status / depth   # win

            if depth >= self.max_depth:
                return 0

        best_score = -self.INF if turn > 0 else self.INF
        best_moves = []

        for i in range(len(board)):
            if board[i] != 0:  # skip zero squares
                continue
            # only 1 and -1
            board[i] = turn
            score = self.__minimax(game, board, -turn, depth + 1)
            if turn > 0 and score >= best_score:
                if best_score != score:
                    best_moves = []
                best_score = score
                if depth == 0:
                    best_moves.append(i)
            elif turn < 0 and score <= best_score:
                if best_score != score:
                    best_moves = []
                best_score = score
                if depth == 0:
                    best_moves.append(i)
            board[i] = 0

        return best_score if depth else best_moves

# %%
class EngineDenseRL2x:
    unique_ids = {}
    EPOCHS = 30
    SAVE_EACH_TRAINS = 100

    REWARD_LR = 0.7
    REWARD_WIN = 0.90
    REWARD_DRW = 0.30
    REWARD_LST = 0.10

    def __init__(self, code='EngineDenseRL2x', unique=False):
        self.counter = 0
        self.code = code
        self.unique_ids = {} if unique else False
        self.model_file = f"../tmp/ttt/{self.code}.keras"
        self.extra_file = f"../tmp/ttt/{self.code}.extra.json"
        os.makedirs(os.path.dirname(self.model_file), exist_ok=True)
        self.__init_model()

    def __init_model(self):
        self.model = self.__load()
        if not self.model:
            self.model = Sequential([
                layers.ReLU(72, input_shape=(18,)),    #  2*9 as split X and 0 to separate cells
                #layers.Normalization(),
                layers.ReLU(72),
                layers.Dropout(0.2),
                layers.Normalization(),
                layers.Dense(9, activation='sigmoid')
            ])
            self.model.compile(optimizer='adam', loss='mse')   # binary_crossentropy

    def __save(self):
        if self.counter % self.SAVE_EACH_TRAINS == 0:
            self.model.save(self.model_file)
            extra = {'counter': self.counter}
            with open(self.extra_file, 'w') as extra_file:
                json.dump(extra, extra_file)
            print('saved')

    def __load(self):
        if os.path.exists(self.model_file):
            with open(self.extra_file, 'r') as extra_file:
                params = json.load(extra_file)
                self.counter = params['counter']
            print(f'loaded {self.code}, last game number is {self.counter}')
            return load_model(self.model_file)
        return False


    def __check_uniq(self, game):
        if self.unique_ids:
            game_id = ''.join(str(item) for item in game.moves)
            if game_id in self.unique_ids:
                return True
            self.unique_ids[game_id] = True
        return False

    def __board2x(self, game):
        board = game.board()
        board2x = 9 * [1, 0]
        # if empty cell then first is 1 to decrase count of 0 values. And 0 if cell is X moved
        for i in range(len(board)):
            if board[i] == 1:
                board2x[2 * i] = 0
            if board[i] == -1:
                board2x[2 * i + 1] = 1
        return board2x

    def __timeseries2x(self, game):
        board = game.board()
        series = 9 * [1, 0]
        timeseries2x = []
        for i in game.moves:
            if board[i] == 1:
                series[2 * i] = 0
            if board[i] == -1:
                series[2 * i + 1] = 1
            timeseries2x.append(series.copy())
        return timeseries2x

    def __legal_moves(self, game, Y):
        for i in range(len(Y)):
            Y[i] = game.remove_illegal_moves(Y[i], game.moves[:i])
        #print('NN legal', Y)
        return Y

    def move(self, game):
        X = [self.__board2x(game)]
        Y = self.model.predict(X, verbose=0)
        y = game.remove_illegal_moves(Y[0])
        return np.argmax(Y[0])

    def train(self, game):
        # this engine trains only on the end of game
        if game.is_tie():
            return

        if self.__check_uniq(game):
            return

        self.counter += 1

        X = self.__timeseries2x(game)[:-1]     # skip last series
        Y = self.model.predict(X, verbose=0)
        Y = self.__legal_moves(game, Y)

        turn_a = True
        reward_a = self.REWARD_WIN if game.status() else self.REWARD_DRW
        reward_b = self.REWARD_LST if game.status() else self.REWARD_DRW

        for t in range(len(Y) - 1, -1, -1):
            move = game.moves[t+1]
            # print(t, move, game.moves, X[t], Y[t])
            if turn_a:
                reward_a = Y[t][move] + self.REWARD_LR * (reward_a - Y[t][move])
                Y[t][move] = reward_a
            else:
                reward_b = Y[t][move] + self.REWARD_LR * (reward_b - Y[t][move])
                Y[t][move] = reward_b
            turn_a = not turn_a
        early_stopping = EarlyStopping(monitor='loss', patience=1, restore_best_weights=True)
        self.model.fit(np.array(X), np.array(Y), epochs=self.EPOCHS, batch_size=10, verbose=0, callbacks=[early_stopping])

        self.__save()

# %%
class EngineDenseRL3x:
    unique_ids = {}

    EPOCHS = 300

    REWARD_LR = 0.7
    REWARD_WIN = 0.90
    REWARD_DRW = 0.30
    REWARD_LST = 0.10

    def __init__(self, code='EngineDenseRL3x', unique=False):
        self.code = code
        self.unique_ids = {} if unique else False
        self.model = Sequential([
            layers.ReLU(81, input_shape=(27,)),    #  2*9 as split X and 0 to separate cells
            layers.Normalization(),
            layers.ReLU(243),
            layers.Dropout(0.2),
            layers.Normalization(),
            layers.Dense(9, activation='sigmoid')
        ])
        self.model.compile(optimizer='adam', loss='binary_crossentropy')   # binary_crossentropy
                        
    def __check_uniq(self, game):
        if self.unique_ids:
            game_id = ''.join(str(item) for item in game.moves)
            if game_id in self.unique_ids:
                return True
            self.unique_ids[game_id] = True
        return False

    def __board3x(self, game):
        board = game.board()
        board3x = 9 * [0, 0, 0]
        for i in range(len(board)):
            if board[i] == 1:
                board3x[3 * i] = 1
            if board[i] == -1:
                board3x[3 * i + 1] = 1
            if board[i] == 0:
                board3x[3 * i + 2] = 1
        return board3x

    def __timeseries3x(self, game):
        board = game.board()
        series = 9 * [0, 0, 0]
        timeseries3x = []
        for i in game.moves:
            if board[i] == 1:
                series[3 * i] = 1
            if board[i] == -1:
                series[3 * i + 1] = 1
            if board[i] == 0:
                series[3 * i + 2] = 1
            timeseries3x.append(series.copy())
        return timeseries3x

    def __legal_moves(self, game, Y):
        for i in range(len(Y)):
            Y[i] = game.remove_illegal_moves(Y[i], game.moves[:i])
        #print('NN legal', Y)
        return Y

    def move(self, game):
        X = [self.__board3x(game)]
        Y = self.model.predict(X, verbose=0)
        y = game.remove_illegal_moves(Y[0])
        return np.argmax(Y[0])

    def train(self, game):
        # this engine trains only on the end of game
        if game.is_tie():
            return

        if self.__check_uniq(game):
            return

        X = self.__timeseries3x(game)[:-1]     # skip last series
        Y = self.model.predict(X, verbose=0)
        Y = self.__legal_moves(game, Y)

        turn_a = True
        reward_a = self.REWARD_WIN if game.status() else self.REWARD_DRW
        reward_b = self.REWARD_LST if game.status() else self.REWARD_DRW

        for t in range(len(Y) - 1, -1, -1):
            move = game.moves[t+1]
            #print(t, move, game.moves, X[t], Y[t])
            if turn_a:
                reward_a = Y[t][move] + self.REWARD_LR * (reward_a - Y[t][move])
                Y[t][move] = reward_a
            else:
                reward_b = Y[t][move] + self.REWARD_LR * (reward_b - Y[t][move])
                Y[t][move] = reward_b
            turn_a = not turn_a
        early_stopping = EarlyStopping(monitor='loss', patience=1, restore_best_weights=True)
        self.model.fit(np.array(X), np.array(Y), epochs=self.EPOCHS, batch_size=10, verbose=0, callbacks=[early_stopping])

# %% [markdown]
# **Game loop**

# %%
engines = [
    EngineMiniMax('Mini-Max', max_depth=5),
    EngineDenseRL2x('RL-2x', unique=False),
    #EngineDenseRL3x('RL-3x', unique=False),
]

game = TicTacToe()
stats = Stats(engines)

for game_num in range(1, 20000):
    engine_X, engine_0 = random.sample(engines, k=2)
    game.auto_play(engine_X, engine_0)
    stats.add(game)
# Out:
# loaded RL-2x, last game number is 2600
# Stats config: STEP = 10, WINDOW = 100
# Game    10 |     5sec | MINI-MAX-5: 90% wins, 10% draws,  0% losts | RL-2X:  0% wins, 10% draws, 90% losts
# Game    20 |    10sec | MINI-MAX-5: 80% wins, 20% draws,  0% losts | RL-2X:  0% wins, 20% draws, 80% losts
# Game    30 |    14sec | MINI-MAX-5: 77% wins, 23% draws,  0% losts | RL-2X:  0% wins, 23% draws, 77% losts
# Game    40 |    19sec | MINI-MAX-5: 78% wins, 22% draws,  0% losts | RL-2X:  0% wins, 22% draws, 78% losts
# Game    50 |    23sec | MINI-MAX-5: 78% wins, 22% draws,  0% losts | RL-2X:  0% wins, 22% draws, 78% losts
# Game    60 |    28sec | MINI-MAX-5: 80% wins, 20% draws,  0% losts | RL-2X:  0% wins, 20% draws, 80% losts
# Game    70 |    32sec | MINI-MAX-5: 81% wins, 19% draws,  0% losts | RL-2X:  0% wins, 19% draws, 81% losts
# Game    80 |    37sec | MINI-MAX-5: 80% wins, 20% draws,  0% losts | RL-2X:  0% wins, 20% draws, 80% losts
# Game    90 |    42sec | MINI-MAX-5: 79% wins, 21% draws,  0% losts | RL-2X:  0% wins, 21% draws, 79% losts
# saved
# Game   100 |    46sec | MINI-MAX-5: 78% wins, 22% draws,  0% losts | RL-2X:  0% wins, 22% draws, 78% losts
# Game   110 |    51sec | MINI-MAX-5: 75% wins, 25% draws,  0% losts | RL-2X:  0% wins, 25% draws, 75% losts
# Game   120 |    55sec | MINI-MAX-5: 76% wins, 24% draws,  0% losts | RL-2X:  0% wins, 24% draws, 76% losts
# Game   130 |    60sec | MINI-MAX-5: 75% wins, 25% draws,  0% losts | RL-2X:  0% wins, 25% draws, 75% losts
# Game   140 |    65sec | MINI-MAX-5: 74% wins, 25% draws,  1% losts | RL-2X:  1% wins, 25% draws, 74% losts
# Game   150 |    70sec | MINI-MAX-5: 71% wins, 28% draws,  1% losts | RL-2X:  1% wins, 28% draws, 71% losts
# Game   160 |    76sec | MINI-MAX-5: 66% wins, 33% draws,  1% losts | RL-2X:  1% wins, 33% draws, 66% losts
# Game   170 |    80sec | MINI-MAX-5: 62% wins, 37% draws,  1% losts | RL-2X:  1% wins, 37% draws, 62% losts
# Game   180 |    85sec | MINI-MAX-5: 62% wins, 37% draws,  1% losts | RL-2X:  1% wins, 37% draws, 62% losts
# Game   190 |    89sec | MINI-MAX-5: 60% wins, 39% draws,  1% losts | RL-2X:  1% wins, 39% draws, 60% losts
# saved
# Game   200 |    94sec | MINI-MAX-5: 57% wins, 42% draws,  1% losts | RL-2X:  1% wins, 42% draws, 57% losts
# Game   210 |    98sec | MINI-MAX-5: 58% wins, 41% draws,  1% losts | RL-2X:  1% wins, 41% draws, 58% losts
# Game   220 |   103sec | MINI-MAX-5: 57% wins, 42% draws,  1% losts | RL-2X:  1% wins, 42% draws, 57% losts
# Game   230 |   107sec | MINI-MAX-5: 57% wins, 41% draws,  2% losts | RL-2X:  2% wins, 41% draws, 57% losts
# Game   240 |   111sec | MINI-MAX-5: 60% wins, 39% draws,  1% losts | RL-2X:  1% wins, 39% draws, 60% losts
# Game   250 |   116sec | MINI-MAX-5: 62% wins, 37% draws,  1% losts | RL-2X:  1% wins, 37% draws, 62% losts
# Game   260 |   121sec | MINI-MAX-5: 63% wins, 36% draws,  1% losts | RL-2X:  1% wins, 36% draws, 63% losts
# Game   270 |   126sec | MINI-MAX-5: 65% wins, 34% draws,  1% losts | RL-2X:  1% wins, 34% draws, 65% losts
# Game   280 |   130sec | MINI-MAX-5: 66% wins, 33% draws,  1% losts | RL-2X:  1% wins, 33% draws, 66% losts
# Game   290 |   135sec | MINI-MAX-5: 69% wins, 30% draws,  1% losts | RL-2X:  1% wins, 30% draws, 69% losts
# saved
# Game   300 |   139sec | MINI-MAX-5: 71% wins, 28% draws,  1% losts | RL-2X:  1% wins, 28% draws, 71% losts
# Game   310 |   144sec | MINI-MAX-5: 70% wins, 29% draws,  1% losts | RL-2X:  1% wins, 29% draws, 70% losts
# Game   320 |   148sec | MINI-MAX-5: 71% wins, 28% draws,  1% losts | RL-2X:  1% wins, 28% draws, 71% losts
# Game   330 |   153sec | MINI-MAX-5: 72% wins, 28% draws,  0% losts | RL-2X:  0% wins, 28% draws, 72% losts
# Game   340 |   157sec | MINI-MAX-5: 68% wins, 32% draws,  0% losts | RL-2X:  0% wins, 32% draws, 68% losts
# Game   350 |   162sec | MINI-MAX-5: 70% wins, 30% draws,  0% losts | RL-2X:  0% wins, 30% draws, 70% losts
# Game   360 |   166sec | MINI-MAX-5: 74% wins, 26% draws,  0% losts | RL-2X:  0% wins, 26% draws, 74% losts
# Game   370 |   171sec | MINI-MAX-5: 76% wins, 24% draws,  0% losts | RL-2X:  0% wins, 24% draws, 76% losts
# Game   380 |   175sec | MINI-MAX-5: 74% wins, 26% draws,  0% losts | RL-2X:  0% wins, 26% draws, 74% losts
# Game   390 |   180sec | MINI-MAX-5: 71% wins, 29% draws,  0% losts | RL-2X:  0% wins, 29% draws, 71% losts
# saved
# Game   400 |   185sec | MINI-MAX-5: 72% wins, 28% draws,  0% losts | RL-2X:  0% wins, 28% draws, 72% losts
# Game   410 |   189sec | MINI-MAX-5: 75% wins, 25% draws,  0% losts | RL-2X:  0% wins, 25% draws, 75% losts
# Game   420 |   194sec | MINI-MAX-5: 72% wins, 28% draws,  0% losts | RL-2X:  0% wins, 28% draws, 72% losts
# Game   430 |   198sec | MINI-MAX-5: 70% wins, 30% draws,  0% losts | RL-2X:  0% wins, 30% draws, 70% losts
# Game   440 |   203sec | MINI-MAX-5: 69% wins, 31% draws,  0% losts | RL-2X:  0% wins, 31% draws, 69% losts
# Game   450 |   207sec | MINI-MAX-5: 68% wins, 32% draws,  0% losts | RL-2X:  0% wins, 32% draws, 68% losts
# Game   460 |   212sec | MINI-MAX-5: 66% wins, 34% draws,  0% losts | RL-2X:  0% wins, 34% draws, 66% losts
# Game   470 |   216sec | MINI-MAX-5: 65% wins, 35% draws,  0% losts | RL-2X:  0% wins, 35% draws, 65% losts
# Game   480 |   220sec | MINI-MAX-5: 64% wins, 36% draws,  0% losts | RL-2X:  0% wins, 36% draws, 64% losts
# Game   490 |   226sec | MINI-MAX-5: 65% wins, 35% draws,  0% losts | RL-2X:  0% wins, 35% draws, 65% losts
# saved
# Game   500 |   230sec | MINI-MAX-5: 65% wins, 35% draws,  0% losts | RL-2X:  0% wins, 35% draws, 65% losts
# Game   510 |   235sec | MINI-MAX-5: 61% wins, 39% draws,  0% losts | RL-2X:  0% wins, 39% draws, 61% losts
# Game   520 |   240sec | MINI-MAX-5: 61% wins, 39% draws,  0% losts | RL-2X:  0% wins, 39% draws, 61% losts
# Game   530 |   244sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# Game   540 |   249sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# Game   550 |   254sec | MINI-MAX-5: 62% wins, 38% draws,  0% losts | RL-2X:  0% wins, 38% draws, 62% losts
# Game   560 |   259sec | MINI-MAX-5: 62% wins, 38% draws,  0% losts | RL-2X:  0% wins, 38% draws, 62% losts
# Game   570 |   264sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# Game   580 |   269sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# Game   590 |   275sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# saved
# Game   600 |   280sec | MINI-MAX-5: 61% wins, 38% draws,  1% losts | RL-2X:  1% wins, 38% draws, 61% losts
# Game   610 |   285sec | MINI-MAX-5: 63% wins, 36% draws,  1% losts | RL-2X:  1% wins, 36% draws, 63% losts
# Game   620 |   289sec | MINI-MAX-5: 65% wins, 34% draws,  1% losts | RL-2X:  1% wins, 34% draws, 65% losts
# Game   630 |   294sec | MINI-MAX-5: 66% wins, 33% draws,  1% losts | RL-2X:  1% wins, 33% draws, 66% losts
# Game   640 |   298sec | MINI-MAX-5: 68% wins, 31% draws,  1% losts | RL-2X:  1% wins, 31% draws, 68% losts
# Game   650 |   302sec | MINI-MAX-5: 68% wins, 31% draws,  1% losts | RL-2X:  1% wins, 31% draws, 68% losts
# Game   660 |   307sec | MINI-MAX-5: 67% wins, 32% draws,  1% losts | RL-2X:  1% wins, 32% draws, 67% losts
# Game   670 |   312sec | MINI-MAX-5: 62% wins, 37% draws,  1% losts | RL-2X:  1% wins, 37% draws, 62% losts
# Game   680 |   316sec | MINI-MAX-5: 61% wins, 38% draws,  1% losts | RL-2X:  1% wins, 38% draws, 61% losts
# Game   690 |   320sec | MINI-MAX-5: 64% wins, 35% draws,  1% losts | RL-2X:  1% wins, 35% draws, 64% losts
# saved
# Game   700 |   325sec | MINI-MAX-5: 67% wins, 33% draws,  0% losts | RL-2X:  0% wins, 33% draws, 67% losts
# Game   710 |   329sec | MINI-MAX-5: 65% wins, 34% draws,  1% losts | RL-2X:  1% wins, 34% draws, 65% losts
# Game   720 |   334sec | MINI-MAX-5: 62% wins, 36% draws,  2% losts | RL-2X:  2% wins, 36% draws, 62% losts
# Game   730 |   338sec | MINI-MAX-5: 61% wins, 37% draws,  2% losts | RL-2X:  2% wins, 37% draws, 61% losts
# Game   740 |   343sec | MINI-MAX-5: 59% wins, 39% draws,  2% losts | RL-2X:  2% wins, 39% draws, 59% losts
# Game   750 |   347sec | MINI-MAX-5: 59% wins, 39% draws,  2% losts | RL-2X:  2% wins, 39% draws, 59% losts
# Game   760 |   351sec | MINI-MAX-5: 61% wins, 37% draws,  2% losts | RL-2X:  2% wins, 37% draws, 61% losts
# Game   770 |   356sec | MINI-MAX-5: 61% wins, 37% draws,  2% losts | RL-2X:  2% wins, 37% draws, 61% losts
# Game   780 |   361sec | MINI-MAX-5: 60% wins, 36% draws,  4% losts | RL-2X:  4% wins, 36% draws, 60% losts
# Game   790 |   366sec | MINI-MAX-5: 58% wins, 37% draws,  5% losts | RL-2X:  5% wins, 37% draws, 58% losts
# saved
# Game   800 |   370sec | MINI-MAX-5: 56% wins, 39% draws,  5% losts | RL-2X:  5% wins, 39% draws, 56% losts
# Game   810 |   375sec | MINI-MAX-5: 58% wins, 37% draws,  5% losts | RL-2X:  5% wins, 37% draws, 58% losts
# Game   820 |   379sec | MINI-MAX-5: 60% wins, 36% draws,  4% losts | RL-2X:  4% wins, 36% draws, 60% losts
# Game   830 |   384sec | MINI-MAX-5: 61% wins, 35% draws,  4% losts | RL-2X:  4% wins, 35% draws, 61% losts
# Game   840 |   388sec | MINI-MAX-5: 65% wins, 31% draws,  4% losts | RL-2X:  4% wins, 31% draws, 65% losts
# Game   850 |   392sec | MINI-MAX-5: 67% wins, 29% draws,  4% losts | RL-2X:  4% wins, 29% draws, 67% losts
# Game   860 |   396sec | MINI-MAX-5: 67% wins, 28% draws,  5% losts | RL-2X:  5% wins, 28% draws, 67% losts
# Game   870 |   400sec | MINI-MAX-5: 70% wins, 25% draws,  5% losts | RL-2X:  5% wins, 25% draws, 70% losts
# Game   880 |   404sec | MINI-MAX-5: 75% wins, 22% draws,  3% losts | RL-2X:  3% wins, 22% draws, 75% losts
# Game   890 |   409sec | MINI-MAX-5: 73% wins, 24% draws,  3% losts | RL-2X:  3% wins, 24% draws, 73% losts
# saved
# Game   900 |   413sec | MINI-MAX-5: 75% wins, 22% draws,  3% losts | RL-2X:  3% wins, 22% draws, 75% losts
# Game   910 |   417sec | MINI-MAX-5: 75% wins, 23% draws,  2% losts | RL-2X:  2% wins, 23% draws, 75% losts
# Game   920 |   421sec | MINI-MAX-5: 77% wins, 21% draws,  2% losts | RL-2X:  2% wins, 21% draws, 77% losts
# Game   930 |   425sec | MINI-MAX-5: 77% wins, 21% draws,  2% losts | RL-2X:  2% wins, 21% draws, 77% losts
# Game   940 |   429sec | MINI-MAX-5: 75% wins, 23% draws,  2% losts | RL-2X:  2% wins, 23% draws, 75% losts
# Game   950 |   433sec | MINI-MAX-5: 75% wins, 23% draws,  2% losts | RL-2X:  2% wins, 23% draws, 75% losts
# Game   960 |   438sec | MINI-MAX-5: 72% wins, 27% draws,  1% losts | RL-2X:  1% wins, 27% draws, 72% losts
# Game   970 |   443sec | MINI-MAX-5: 71% wins, 28% draws,  1% losts | RL-2X:  1% wins, 28% draws, 71% losts
# Game   980 |   448sec | MINI-MAX-5: 71% wins, 28% draws,  1% losts | RL-2X:  1% wins, 28% draws, 71% losts
# Game   990 |   452sec | MINI-MAX-5: 70% wins, 30% draws,  0% losts | RL-2X:  0% wins, 30% draws, 70% losts
# saved
# Game  1000 |   456sec | MINI-MAX-5: 70% wins, 30% draws,  0% losts | RL-2X:  0% wins, 30% draws, 70% losts
# Game  1010 |   460sec | MINI-MAX-5: 71% wins, 29% draws,  0% losts | RL-2X:  0% wins, 29% draws, 71% losts
# Game  1020 |   464sec | MINI-MAX-5: 73% wins, 27% draws,  0% losts | RL-2X:  0% wins, 27% draws, 73% losts
# Game  1030 |   468sec | MINI-MAX-5: 74% wins, 26% draws,  0% losts | RL-2X:  0% wins, 26% draws, 74% losts
# Game  1040 |   472sec | MINI-MAX-5: 73% wins, 26% draws,  1% losts | RL-2X:  1% wins, 26% draws, 73% losts
# Game  1050 |   476sec | MINI-MAX-5: 69% wins, 30% draws,  1% losts | RL-2X:  1% wins, 30% draws, 69% losts
# Game  1060 |   481sec | MINI-MAX-5: 71% wins, 28% draws,  1% losts | RL-2X:  1% wins, 28% draws, 71% losts
# Game  1070 |   485sec | MINI-MAX-5: 70% wins, 29% draws,  1% losts | RL-2X:  1% wins, 29% draws, 70% losts
# Game  1080 |   488sec | MINI-MAX-5: 69% wins, 30% draws,  1% losts | RL-2X:  1% wins, 30% draws, 69% losts
# Game  1090 |   493sec | MINI-MAX-5: 71% wins, 28% draws,  1% losts | RL-2X:  1% wins, 28% draws, 71% losts
# saved
# Game  1100 |   497sec | MINI-MAX-5: 67% wins, 32% draws,  1% losts | RL-2X:  1% wins, 32% draws, 67% losts
# Game  1110 |   502sec | MINI-MAX-5: 65% wins, 34% draws,  1% losts | RL-2X:  1% wins, 34% draws, 65% losts
# Game  1120 |   506sec | MINI-MAX-5: 63% wins, 36% draws,  1% losts | RL-2X:  1% wins, 36% draws, 63% losts
# Game  1130 |   510sec | MINI-MAX-5: 61% wins, 38% draws,  1% losts | RL-2X:  1% wins, 38% draws, 61% losts
# Game  1140 |   514sec | MINI-MAX-5: 62% wins, 38% draws,  0% losts | RL-2X:  0% wins, 38% draws, 62% losts
# Game  1150 |   519sec | MINI-MAX-5: 64% wins, 36% draws,  0% losts | RL-2X:  0% wins, 36% draws, 64% losts
# Game  1160 |   523sec | MINI-MAX-5: 65% wins, 35% draws,  0% losts | RL-2X:  0% wins, 35% draws, 65% losts
# Game  1170 |   527sec | MINI-MAX-5: 68% wins, 32% draws,  0% losts | RL-2X:  0% wins, 32% draws, 68% losts
# Game  1180 |   531sec | MINI-MAX-5: 67% wins, 33% draws,  0% losts | RL-2X:  0% wins, 33% draws, 67% losts
# Game  1190 |   535sec | MINI-MAX-5: 69% wins, 31% draws,  0% losts | RL-2X:  0% wins, 31% draws, 69% losts
# saved
# Game  1200 |   539sec | MINI-MAX-5: 73% wins, 27% draws,  0% losts | RL-2X:  0% wins, 27% draws, 73% losts
# Game  1210 |   543sec | MINI-MAX-5: 76% wins, 24% draws,  0% losts | RL-2X:  0% wins, 24% draws, 76% losts
# Game  1220 |   547sec | MINI-MAX-5: 76% wins, 24% draws,  0% losts | RL-2X:  0% wins, 24% draws, 76% losts
# Game  1230 |   551sec | MINI-MAX-5: 74% wins, 26% draws,  0% losts | RL-2X:  0% wins, 26% draws, 74% losts
# Game  1240 |   556sec | MINI-MAX-5: 71% wins, 28% draws,  1% losts | RL-2X:  1% wins, 28% draws, 71% losts
# Game  1250 |   561sec | MINI-MAX-5: 68% wins, 30% draws,  2% losts | RL-2X:  2% wins, 30% draws, 68% losts
# Game  1260 |   565sec | MINI-MAX-5: 65% wins, 33% draws,  2% losts | RL-2X:  2% wins, 33% draws, 65% losts
# Game  1270 |   569sec | MINI-MAX-5: 61% wins, 37% draws,  2% losts | RL-2X:  2% wins, 37% draws, 61% losts
# Game  1280 |   573sec | MINI-MAX-5: 63% wins, 35% draws,  2% losts | RL-2X:  2% wins, 35% draws, 63% losts
# Game  1290 |   577sec | MINI-MAX-5: 61% wins, 37% draws,  2% losts | RL-2X:  2% wins, 37% draws, 61% losts
# saved
# Game  1300 |   582sec | MINI-MAX-5: 58% wins, 40% draws,  2% losts | RL-2X:  2% wins, 40% draws, 58% losts
# Game  1310 |   586sec | MINI-MAX-5: 54% wins, 44% draws,  2% losts | RL-2X:  2% wins, 44% draws, 54% losts
# Game  1320 |   590sec | MINI-MAX-5: 50% wins, 48% draws,  2% losts | RL-2X:  2% wins, 48% draws, 50% losts
# Game  1330 |   594sec | MINI-MAX-5: 53% wins, 45% draws,  2% losts | RL-2X:  2% wins, 45% draws, 53% losts
# Game  1340 |   598sec | MINI-MAX-5: 56% wins, 43% draws,  1% losts | RL-2X:  1% wins, 43% draws, 56% losts
# Game  1350 |   602sec | MINI-MAX-5: 60% wins, 40% draws,  0% losts | RL-2X:  0% wins, 40% draws, 60% losts
# Game  1360 |   606sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# Game  1370 |   610sec | MINI-MAX-5: 65% wins, 35% draws,  0% losts | RL-2X:  0% wins, 35% draws, 65% losts
# Game  1380 |   615sec | MINI-MAX-5: 62% wins, 38% draws,  0% losts | RL-2X:  0% wins, 38% draws, 62% losts
# Game  1390 |   619sec | MINI-MAX-5: 62% wins, 38% draws,  0% losts | RL-2X:  0% wins, 38% draws, 62% losts
# saved
# Game  1400 |   624sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# Game  1410 |   629sec | MINI-MAX-5: 66% wins, 34% draws,  0% losts | RL-2X:  0% wins, 34% draws, 66% losts
# Game  1420 |   634sec | MINI-MAX-5: 69% wins, 31% draws,  0% losts | RL-2X:  0% wins, 31% draws, 69% losts
# Game  1430 |   638sec | MINI-MAX-5: 67% wins, 33% draws,  0% losts | RL-2X:  0% wins, 33% draws, 67% losts
# Game  1440 |   643sec | MINI-MAX-5: 67% wins, 33% draws,  0% losts | RL-2X:  0% wins, 33% draws, 67% losts
# Game  1450 |   647sec | MINI-MAX-5: 64% wins, 36% draws,  0% losts | RL-2X:  0% wins, 36% draws, 64% losts
# Game  1460 |   653sec | MINI-MAX-5: 65% wins, 35% draws,  0% losts | RL-2X:  0% wins, 35% draws, 65% losts
# Game  1470 |   658sec | MINI-MAX-5: 64% wins, 36% draws,  0% losts | RL-2X:  0% wins, 36% draws, 64% losts
# Game  1480 |   662sec | MINI-MAX-5: 68% wins, 32% draws,  0% losts | RL-2X:  0% wins, 32% draws, 68% losts
# Game  1490 |   666sec | MINI-MAX-5: 70% wins, 30% draws,  0% losts | RL-2X:  0% wins, 30% draws, 70% losts
# saved
# Game  1500 |   671sec | MINI-MAX-5: 68% wins, 32% draws,  0% losts | RL-2X:  0% wins, 32% draws, 68% losts
# Game  1510 |   675sec | MINI-MAX-5: 66% wins, 34% draws,  0% losts | RL-2X:  0% wins, 34% draws, 66% losts
# Game  1520 |   680sec | MINI-MAX-5: 65% wins, 35% draws,  0% losts | RL-2X:  0% wins, 35% draws, 65% losts
# Game  1530 |   684sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# Game  1540 |   689sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# Game  1550 |   693sec | MINI-MAX-5: 64% wins, 36% draws,  0% losts | RL-2X:  0% wins, 36% draws, 64% losts
# Game  1560 |   697sec | MINI-MAX-5: 59% wins, 41% draws,  0% losts | RL-2X:  0% wins, 41% draws, 59% losts
# Game  1570 |   703sec | MINI-MAX-5: 60% wins, 40% draws,  0% losts | RL-2X:  0% wins, 40% draws, 60% losts
# Game  1580 |   708sec | MINI-MAX-5: 57% wins, 43% draws,  0% losts | RL-2X:  0% wins, 43% draws, 57% losts
# Game  1590 |   712sec | MINI-MAX-5: 55% wins, 44% draws,  1% losts | RL-2X:  1% wins, 44% draws, 55% losts
# saved
# Game  1600 |   717sec | MINI-MAX-5: 59% wins, 40% draws,  1% losts | RL-2X:  1% wins, 40% draws, 59% losts
# Game  1610 |   721sec | MINI-MAX-5: 60% wins, 39% draws,  1% losts | RL-2X:  1% wins, 39% draws, 60% losts
# Game  1620 |   726sec | MINI-MAX-5: 62% wins, 37% draws,  1% losts | RL-2X:  1% wins, 37% draws, 62% losts
# Game  1630 |   731sec | MINI-MAX-5: 64% wins, 34% draws,  2% losts | RL-2X:  2% wins, 34% draws, 64% losts
# Game  1640 |   736sec | MINI-MAX-5: 62% wins, 35% draws,  3% losts | RL-2X:  3% wins, 35% draws, 62% losts
# Game  1650 |   741sec | MINI-MAX-5: 60% wins, 36% draws,  4% losts | RL-2X:  4% wins, 36% draws, 60% losts
# Game  1660 |   746sec | MINI-MAX-5: 63% wins, 33% draws,  4% losts | RL-2X:  4% wins, 33% draws, 63% losts
# Game  1670 |   751sec | MINI-MAX-5: 63% wins, 33% draws,  4% losts | RL-2X:  4% wins, 33% draws, 63% losts
# Game  1680 |   755sec | MINI-MAX-5: 62% wins, 32% draws,  6% losts | RL-2X:  6% wins, 32% draws, 62% losts
# Game  1690 |   760sec | MINI-MAX-5: 60% wins, 35% draws,  5% losts | RL-2X:  5% wins, 35% draws, 60% losts
# saved
# Game  1700 |   765sec | MINI-MAX-5: 59% wins, 36% draws,  5% losts | RL-2X:  5% wins, 36% draws, 59% losts
# Game  1710 |   770sec | MINI-MAX-5: 57% wins, 37% draws,  6% losts | RL-2X:  6% wins, 37% draws, 57% losts
# Game  1720 |   774sec | MINI-MAX-5: 57% wins, 37% draws,  6% losts | RL-2X:  6% wins, 37% draws, 57% losts
# Game  1730 |   779sec | MINI-MAX-5: 59% wins, 36% draws,  5% losts | RL-2X:  5% wins, 36% draws, 59% losts
# Game  1740 |   783sec | MINI-MAX-5: 61% wins, 34% draws,  5% losts | RL-2X:  5% wins, 34% draws, 61% losts
# Game  1750 |   787sec | MINI-MAX-5: 64% wins, 31% draws,  5% losts | RL-2X:  5% wins, 31% draws, 64% losts
# Game  1760 |   792sec | MINI-MAX-5: 66% wins, 29% draws,  5% losts | RL-2X:  5% wins, 29% draws, 66% losts
# Game  1770 |   797sec | MINI-MAX-5: 65% wins, 30% draws,  5% losts | RL-2X:  5% wins, 30% draws, 65% losts
# Game  1780 |   802sec | MINI-MAX-5: 66% wins, 31% draws,  3% losts | RL-2X:  3% wins, 31% draws, 66% losts
# Game  1790 |   806sec | MINI-MAX-5: 70% wins, 27% draws,  3% losts | RL-2X:  3% wins, 27% draws, 70% losts
# saved
# Game  1800 |   811sec | MINI-MAX-5: 68% wins, 29% draws,  3% losts | RL-2X:  3% wins, 29% draws, 68% losts
# Game  1810 |   816sec | MINI-MAX-5: 71% wins, 27% draws,  2% losts | RL-2X:  2% wins, 27% draws, 71% losts
# Game  1820 |   820sec | MINI-MAX-5: 70% wins, 28% draws,  2% losts | RL-2X:  2% wins, 28% draws, 70% losts
# Game  1830 |   824sec | MINI-MAX-5: 69% wins, 28% draws,  3% losts | RL-2X:  3% wins, 28% draws, 69% losts
# Game  1840 |   828sec | MINI-MAX-5: 70% wins, 28% draws,  2% losts | RL-2X:  2% wins, 28% draws, 70% losts
# Game  1850 |   833sec | MINI-MAX-5: 68% wins, 30% draws,  2% losts | RL-2X:  2% wins, 30% draws, 68% losts
# Game  1860 |   838sec | MINI-MAX-5: 64% wins, 34% draws,  2% losts | RL-2X:  2% wins, 34% draws, 64% losts
# Game  1870 |   843sec | MINI-MAX-5: 61% wins, 37% draws,  2% losts | RL-2X:  2% wins, 37% draws, 61% losts
# Game  1880 |   848sec | MINI-MAX-5: 61% wins, 37% draws,  2% losts | RL-2X:  2% wins, 37% draws, 61% losts
# Game  1890 |   853sec | MINI-MAX-5: 59% wins, 39% draws,  2% losts | RL-2X:  2% wins, 39% draws, 59% losts
# saved
# Game  1900 |   858sec | MINI-MAX-5: 60% wins, 38% draws,  2% losts | RL-2X:  2% wins, 38% draws, 60% losts
# Game  1910 |   863sec | MINI-MAX-5: 59% wins, 39% draws,  2% losts | RL-2X:  2% wins, 39% draws, 59% losts
# Game  1920 |   868sec | MINI-MAX-5: 58% wins, 38% draws,  4% losts | RL-2X:  4% wins, 38% draws, 58% losts
# Game  1930 |   872sec | MINI-MAX-5: 58% wins, 39% draws,  3% losts | RL-2X:  3% wins, 39% draws, 58% losts
# Game  1940 |   877sec | MINI-MAX-5: 59% wins, 38% draws,  3% losts | RL-2X:  3% wins, 38% draws, 59% losts
# Game  1950 |   881sec | MINI-MAX-5: 63% wins, 35% draws,  2% losts | RL-2X:  2% wins, 35% draws, 63% losts
# Game  1960 |   885sec | MINI-MAX-5: 63% wins, 35% draws,  2% losts | RL-2X:  2% wins, 35% draws, 63% losts
# Game  1970 |   891sec | MINI-MAX-5: 67% wins, 31% draws,  2% losts | RL-2X:  2% wins, 31% draws, 67% losts
# Game  1980 |   895sec | MINI-MAX-5: 68% wins, 30% draws,  2% losts | RL-2X:  2% wins, 30% draws, 68% losts
# Game  1990 |   899sec | MINI-MAX-5: 70% wins, 28% draws,  2% losts | RL-2X:  2% wins, 28% draws, 70% losts
# saved
# Game  2000 |   904sec | MINI-MAX-5: 71% wins, 27% draws,  2% losts | RL-2X:  2% wins, 27% draws, 71% losts
# Game  2010 |   909sec | MINI-MAX-5: 71% wins, 26% draws,  3% losts | RL-2X:  3% wins, 26% draws, 71% losts
# Game  2020 |   913sec | MINI-MAX-5: 72% wins, 27% draws,  1% losts | RL-2X:  1% wins, 27% draws, 72% losts
# Game  2030 |   919sec | MINI-MAX-5: 69% wins, 30% draws,  1% losts | RL-2X:  1% wins, 30% draws, 69% losts
# Game  2040 |   924sec | MINI-MAX-5: 67% wins, 32% draws,  1% losts | RL-2X:  1% wins, 32% draws, 67% losts
# Game  2050 |   929sec | MINI-MAX-5: 62% wins, 37% draws,  1% losts | RL-2X:  1% wins, 37% draws, 62% losts
# Game  2060 |   933sec | MINI-MAX-5: 62% wins, 37% draws,  1% losts | RL-2X:  1% wins, 37% draws, 62% losts
# Game  2070 |   937sec | MINI-MAX-5: 63% wins, 35% draws,  2% losts | RL-2X:  2% wins, 35% draws, 63% losts
# Game  2080 |   941sec | MINI-MAX-5: 63% wins, 35% draws,  2% losts | RL-2X:  2% wins, 35% draws, 63% losts
# Game  2090 |   946sec | MINI-MAX-5: 59% wins, 38% draws,  3% losts | RL-2X:  3% wins, 38% draws, 59% losts
# saved
# Game  2100 |   950sec | MINI-MAX-5: 58% wins, 39% draws,  3% losts | RL-2X:  3% wins, 39% draws, 58% losts
# Game  2110 |   955sec | MINI-MAX-5: 55% wins, 42% draws,  3% losts | RL-2X:  3% wins, 42% draws, 55% losts
# Game  2120 |   960sec | MINI-MAX-5: 51% wins, 45% draws,  4% losts | RL-2X:  4% wins, 45% draws, 51% losts
# Game  2130 |   964sec | MINI-MAX-5: 54% wins, 42% draws,  4% losts | RL-2X:  4% wins, 42% draws, 54% losts
# Game  2140 |   969sec | MINI-MAX-5: 53% wins, 43% draws,  4% losts | RL-2X:  4% wins, 43% draws, 53% losts
# Game  2150 |   974sec | MINI-MAX-5: 56% wins, 40% draws,  4% losts | RL-2X:  4% wins, 40% draws, 56% losts
# Game  2160 |   978sec | MINI-MAX-5: 59% wins, 36% draws,  5% losts | RL-2X:  5% wins, 36% draws, 59% losts
# Game  2170 |   983sec | MINI-MAX-5: 60% wins, 36% draws,  4% losts | RL-2X:  4% wins, 36% draws, 60% losts
# Game  2180 |   988sec | MINI-MAX-5: 62% wins, 34% draws,  4% losts | RL-2X:  4% wins, 34% draws, 62% losts
# Game  2190 |   993sec | MINI-MAX-5: 65% wins, 32% draws,  3% losts | RL-2X:  3% wins, 32% draws, 65% losts
# saved
# Game  2200 |   997sec | MINI-MAX-5: 67% wins, 30% draws,  3% losts | RL-2X:  3% wins, 30% draws, 67% losts
# Game  2210 |  1002sec | MINI-MAX-5: 68% wins, 30% draws,  2% losts | RL-2X:  2% wins, 30% draws, 68% losts
# Game  2220 |  1006sec | MINI-MAX-5: 73% wins, 26% draws,  1% losts | RL-2X:  1% wins, 26% draws, 73% losts
# Game  2230 |  1010sec | MINI-MAX-5: 74% wins, 24% draws,  2% losts | RL-2X:  2% wins, 24% draws, 74% losts
# Game  2240 |  1014sec | MINI-MAX-5: 76% wins, 22% draws,  2% losts | RL-2X:  2% wins, 22% draws, 76% losts
# Game  2250 |  1019sec | MINI-MAX-5: 76% wins, 22% draws,  2% losts | RL-2X:  2% wins, 22% draws, 76% losts
# Game  2260 |  1023sec | MINI-MAX-5: 76% wins, 22% draws,  2% losts | RL-2X:  2% wins, 22% draws, 76% losts
# Game  2270 |  1028sec | MINI-MAX-5: 74% wins, 24% draws,  2% losts | RL-2X:  2% wins, 24% draws, 74% losts
# Game  2280 |  1032sec | MINI-MAX-5: 71% wins, 27% draws,  2% losts | RL-2X:  2% wins, 27% draws, 71% losts
# Game  2290 |  1038sec | MINI-MAX-5: 68% wins, 30% draws,  2% losts | RL-2X:  2% wins, 30% draws, 68% losts
# saved
# Game  2300 |  1043sec | MINI-MAX-5: 65% wins, 33% draws,  2% losts | RL-2X:  2% wins, 33% draws, 65% losts
# Game  2310 |  1047sec | MINI-MAX-5: 67% wins, 31% draws,  2% losts | RL-2X:  2% wins, 31% draws, 67% losts
# Game  2320 |  1052sec | MINI-MAX-5: 65% wins, 33% draws,  2% losts | RL-2X:  2% wins, 33% draws, 65% losts
# Game  2330 |  1056sec | MINI-MAX-5: 66% wins, 33% draws,  1% losts | RL-2X:  1% wins, 33% draws, 66% losts
# Game  2340 |  1061sec | MINI-MAX-5: 67% wins, 32% draws,  1% losts | RL-2X:  1% wins, 32% draws, 67% losts
# Game  2350 |  1066sec | MINI-MAX-5: 65% wins, 34% draws,  1% losts | RL-2X:  1% wins, 34% draws, 65% losts
# Game  2360 |  1070sec | MINI-MAX-5: 64% wins, 36% draws,  0% losts | RL-2X:  0% wins, 36% draws, 64% losts
# Game  2370 |  1075sec | MINI-MAX-5: 62% wins, 38% draws,  0% losts | RL-2X:  0% wins, 38% draws, 62% losts
# Game  2380 |  1080sec | MINI-MAX-5: 60% wins, 40% draws,  0% losts | RL-2X:  0% wins, 40% draws, 60% losts
# Game  2390 |  1085sec | MINI-MAX-5: 62% wins, 38% draws,  0% losts | RL-2X:  0% wins, 38% draws, 62% losts
# saved
# Game  2400 |  1090sec | MINI-MAX-5: 66% wins, 34% draws,  0% losts | RL-2X:  0% wins, 34% draws, 66% losts
# Game  2410 |  1094sec | MINI-MAX-5: 66% wins, 34% draws,  0% losts | RL-2X:  0% wins, 34% draws, 66% losts
# Game  2420 |  1099sec | MINI-MAX-5: 66% wins, 34% draws,  0% losts | RL-2X:  0% wins, 34% draws, 66% losts
# Game  2430 |  1103sec | MINI-MAX-5: 64% wins, 36% draws,  0% losts | RL-2X:  0% wins, 36% draws, 64% losts
# Game  2440 |  1108sec | MINI-MAX-5: 60% wins, 40% draws,  0% losts | RL-2X:  0% wins, 40% draws, 60% losts
# Game  2450 |  1112sec | MINI-MAX-5: 63% wins, 37% draws,  0% losts | RL-2X:  0% wins, 37% draws, 63% losts
# Game  2460 |  1117sec | MINI-MAX-5: 62% wins, 38% draws,  0% losts | RL-2X:  0% wins, 38% draws, 62% losts
# Game  2470 |  1123sec | MINI-MAX-5: 61% wins, 39% draws,  0% losts | RL-2X:  0% wins, 39% draws, 61% losts
# Game  2480 |  1128sec | MINI-MAX-5: 59% wins, 41% draws,  0% losts | RL-2X:  0% wins, 41% draws, 59% losts
# Game  2490 |  1133sec | MINI-MAX-5: 59% wins, 41% draws,  0% losts | RL-2X:  0% wins, 41% draws, 59% losts
# saved
# Game  2500 |  1138sec | MINI-MAX-5: 55% wins, 44% draws,  1% losts | RL-2X:  1% wins, 44% draws, 55% losts
# Game  2510 |  1142sec | MINI-MAX-5: 55% wins, 43% draws,  2% losts | RL-2X:  2% wins, 43% draws, 55% losts
# Game  2520 |  1147sec | MINI-MAX-5: 56% wins, 42% draws,  2% losts | RL-2X:  2% wins, 42% draws, 56% losts
# Game  2530 |  1151sec | MINI-MAX-5: 53% wins, 45% draws,  2% losts | RL-2X:  2% wins, 45% draws, 53% losts
# Game  2540 |  1156sec | MINI-MAX-5: 55% wins, 41% draws,  4% losts | RL-2X:  4% wins, 41% draws, 55% losts
# Game  2550 |  1162sec | MINI-MAX-5: 51% wins, 45% draws,  4% losts | RL-2X:  4% wins, 45% draws, 51% losts
# Game  2560 |  1167sec | MINI-MAX-5: 49% wins, 47% draws,  4% losts | RL-2X:  4% wins, 47% draws, 49% losts
# Game  2570 |  1171sec | MINI-MAX-5: 50% wins, 45% draws,  5% losts | RL-2X:  5% wins, 45% draws, 50% losts
# Game  2580 |  1176sec | MINI-MAX-5: 55% wins, 40% draws,  5% losts | RL-2X:  5% wins, 40% draws, 55% losts
# Game  2590 |  1180sec | MINI-MAX-5: 57% wins, 38% draws,  5% losts | RL-2X:  5% wins, 38% draws, 57% losts
# saved
# Game  2600 |  1185sec | MINI-MAX-5: 58% wins, 38% draws,  4% losts | RL-2X:  4% wins, 38% draws, 58% losts
# Game  2610 |  1189sec | MINI-MAX-5: 59% wins, 38% draws,  3% losts | RL-2X:  3% wins, 38% draws, 59% losts
# Game  2620 |  1194sec | MINI-MAX-5: 56% wins, 41% draws,  3% losts | RL-2X:  3% wins, 41% draws, 56% losts
# Game  2630 |  1198sec | MINI-MAX-5: 60% wins, 36% draws,  4% losts | RL-2X:  4% wins, 36% draws, 60% losts
# Game  2640 |  1203sec | MINI-MAX-5: 59% wins, 39% draws,  2% losts | RL-2X:  2% wins, 39% draws, 59% losts
# Game  2650 |  1207sec | MINI-MAX-5: 61% wins, 37% draws,  2% losts | RL-2X:  2% wins, 37% draws, 61% losts
# Game  2660 |  1211sec | MINI-MAX-5: 61% wins, 35% draws,  4% losts | RL-2X:  4% wins, 35% draws, 61% losts
# Game  2670 |  1216sec | MINI-MAX-5: 64% wins, 33% draws,  3% losts | RL-2X:  3% wins, 33% draws, 64% losts
# Game  2680 |  1220sec | MINI-MAX-5: 63% wins, 33% draws,  4% losts | RL-2X:  4% wins, 33% draws, 63% losts
# Game  2690 |  1224sec | MINI-MAX-5: 63% wins, 33% draws,  4% losts | RL-2X:  4% wins, 33% draws, 63% losts
# saved
# Game  2700 |  1228sec | MINI-MAX-5: 59% wins, 37% draws,  4% losts | RL-2X:  4% wins, 37% draws, 59% losts
# Game  2710 |  1233sec | MINI-MAX-5: 58% wins, 38% draws,  4% losts | RL-2X:  4% wins, 38% draws, 58% losts
# Game  2720 |  1236sec | MINI-MAX-5: 62% wins, 34% draws,  4% losts | RL-2X:  4% wins, 34% draws, 62% losts
# Game  2730 |  1241sec | MINI-MAX-5: 57% wins, 40% draws,  3% losts | RL-2X:  3% wins, 40% draws, 57% losts
# Game  2740 |  1246sec | MINI-MAX-5: 58% wins, 39% draws,  3% losts | RL-2X:  3% wins, 39% draws, 58% losts
# Game  2750 |  1250sec | MINI-MAX-5: 57% wins, 40% draws,  3% losts | RL-2X:  3% wins, 40% draws, 57% losts
# Game  2760 |  1254sec | MINI-MAX-5: 60% wins, 38% draws,  2% losts | RL-2X:  2% wins, 38% draws, 60% losts
# Game  2770 |  1259sec | MINI-MAX-5: 59% wins, 39% draws,  2% losts | RL-2X:  2% wins, 39% draws, 59% losts
# Game  2780 |  1263sec | MINI-MAX-5: 61% wins, 38% draws,  1% losts | RL-2X:  1% wins, 38% draws, 61% losts
# Game  2790 |  1267sec | MINI-MAX-5: 60% wins, 39% draws,  1% losts | RL-2X:  1% wins, 39% draws, 60% losts
# saved
# Game  2800 |  1271sec | MINI-MAX-5: 66% wins, 33% draws,  1% losts | RL-2X:  1% wins, 33% draws, 66% losts
# Game  2810 |  1277sec | MINI-MAX-5: 66% wins, 33% draws,  1% losts | RL-2X:  1% wins, 33% draws, 66% losts
# Game  2820 |  1281sec | MINI-MAX-5: 66% wins, 33% draws,  1% losts | RL-2X:  1% wins, 33% draws, 66% losts
# Game  2830 |  1286sec | MINI-MAX-5: 67% wins, 32% draws,  1% losts | RL-2X:  1% wins, 32% draws, 67% losts
# Game  2840 |  1291sec | MINI-MAX-5: 66% wins, 32% draws,  2% losts | RL-2X:  2% wins, 32% draws, 66% losts
# Game  2850 |  1295sec | MINI-MAX-5: 66% wins, 32% draws,  2% losts | RL-2X:  2% wins, 32% draws, 66% losts
# Game  2860 |  1300sec | MINI-MAX-5: 66% wins, 32% draws,  2% losts | RL-2X:  2% wins, 32% draws, 66% losts
# Game  2870 |  1305sec | MINI-MAX-5: 65% wins, 33% draws,  2% losts | RL-2X:  2% wins, 33% draws, 65% losts
# Game  2880 |  1310sec | MINI-MAX-5: 60% wins, 38% draws,  2% losts | RL-2X:  2% wins, 38% draws, 60% losts
# Game  2890 |  1315sec | MINI-MAX-5: 60% wins, 38% draws,  2% losts | RL-2X:  2% wins, 38% draws, 60% losts
# saved
# Game  2900 |  1319sec | MINI-MAX-5: 59% wins, 39% draws,  2% losts | RL-2X:  2% wins, 39% draws, 59% losts
# Game  2910 |  1324sec | MINI-MAX-5: 59% wins, 38% draws,  3% losts | RL-2X:  3% wins, 38% draws, 59% losts
# Game  2920 |  1329sec | MINI-MAX-5: 58% wins, 39% draws,  3% losts | RL-2X:  3% wins, 39% draws, 58% losts
# Game  2930 |  1336sec | MINI-MAX-5: 61% wins, 36% draws,  3% losts | RL-2X:  3% wins, 36% draws, 61% losts
# Game  2940 |  1341sec | MINI-MAX-5: 60% wins, 38% draws,  2% losts | RL-2X:  2% wins, 38% draws, 60% losts
# Game  2950 |  1345sec | MINI-MAX-5: 61% wins, 36% draws,  3% losts | RL-2X:  3% wins, 36% draws, 61% losts
# Game  2960 |  1349sec | MINI-MAX-5: 64% wins, 34% draws,  2% losts | RL-2X:  2% wins, 34% draws, 64% losts
# Game  2970 |  1353sec | MINI-MAX-5: 63% wins, 34% draws,  3% losts | RL-2X:  3% wins, 34% draws, 63% losts
# Game  2980 |  1357sec | MINI-MAX-5: 68% wins, 28% draws,  4% losts | RL-2X:  4% wins, 28% draws, 68% losts
# Game  2990 |  1361sec | MINI-MAX-5: 67% wins, 27% draws,  6% losts | RL-2X:  6% wins, 27% draws, 67% losts
# saved
# Game  3000 |  1369sec | MINI-MAX-5: 68% wins, 25% draws,  7% losts | RL-2X:  7% wins, 25% draws, 68% losts
# Game  3010 |  1376sec | MINI-MAX-5: 68% wins, 25% draws,  7% losts | RL-2X:  7% wins, 25% draws, 68% losts
# Game  3020 |  1383sec | MINI-MAX-5: 66% wins, 27% draws,  7% losts | RL-2X:  7% wins, 27% draws, 66% losts
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 12
#      10 for game_num in range(1, 20000):
#      11     engine_X, engine_0 = random.sample(engines, k=2)
# ---> 12     game.auto_play(engine_X, engine_0)
#      13     stats.add(game)
#
# Cell In[37], line 74, in TicTacToe.auto_play(self, player_X, player_0)
#      72 self.new(player_X, player_0)
#      73 for i in range(0, 9):
# ---> 74     self.auto_move()
#      75     self.engine_X.train(self)
#      76     self.engine_0.train(self)
#
# Cell In[37], line 82, in TicTacToe.auto_move(self)
#      80 def auto_move(self):
#      81     if self.is_tie():  # game is not finished
# ---> 82         best_move = self.engine_X.move(self) if self.player == 1 else self.engine_0.move(self)
#      83         if best_move in self.moves:
#      84             print('!!!!!!!!!! Wrong move')
#
# Cell In[40], line 90, in EngineDenseRL2x.move(self, game)
#      88 def move(self, game):
#      89     X = [self.__board2x(game)]
# ---> 90     Y = self.model.predict(X, verbose=0)
#      91     y = game.remove_illegal_moves(Y[0])
#      92     return np.argmax(Y[0])
#
# File c:\work\python\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\work\python\venv\Lib\site-packages\keras\src\engine\training.py:2620, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2611     except ValueError:
#    2612         warnings.warn(
#    2613             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2614             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2617             stacklevel=2,
#    2618         )
# -> 2620 data_handler = data_adapter.get_data_handler(
#    2621     x=x,
#    2622     batch_size=batch_size,
#    2623     steps_per_epoch=steps,
#    2624     initial_epoch=0,
#    2625     epochs=1,
#    2626     max_queue_size=max_queue_size,
#    2627     workers=workers,
#    2628     use_multiprocessing=use_multiprocessing,
#    2629     model=self,
#    2630     steps_per_execution=self._steps_per_execution,
#    2631 )
#    2633 # Container that configures and calls `tf.keras.Callback`s.
#    2634 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\work\python\venv\Lib\site-packages\keras\src\engine\data_adapter.py:1688, in get_data_handler(*args, **kwargs)
#    1686         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688 return DataHandler(*args, **kwargs)
#
# File c:\work\python\venv\Lib\site-packages\keras\src\engine\data_adapter.py:1292, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1289     self._steps_per_execution = steps_per_execution
#    1291 adapter_cls = select_data_adapter(x, y)
# -> 1292 self._adapter = adapter_cls(
#    1293     x,
#    1294     y,
#    1295     batch_size=batch_size,
#    1296     steps=steps_per_epoch,
#    1297     epochs=epochs - initial_epoch,
#    1298     sample_weights=sample_weight,
#    1299     shuffle=shuffle,
#    1300     max_queue_size=max_queue_size,
#    1301     workers=workers,
#    1302     use_multiprocessing=use_multiprocessing,
#    1303     distribution_strategy=tf.distribute.get_strategy(),
#    1304     model=model,
#    1305     pss_evaluation_shards=pss_evaluation_shards,
#    1306 )
#    1308 strategy = tf.distribute.get_strategy()
#    1310 self._current_step = 0
#
# File c:\work\python\venv\Lib\site-packages\keras\src\engine\data_adapter.py:723, in ListsOfScalarsDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, shuffle, **kwargs)
#     718     sample_weights = np.asarray(sample_weights)
#     719 sample_weight_modes = broadcast_sample_weight_modes(
#     720     sample_weights, sample_weight_modes
#     721 )
# --> 723 self._internal_adapter = TensorLikeDataAdapter(
#     724     x,
#     725     y=y,
#     726     sample_weights=sample_weights,
#     727     sample_weight_modes=sample_weight_modes,
#     728     batch_size=batch_size,
#     729     shuffle=shuffle,
#     730     **kwargs,
#     731 )
#
# File c:\work\python\venv\Lib\site-packages\keras\src\engine\data_adapter.py:353, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     350         flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     351     return flat_dataset
# --> 353 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     355 dataset = self.slice_inputs(indices_dataset, inputs)
#     357 if shuffle == "batch":
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2325, in DatasetV2.flat_map(self, map_func, name)
#    2321 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2322 # dataset_ops).
#    2323 # pylint: disable=g-import-not-at-top,protected-access
#    2324 from tensorflow.python.data.ops import flat_map_op
# -> 2325 return flat_map_op._flat_map(self, map_func, name=name)
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:33, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      30 def __init__(self, input_dataset, map_func, name=None):
#      32   self._input_dataset = input_dataset
# ---> 33   self._map_func = structured_function.StructuredFunctionWrapper(
#      34       map_func, self._transformation_name(), dataset=input_dataset)
#      35   if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#      36     raise TypeError(
#      37         "The `map_func` argument must return a `Dataset` object. Got "
#      38         f"{dataset_ops.get_type(self._map_func.output_structure)!r}.")
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1227, in Function.get_concrete_function(self, *args, **kwargs)
#    1225 def get_concrete_function(self, *args, **kwargs):
#    1226   # Implements PolymorphicFunction.get_concrete_function.
# -> 1227   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1228   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1229   return concrete
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1197, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1195   if self._variable_creation_config is None:
#    1196     initializers = []
# -> 1197     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1198     self._initialize_uninitialized_variables(initializers)
#    1200 if self._created_variables:
#    1201   # In this case we have created variables on the first call, so we run the
#    1202   # version which is guaranteed to never create variables.
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:695, in Function._initialize(self, args, kwds, add_initializers_to)
#     690 self._variable_creation_config = self._generate_scoped_tracing_options(
#     691     variable_capturing_scope,
#     692     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     693 )
#     694 # Force the definition of the function for these arguments
# --> 695 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696     args, kwds, self._variable_creation_config
#     697 )
#     699 def invalid_creator_scope(*unused_args, **unused_kwds):
#     700   """Disables variable creation."""
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:598, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     594 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     595   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     596   # the function a weak reference to itself to avoid a reference cycle.
#     597   with OptionalXlaContext(compile_with_xla):
# --> 598     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599   return out
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:231, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     230 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231   ret = wrapper_helper(*args)
#     232   ret = structure.to_tensor_list(self._output_structure, ret)
#     233   return [ops.convert_to_tensor(t) for t in ret]
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:161, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     159 if not _should_unpack(nested_args):
#     160   nested_args = (nested_args,)
# --> 161 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162 ret = variable_utils.convert_variables_to_tensors(ret)
#     163 if _should_pack(ret):
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\work\python\venv\Lib\site-packages\keras\src\engine\data_adapter.py:342, in TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices(indices)
#     339 flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     340 if self._partial_batch_size:
#     341     index_remainder = tf.data.Dataset.from_tensors(
# --> 342         tf.slice(
#     343             indices, [num_in_full_batch], [self._partial_batch_size]
#     344         )
#     345     )
#     346     flat_dataset = flat_dataset.concatenate(index_remainder)
#     348 if shuffle == "batch":
#     349     # 1024 is a magic constant that has not been properly evaluated
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\ops\array_ops.py:1223, in slice(input_, begin, size, name)
#    1171 @tf_export("slice")
#    1172 @dispatch.add_dispatch_support
#    1173 def slice(input_, begin, size, name=None):
#    1174   # pylint: disable=redefined-builtin
#    1175   """Extracts a slice from a tensor.
#    1176
#    1177   See also `tf.strided_slice`.
#    (...)
#    1221     A `Tensor` the same type as `input_`.
#    1222   """
# -> 1223   return gen_array_ops._slice(input_, begin, size, name=name)
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\ops\gen_array_ops.py:9826, in _slice(input, begin, size, name)
#    9824     pass  # Add nodes to the TensorFlow graph.
#    9825 # Add nodes to the TensorFlow graph.
# -> 9826 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9827       "Slice", input=input, begin=begin, size=size, name=name)
#    9828 _result = _outputs[:]
#    9829 if _execute.must_record_gradient():
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\framework\op_def_library.py:796, in _apply_op_helper(op_type_name, name, **keywords)
#     791 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     792                         if arg.is_ref]
#     793 with _MaybeColocateWith(must_colocate_inputs):
#     794   # Add Op to graph
#     795   # pylint: disable=protected-access
# --> 796   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     797                              name=scope, input_types=input_types,
#     798                              attrs=attr_protos, op_def=op_def)
#     800 # `outputs` is returned as a separate return value so that the output
#     801 # tensors can the `op` per se can be decoupled so that the
#     802 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     803 # for more details.
#     804 outputs = op.outputs
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\framework\ops.py:2652, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2649 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2650 # Session.run call cannot occur between creating and mutating the op.
#    2651 with self._mutation_lock():
# -> 2652   ret = Operation.from_node_def(
#    2653       node_def,
#    2654       self,
#    2655       inputs=inputs,
#    2656       output_types=dtypes,
#    2657       control_inputs=control_inputs,
#    2658       input_types=input_types,
#    2659       original_op=self._default_original_op,
#    2660       op_def=op_def,
#    2661   )
#    2662   self._create_op_helper(ret, compute_device=compute_device)
#    2663 return ret
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\framework\ops.py:1160, in Operation.from_node_def(***failed resolving arguments***)
#    1157     control_input_ops.append(control_op)
#    1159 # Initialize c_op from node_def and other inputs
# -> 1160 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1161 self = Operation(c_op, SymbolicTensor)
#    1162 self._init(g)
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\work\python\venv\Lib\site-packages\tensorflow\python\framework\ops.py:1017, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1013   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1014                                          serialized)
#    1016 try:
# -> 1017   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1018 except errors.InvalidArgumentError as e:
#    1019   # Convert to ValueError for backwards compatibility.
#    1020   raise ValueError(e.message)
#
# KeyboardInterrupt:
