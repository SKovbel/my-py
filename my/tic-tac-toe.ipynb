# %%
import os
import json
import time
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import EarlyStopping, Callback

# %% [markdown]
# **MiniMax engine**

# %%
class TicTacToe:
    moves = []
    player = None
    game_status = None
    engine_X = None
    engine_0 = None
    RULES = [
        [0, 1, 2], [3, 4, 5], [6, 7, 8],  # horizontal
        [0, 3, 6], [1, 4, 7], [2, 5, 8],  # vertical
        [0, 4, 8], [2, 4, 6]  # diagonal
    ]

    def __init__(self):
        pass

    def new(self, engine_X, engine_0):
        self.player = 1
        self.moves = []
        self.game_status = None
        self.engine_X = engine_X
        self.engine_0 = engine_0

    # 1 if won <X>, -1 if won <0>, 0 if draw, None if game is not finished
    def status(self, board=None):
        if board is None:
            return self.game_status

        is_draw = True
        for rule in self.RULES:
            abs_sum = abs(board[rule[0]] + board[rule[1]] + board[rule[2]])
            if abs_sum == 3:
                return board[rule[0]]  # return player won (1, -1)
            if is_draw:
                sum_abs = abs(board[rule[0]]) + abs(board[rule[1]]) + abs(board[rule[2]])
                is_draw = False if abs_sum == sum_abs else is_draw
        return 0 if is_draw else None  # return draw or game is not finished

    def board(self, pos=None):
        board = 9 * [0.]
        pos = len(self.moves) if pos is None else pos
        last = pos if pos >= 0 else len(self.moves) + pos
        turn = 1
        for idx in self.moves[0:last]:
            board[idx] = float(turn)
            turn = -turn
        return board

    def timeseries(self):
        moves = 9 * [0.]
        time_series = [moves.copy()]
        turn = 1
        for move_idx in self.moves:
            moves[move_idx] = 1. if turn == 1 else -1.
            time_series.append(moves.copy())
            turn = -turn
        return time_series

    def is_tie(self, status=None):
        status = status if status else self.game_status
        return status is None

    def is_game_over(self, status=None):
        return not self.is_tie(status)

    def remove_illegal_moves(self, Y, moves = None):
        moves = moves if moves else self.moves
        for pos in moves:
            Y[pos] = -1
        return Y

    def auto_play(self, player_X, player_0):
        self.new(player_X, player_0)
        for i in range(0, 9):
            self.auto_move()
            self.engine_X.train(self)
            self.engine_0.train(self)
            if self.is_game_over():
                break

    def auto_move(self):
        if self.is_tie():  # game is not finished
            best_move = self.engine_X.move(self) if self.player == 1 else self.engine_0.move(self)
            if best_move in self.moves:
                print('!!!!!!!!!! Wrong move')
                exit(0)
            self.moves.append(best_move)
        # update status
        self.game_status = self.status(self.board())
        if self.is_tie():  # game is continue we change player, else left winner or last moved as is
            self.player = -self.player

    def print(self):
        board = self.board()
        print(board)
        print("\n", self.engine_X.code, self.engine_0.code)
        for r in range(0, 3):
            for c in range(0, 3):
                mark = ' '
                mark = 'X' if board[3*r + c] == 1 else mark
                mark = '0' if board[3 * r + c] == -1 else mark
                print(mark, end='')
            print()

# %%
class Stats:
    STEP = 10
    WINDOW = 100

    def __init__(self, engines):
        self.counter = 0
        self.start_time = int(time.time() * 1000)
        self.engines = engines
        self.statuses = []

    def add(self, game):
        self.counter += 1

        won = game.status()
        code_x = game.engine_X.code
        code_0 = game.engine_0.code

        stats = {
            code_x: {'g': 1, 'w': 0, 'd': 0, 'l': 0},
            code_0: {'g': 1, 'w': 0, 'd': 0, 'l': 0}
        }

        if won:
            win, lost = (code_x, code_0) if won == 1 else (code_0, code_x)
            stats[win]['w'] = 1
            stats[lost]['l'] = 1
        else:
            stats[code_x]['d'] = 1
            stats[code_0]['d'] = 1

        self.statuses.append(stats)
        self.pop()

        if self.counter == 1:
            self.header()
        if self.counter % self.STEP == 0:
            self.print()

    def pop(self):
        if len(self.statuses) > self.WINDOW:
            self.statuses.pop(0)

    def header(self):
        print(f"Stats config: STEP = {self.STEP}, WINDOW = {self.WINDOW}")

    def print(self):
        loop = int(time.time() * 1000)
        p = lambda x, c: round(100*x/c)
        print(f"Game {self.counter:>5} | {int((loop - self.start_time) / 1000):>5}sec", end=' | ')
        stats_str = []
        for item in self.engines:
            engine = item.code
            cnt = win = drw = lst = 0
            for row in self.statuses:
                if engine in row:
                    cnt += row[engine]['g']
                    win += row[engine]['w']
                    drw += row[engine]['d']
                    lst += row[engine]['l']
            stats_str.append(
                f"{engine.upper()}: {p(win,cnt):>2}% wins, {p(drw,cnt):>2}% draws, {p(lst,cnt):>2}% losts")
        print(' | '.join(stats_str))

# %%
class EngineMiniMax:
    INF = 1000

    def __init__(self, code='MinMax', max_depth=5):
        self.code = f"{code}-{max_depth}"
        self.max_depth = max_depth
        
    def move(self, game):
        best_moves = self.__minimax(game, game.board())
        moves = self.__legal_moves(best_moves)
        return moves.index(max(moves))

    def train(self, game):
        pass

    def __legal_moves(self, best_moves):
        y = 9 * [0]
        for move in best_moves:
            y[move] = 1 + random.uniform(-0.5, 0.5)
        y = game.remove_illegal_moves(y)
        #print('MM legal', y)
        return y

    def __minimax(self, game, board, turn=1, depth=0):
        if depth:
            status = game.status(board)
            if game.is_game_over(status):
                return status / depth   # win

            if depth >= self.max_depth:
                return 0

        best_score = -self.INF if turn > 0 else self.INF
        best_moves = []

        for i in range(len(board)):
            if board[i] != 0:  # skip zero squares
                continue
            # only 1 and -1
            board[i] = turn
            score = self.__minimax(game, board, -turn, depth + 1)
            if turn > 0 and score >= best_score:
                if best_score != score:
                    best_moves = []
                best_score = score
                if depth == 0:
                    best_moves.append(i)
            elif turn < 0 and score <= best_score:
                if best_score != score:
                    best_moves = []
                best_score = score
                if depth == 0:
                    best_moves.append(i)
            board[i] = 0

        return best_score if depth else best_moves

# %%
class EngineDenseRL2x:
    unique_ids = {}
    EPOCHS = 300
    SAVE_EACH_TRAINS = 100

    REWARD_LR = 0.7
    REWARD_WIN = 0.90
    REWARD_DRW = 0.30
    REWARD_LST = 0.10

    def __init__(self, code='EngineDenseRL2x', unique=False):
        self.counter = 0
        self.code = code
        self.unique_ids = {} if unique else False
        self.model_file = f"save/{self.code}.keras"
        self.extra_file = f"save/{self.code}.extra.json"
        os.makedirs(os.path.dirname(self.model_file), exist_ok=True)
        self.__init_model()

    def __init_model(self):
        self.model = self.__load()
        if not self.model:
            self.model = Sequential([
                layers.ReLU(72, input_shape=(18,)),    #  2*9 as split X and 0 to separate cells
                #layers.Normalization(),
                layers.ReLU(36),
                #layers.Dropout(0.2),
                layers.Normalization(),
                layers.Dense(9, activation='sigmoid')
            ])
            self.model.compile(optimizer='adam', loss='mse')   # binary_crossentropy

    def __check_uniq(self, game):
        if self.unique_ids:
            game_id = ''.join(str(item) for item in game.moves)
            if game_id in self.unique_ids:
                return True
            self.unique_ids[game_id] = True
        return False

    def __board2x(self, game):
        board = game.board()
        board2x = 9 * [1, 0]
        # if empty cell then first is 1 to decrase count of 0 values. And 0 if cell is X moved
        for i in range(len(board)):
            if board[i] == 1:
                board2x[2 * i] = 0
            if board[i] == -1:
                board2x[2 * i + 1] = 1
        return board2x

    def __timeseries2x(self, game):
        board = game.board()
        series = 9 * [1, 0]
        timeseries2x = []
        for i in game.moves:
            if board[i] == 1:
                series[2 * i] = 0
            if board[i] == -1:
                series[2 * i + 1] = 1
            timeseries2x.append(series.copy())
        return timeseries2x

    def __legal_moves(self, game, Y):
        for i in range(len(Y)):
            Y[i] = game.remove_illegal_moves(Y[i], game.moves[:i])
        #print('NN legal', Y)
        return Y

    def __save(self):
        if self.counter % self.SAVE_EACH_TRAINS == 0:
            self.model.save(self.model_file)
            extra = {'counter': self.counter}
            with open(self.extra_file, 'w') as extra_file:
                json.dump(extra, extra_file)
            print('saved')

    def __load(self):
        if os.path.exists(self.model_file):
            with open(self.extra_file, 'r') as extra_file:
                params = json.load(extra_file)
                self.counter = params['counter']
            print(f'loaded, last game number is {self.counter}')
            return load_model(self.model_file)
        return False


    def move(self, game):
        X = [self.__board2x(game)]
        Y = self.model.predict(X, verbose=0)
        y = game.remove_illegal_moves(Y[0])
        return np.argmax(Y[0])

    def train(self, game):
        # this engine trains only on the end of game
        if game.is_tie():
            return

        if self.__check_uniq(game):
            return

        self.counter += 1

        X = self.__timeseries2x(game)[:-1]     # skip last series
        Y = self.model.predict(X, verbose=0)
        Y = self.__legal_moves(game, Y)

        turn_a = True
        reward_a = self.REWARD_WIN if game.status() else self.REWARD_DRW
        reward_b = self.REWARD_LST if game.status() else self.REWARD_DRW

        for t in range(len(Y) - 1, -1, -1):
            move = game.moves[t+1]
            # print(t, move, game.moves, X[t], Y[t])
            if turn_a:
                reward_a = Y[t][move] + self.REWARD_LR * (reward_a - Y[t][move])
                Y[t][move] = reward_a
            else:
                reward_b = Y[t][move] + self.REWARD_LR * (reward_b - Y[t][move])
                Y[t][move] = reward_b
            turn_a = not turn_a
        early_stopping = EarlyStopping(monitor='loss', patience=1, restore_best_weights=True)
        self.model.fit(np.array(X), np.array(Y), epochs=self.EPOCHS, batch_size=10, verbose=0, callbacks=[early_stopping])

        self.__save()

# %%
class EngineDenseRL3x:
    unique_ids = {}

    EPOCHS = 300

    REWARD_LR = 0.7
    REWARD_WIN = 0.90
    REWARD_DRW = 0.30
    REWARD_LST = 0.10

    def __init__(self, code='EngineDenseRL2x', unique=False):
        self.code = code
        self.unique_ids = {} if unique else False
        self.model = Sequential([
            layers.ReLU(81, input_shape=(27,)),    #  2*9 as split X and 0 to separate cells
            #layers.Normalization(),
            layers.ReLU(81),
            #layers.Dropout(0.2),
            layers.Normalization(),
            layers.Dense(9, activation='sigmoid')
        ])
        self.model.compile(optimizer='adam', loss='binary_crossentropy')   # binary_crossentropy
                        
    def __check_uniq(self, game):
        if self.unique_ids:
            game_id = ''.join(str(item) for item in game.moves)
            if game_id in self.unique_ids:
                return True
            self.unique_ids[game_id] = True
        return False

    def __board3x(self, game):
        board = game.board()
        board3x = 9 * [0, 0, 0]
        for i in range(len(board)):
            if board[i] == 1:
                board3x[3 * i] = 1
            if board[i] == -1:
                board3x[3 * i + 1] = 1
            if board[i] == 0:
                board3x[3 * i + 2] = 1
        return board3x

    def __timeseries3x(self, game):
        board = game.board()
        series = 9 * [0, 0, 0]
        timeseries3x = []
        for i in game.moves:
            if board[i] == 1:
                series[3 * i] = 1
            if board[i] == -1:
                series[3 * i + 1] = 1
            if board[i] == 0:
                series[3 * i + 2] = 1
            timeseries3x.append(series.copy())
        return timeseries3x

    def __legal_moves(self, game, Y):
        for i in range(len(Y)):
            Y[i] = game.remove_illegal_moves(Y[i], game.moves[:i])
        #print('NN legal', Y)
        return Y

    def move(self, game):
        X = [self.__board3x(game)]
        Y = self.model.predict(X, verbose=0)
        y = game.remove_illegal_moves(Y[0])
        return np.argmax(Y[0])

    def train(self, game):
        # this engine trains only on the end of game
        if game.is_tie():
            return

        if self.__check_uniq(game):
            return

        X = self.__timeseries3x(game)[:-1]     # skip last series
        Y = self.model.predict(X, verbose=0)
        Y = self.__legal_moves(game, Y)

        turn_a = True
        reward_a = self.REWARD_WIN if game.status() else self.REWARD_DRW
        reward_b = self.REWARD_LST if game.status() else self.REWARD_DRW

        for t in range(len(Y) - 1, -1, -1):
            move = game.moves[t+1]
            # print(t, move, game.moves, X[t], Y[t])
            if turn_a:
                reward_a = Y[t][move] + self.REWARD_LR * (reward_a - Y[t][move])
                Y[t][move] = reward_a
            else:
                reward_b = Y[t][move] + self.REWARD_LR * (reward_b - Y[t][move])
                Y[t][move] = reward_b
            turn_a = not turn_a
        early_stopping = EarlyStopping(monitor='loss', patience=1, restore_best_weights=True)
        self.model.fit(np.array(X), np.array(Y), epochs=self.EPOCHS, batch_size=10, verbose=0, callbacks=[early_stopping])

# %% [markdown]
# **Game loop**

# %%
engines = [
    EngineMiniMax('Mini-Max', max_depth=5),
    EngineDenseRL2x('RL-2x', unique=False),
    # EngineDenseRL3x('RL-3x', unique=False),
]

game = TicTacToe()
stats = Stats(engines)

for game_num in range(1, 20000):
    engine_X, engine_0 = random.sample(engines, k=2)
    game.auto_play(engine_X, engine_0)
    stats.add(game)
# Out:
# loaded, last train number is 100
# Stats config: STEP = 10, WINDOW = 100
# Game    10 |     4sec | MINI-MAX-5: 90% wins, 10% draws,  0% losts | RL-2X:  0% wins, 10% draws, 90% losts
# Game    20 |     8sec | MINI-MAX-5: 95% wins,  5% draws,  0% losts | RL-2X:  0% wins,  5% draws, 95% losts
# Game    30 |    13sec | MINI-MAX-5: 97% wins,  3% draws,  0% losts | RL-2X:  0% wins,  3% draws, 97% losts
# Game    40 |    18sec | MINI-MAX-5: 95% wins,  5% draws,  0% losts | RL-2X:  0% wins,  5% draws, 95% losts
# Game    50 |    23sec | MINI-MAX-5: 92% wins,  6% draws,  2% losts | RL-2X:  2% wins,  6% draws, 92% losts
# Game    60 |    28sec | MINI-MAX-5: 88% wins,  7% draws,  5% losts | RL-2X:  5% wins,  7% draws, 88% losts
# Game    70 |    34sec | MINI-MAX-5: 84% wins,  7% draws,  9% losts | RL-2X:  9% wins,  7% draws, 84% losts
# Game    80 |    38sec | MINI-MAX-5: 84% wins,  9% draws,  8% losts | RL-2X:  8% wins,  9% draws, 84% losts
# Game    90 |    43sec | MINI-MAX-5: 83% wins, 10% draws,  7% losts | RL-2X:  7% wins, 10% draws, 83% losts
# saved
# Game   100 |    47sec | MINI-MAX-5: 84% wins,  9% draws,  7% losts | RL-2X:  7% wins,  9% draws, 84% losts
# Game   110 |    52sec | MINI-MAX-5: 83% wins, 10% draws,  7% losts | RL-2X:  7% wins, 10% draws, 83% losts
# Game   120 |    56sec | MINI-MAX-5: 80% wins, 12% draws,  8% losts | RL-2X:  8% wins, 12% draws, 80% losts
# Game   130 |    63sec | MINI-MAX-5: 74% wins, 14% draws, 12% losts | RL-2X: 12% wins, 14% draws, 74% losts
# Game   140 |    76sec | MINI-MAX-5: 71% wins, 13% draws, 16% losts | RL-2X: 16% wins, 13% draws, 71% losts
# Game   150 |    87sec | MINI-MAX-5: 71% wins, 13% draws, 16% losts | RL-2X: 16% wins, 13% draws, 71% losts
# Game   160 |    93sec | MINI-MAX-5: 73% wins, 12% draws, 15% losts | RL-2X: 15% wins, 12% draws, 73% losts
# Game   170 |    97sec | MINI-MAX-5: 74% wins, 12% draws, 14% losts | RL-2X: 14% wins, 12% draws, 74% losts
# Game   180 |   101sec | MINI-MAX-5: 71% wins, 10% draws, 19% losts | RL-2X: 19% wins, 10% draws, 71% losts
# Game   190 |   105sec | MINI-MAX-5: 72% wins,  9% draws, 19% losts | RL-2X: 19% wins,  9% draws, 72% losts
# saved
# Game   200 |   109sec | MINI-MAX-5: 71% wins, 10% draws, 19% losts | RL-2X: 19% wins, 10% draws, 71% losts
# Game   210 |   114sec | MINI-MAX-5: 70% wins,  9% draws, 21% losts | RL-2X: 21% wins,  9% draws, 70% losts
# Game   220 |   119sec | MINI-MAX-5: 71% wins,  8% draws, 21% losts | RL-2X: 21% wins,  8% draws, 71% losts
# Game   230 |   123sec | MINI-MAX-5: 73% wins,  8% draws, 19% losts | RL-2X: 19% wins,  8% draws, 73% losts
# Game   240 |   127sec | MINI-MAX-5: 74% wins,  9% draws, 17% losts | RL-2X: 17% wins,  9% draws, 74% losts
# Game   250 |   132sec | MINI-MAX-5: 74% wins,  9% draws, 17% losts | RL-2X: 17% wins,  9% draws, 74% losts
# Game   260 |   137sec | MINI-MAX-5: 71% wins, 10% draws, 19% losts | RL-2X: 19% wins, 10% draws, 71% losts
# Game   270 |   142sec | MINI-MAX-5: 70% wins,  9% draws, 21% losts | RL-2X: 21% wins,  9% draws, 70% losts
# Game   280 |   146sec | MINI-MAX-5: 72% wins, 10% draws, 18% losts | RL-2X: 18% wins, 10% draws, 72% losts
# Game   290 |   151sec | MINI-MAX-5: 68% wins, 11% draws, 21% losts | RL-2X: 21% wins, 11% draws, 68% losts
# saved
# Game   300 |   155sec | MINI-MAX-5: 68% wins, 11% draws, 21% losts | RL-2X: 21% wins, 11% draws, 68% losts
# Game   310 |   160sec | MINI-MAX-5: 68% wins, 12% draws, 20% losts | RL-2X: 20% wins, 12% draws, 68% losts
# Game   320 |   164sec | MINI-MAX-5: 68% wins, 11% draws, 21% losts | RL-2X: 21% wins, 11% draws, 68% losts
# Game   330 |   169sec | MINI-MAX-5: 68% wins, 10% draws, 22% losts | RL-2X: 22% wins, 10% draws, 68% losts
# Game   340 |   174sec | MINI-MAX-5: 67% wins, 10% draws, 23% losts | RL-2X: 23% wins, 10% draws, 67% losts
# Game   350 |   178sec | MINI-MAX-5: 65% wins,  9% draws, 26% losts | RL-2X: 26% wins,  9% draws, 65% losts
# Game   360 |   183sec | MINI-MAX-5: 62% wins, 11% draws, 27% losts | RL-2X: 27% wins, 11% draws, 62% losts
# Game   370 |   188sec | MINI-MAX-5: 65% wins, 11% draws, 24% losts | RL-2X: 24% wins, 11% draws, 65% losts
# Game   380 |   192sec | MINI-MAX-5: 62% wins, 11% draws, 27% losts | RL-2X: 27% wins, 11% draws, 62% losts
# Game   390 |   196sec | MINI-MAX-5: 66% wins,  9% draws, 25% losts | RL-2X: 25% wins,  9% draws, 66% losts
# saved
# Game   400 |   201sec | MINI-MAX-5: 66% wins,  9% draws, 25% losts | RL-2X: 25% wins,  9% draws, 66% losts
# Game   410 |   205sec | MINI-MAX-5: 68% wins,  7% draws, 25% losts | RL-2X: 25% wins,  7% draws, 68% losts
# Game   420 |   209sec | MINI-MAX-5: 68% wins,  9% draws, 23% losts | RL-2X: 23% wins,  9% draws, 68% losts
# Game   430 |   214sec | MINI-MAX-5: 70% wins,  9% draws, 21% losts | RL-2X: 21% wins,  9% draws, 70% losts
# Game   440 |   219sec | MINI-MAX-5: 70% wins, 10% draws, 20% losts | RL-2X: 20% wins, 10% draws, 70% losts
# Game   450 |   223sec | MINI-MAX-5: 72% wins, 11% draws, 17% losts | RL-2X: 17% wins, 11% draws, 72% losts
# Game   460 |   228sec | MINI-MAX-5: 74% wins,  9% draws, 17% losts | RL-2X: 17% wins,  9% draws, 74% losts
# Game   470 |   233sec | MINI-MAX-5: 71% wins, 10% draws, 19% losts | RL-2X: 19% wins, 10% draws, 71% losts
# Game   480 |   239sec | MINI-MAX-5: 76% wins,  9% draws, 15% losts | RL-2X: 15% wins,  9% draws, 76% losts
# Game   490 |   243sec | MINI-MAX-5: 73% wins, 11% draws, 16% losts | RL-2X: 16% wins, 11% draws, 73% losts
# saved
# Game   500 |   248sec | MINI-MAX-5: 71% wins, 12% draws, 17% losts | RL-2X: 17% wins, 12% draws, 71% losts
# Game   510 |   252sec | MINI-MAX-5: 69% wins, 13% draws, 18% losts | RL-2X: 18% wins, 13% draws, 69% losts
# Game   520 |   256sec | MINI-MAX-5: 69% wins, 12% draws, 19% losts | RL-2X: 19% wins, 12% draws, 69% losts
# Game   530 |   260sec | MINI-MAX-5: 67% wins, 12% draws, 21% losts | RL-2X: 21% wins, 12% draws, 67% losts
# Game   540 |   265sec | MINI-MAX-5: 68% wins, 12% draws, 20% losts | RL-2X: 20% wins, 12% draws, 68% losts
# Game   550 |   270sec | MINI-MAX-5: 67% wins, 11% draws, 22% losts | RL-2X: 22% wins, 11% draws, 67% losts
# Game   560 |   274sec | MINI-MAX-5: 71% wins, 11% draws, 18% losts | RL-2X: 18% wins, 11% draws, 71% losts
# Game   570 |   279sec | MINI-MAX-5: 73% wins, 11% draws, 16% losts | RL-2X: 16% wins, 11% draws, 73% losts
# Game   580 |   285sec | MINI-MAX-5: 69% wins, 13% draws, 18% losts | RL-2X: 18% wins, 13% draws, 69% losts
# Game   590 |   289sec | MINI-MAX-5: 72% wins, 12% draws, 16% losts | RL-2X: 16% wins, 12% draws, 72% losts
# saved
# Game   600 |   293sec | MINI-MAX-5: 73% wins, 12% draws, 15% losts | RL-2X: 15% wins, 12% draws, 73% losts
# Game   610 |   297sec | MINI-MAX-5: 74% wins, 12% draws, 14% losts | RL-2X: 14% wins, 12% draws, 74% losts
# Game   620 |   301sec | MINI-MAX-5: 74% wins, 12% draws, 14% losts | RL-2X: 14% wins, 12% draws, 74% losts
# Game   630 |   305sec | MINI-MAX-5: 76% wins, 11% draws, 13% losts | RL-2X: 13% wins, 11% draws, 76% losts
# Game   640 |   311sec | MINI-MAX-5: 74% wins, 11% draws, 15% losts | RL-2X: 15% wins, 11% draws, 74% losts
# Game   650 |   316sec | MINI-MAX-5: 76% wins, 12% draws, 12% losts | RL-2X: 12% wins, 12% draws, 76% losts
# Game   660 |   320sec | MINI-MAX-5: 75% wins, 11% draws, 14% losts | RL-2X: 14% wins, 11% draws, 75% losts
# Game   670 |   325sec | MINI-MAX-5: 74% wins, 11% draws, 15% losts | RL-2X: 15% wins, 11% draws, 74% losts
# Game   680 |   329sec | MINI-MAX-5: 79% wins,  9% draws, 12% losts | RL-2X: 12% wins,  9% draws, 79% losts
# Game   690 |   333sec | MINI-MAX-5: 80% wins,  8% draws, 12% losts | RL-2X: 12% wins,  8% draws, 80% losts
# saved
# Game   700 |   338sec | MINI-MAX-5: 81% wins,  6% draws, 13% losts | RL-2X: 13% wins,  6% draws, 81% losts
# Game   710 |   343sec | MINI-MAX-5: 78% wins,  7% draws, 15% losts | RL-2X: 15% wins,  7% draws, 78% losts
# Game   720 |   347sec | MINI-MAX-5: 80% wins,  6% draws, 14% losts | RL-2X: 14% wins,  6% draws, 80% losts
# Game   730 |   352sec | MINI-MAX-5: 78% wins, 10% draws, 12% losts | RL-2X: 12% wins, 10% draws, 78% losts
# Game   740 |   356sec | MINI-MAX-5: 82% wins,  8% draws, 10% losts | RL-2X: 10% wins,  8% draws, 82% losts
# Game   750 |   361sec | MINI-MAX-5: 80% wins,  9% draws, 11% losts | RL-2X: 11% wins,  9% draws, 80% losts
# Game   760 |   365sec | MINI-MAX-5: 81% wins,  9% draws, 10% losts | RL-2X: 10% wins,  9% draws, 81% losts
# Game   770 |   370sec | MINI-MAX-5: 81% wins,  9% draws, 10% losts | RL-2X: 10% wins,  9% draws, 81% losts
# Game   780 |   374sec | MINI-MAX-5: 76% wins, 13% draws, 11% losts | RL-2X: 11% wins, 13% draws, 76% losts
# Game   790 |   378sec | MINI-MAX-5: 73% wins, 14% draws, 13% losts | RL-2X: 13% wins, 14% draws, 73% losts
# saved
# Game   800 |   383sec | MINI-MAX-5: 73% wins, 16% draws, 11% losts | RL-2X: 11% wins, 16% draws, 73% losts
# Game   810 |   386sec | MINI-MAX-5: 77% wins, 14% draws,  9% losts | RL-2X:  9% wins, 14% draws, 77% losts
# Game   820 |   391sec | MINI-MAX-5: 73% wins, 16% draws, 11% losts | RL-2X: 11% wins, 16% draws, 73% losts
# Game   830 |   395sec | MINI-MAX-5: 73% wins, 15% draws, 12% losts | RL-2X: 12% wins, 15% draws, 73% losts
# Game   840 |   400sec | MINI-MAX-5: 68% wins, 18% draws, 14% losts | RL-2X: 14% wins, 18% draws, 68% losts
# Game   850 |   404sec | MINI-MAX-5: 67% wins, 17% draws, 16% losts | RL-2X: 16% wins, 17% draws, 67% losts
# Game   860 |   408sec | MINI-MAX-5: 67% wins, 17% draws, 16% losts | RL-2X: 16% wins, 17% draws, 67% losts
# Game   870 |   413sec | MINI-MAX-5: 68% wins, 18% draws, 14% losts | RL-2X: 14% wins, 18% draws, 68% losts
# Game   880 |   417sec | MINI-MAX-5: 69% wins, 17% draws, 14% losts | RL-2X: 14% wins, 17% draws, 69% losts
# Game   890 |   421sec | MINI-MAX-5: 69% wins, 17% draws, 14% losts | RL-2X: 14% wins, 17% draws, 69% losts
# saved
# Game   900 |   425sec | MINI-MAX-5: 69% wins, 16% draws, 15% losts | RL-2X: 15% wins, 16% draws, 69% losts
# Game   910 |   429sec | MINI-MAX-5: 67% wins, 17% draws, 16% losts | RL-2X: 16% wins, 17% draws, 67% losts
# Game   920 |   434sec | MINI-MAX-5: 66% wins, 19% draws, 15% losts | RL-2X: 15% wins, 19% draws, 66% losts
# Game   930 |   438sec | MINI-MAX-5: 67% wins, 19% draws, 14% losts | RL-2X: 14% wins, 19% draws, 67% losts
# Game   940 |   443sec | MINI-MAX-5: 68% wins, 18% draws, 14% losts | RL-2X: 14% wins, 18% draws, 68% losts
# Game   950 |   447sec | MINI-MAX-5: 69% wins, 18% draws, 13% losts | RL-2X: 13% wins, 18% draws, 69% losts
# Game   960 |   451sec | MINI-MAX-5: 68% wins, 19% draws, 13% losts | RL-2X: 13% wins, 19% draws, 68% losts
# Game   970 |   455sec | MINI-MAX-5: 70% wins, 17% draws, 13% losts | RL-2X: 13% wins, 17% draws, 70% losts
# Game   980 |   459sec | MINI-MAX-5: 72% wins, 14% draws, 14% losts | RL-2X: 14% wins, 14% draws, 72% losts
# Game   990 |   464sec | MINI-MAX-5: 73% wins, 13% draws, 14% losts | RL-2X: 14% wins, 13% draws, 73% losts
# saved
# Game  1000 |   468sec | MINI-MAX-5: 70% wins, 15% draws, 15% losts | RL-2X: 15% wins, 15% draws, 70% losts
# Game  1010 |   473sec | MINI-MAX-5: 69% wins, 16% draws, 15% losts | RL-2X: 15% wins, 16% draws, 69% losts
# Game  1020 |   477sec | MINI-MAX-5: 73% wins, 12% draws, 15% losts | RL-2X: 15% wins, 12% draws, 73% losts
# Game  1030 |   481sec | MINI-MAX-5: 71% wins, 13% draws, 16% losts | RL-2X: 16% wins, 13% draws, 71% losts
# Game  1040 |   486sec | MINI-MAX-5: 71% wins, 14% draws, 15% losts | RL-2X: 15% wins, 14% draws, 71% losts
# Game  1050 |   490sec | MINI-MAX-5: 69% wins, 16% draws, 15% losts | RL-2X: 15% wins, 16% draws, 69% losts
# Game  1060 |   494sec | MINI-MAX-5: 66% wins, 18% draws, 16% losts | RL-2X: 16% wins, 18% draws, 66% losts
# Game  1070 |   498sec | MINI-MAX-5: 63% wins, 19% draws, 18% losts | RL-2X: 18% wins, 19% draws, 63% losts
# Game  1080 |   503sec | MINI-MAX-5: 61% wins, 21% draws, 18% losts | RL-2X: 18% wins, 21% draws, 61% losts
# Game  1090 |   507sec | MINI-MAX-5: 62% wins, 22% draws, 16% losts | RL-2X: 16% wins, 22% draws, 62% losts
# saved
# Game  1100 |   512sec | MINI-MAX-5: 60% wins, 20% draws, 20% losts | RL-2X: 20% wins, 20% draws, 60% losts
# Game  1110 |   516sec | MINI-MAX-5: 61% wins, 19% draws, 20% losts | RL-2X: 20% wins, 19% draws, 61% losts
# Game  1120 |   520sec | MINI-MAX-5: 62% wins, 19% draws, 19% losts | RL-2X: 19% wins, 19% draws, 62% losts
# Game  1130 |   524sec | MINI-MAX-5: 67% wins, 15% draws, 18% losts | RL-2X: 18% wins, 15% draws, 67% losts
# Game  1140 |   529sec | MINI-MAX-5: 71% wins, 13% draws, 16% losts | RL-2X: 16% wins, 13% draws, 71% losts
# Game  1150 |   533sec | MINI-MAX-5: 73% wins, 11% draws, 16% losts | RL-2X: 16% wins, 11% draws, 73% losts
# Game  1160 |   537sec | MINI-MAX-5: 77% wins,  9% draws, 14% losts | RL-2X: 14% wins,  9% draws, 77% losts
# Game  1170 |   541sec | MINI-MAX-5: 76% wins, 10% draws, 14% losts | RL-2X: 14% wins, 10% draws, 76% losts
# Game  1180 |   545sec | MINI-MAX-5: 76% wins, 10% draws, 14% losts | RL-2X: 14% wins, 10% draws, 76% losts
# Game  1190 |   549sec | MINI-MAX-5: 75% wins, 10% draws, 15% losts | RL-2X: 15% wins, 10% draws, 75% losts
# saved
# Game  1200 |   554sec | MINI-MAX-5: 79% wins, 10% draws, 11% losts | RL-2X: 11% wins, 10% draws, 79% losts
# Game  1210 |   557sec | MINI-MAX-5: 81% wins, 10% draws,  9% losts | RL-2X:  9% wins, 10% draws, 81% losts
# Game  1220 |   561sec | MINI-MAX-5: 78% wins, 11% draws, 11% losts | RL-2X: 11% wins, 11% draws, 78% losts
# Game  1230 |   565sec | MINI-MAX-5: 75% wins, 13% draws, 12% losts | RL-2X: 12% wins, 13% draws, 75% losts
# Game  1240 |   569sec | MINI-MAX-5: 76% wins, 12% draws, 12% losts | RL-2X: 12% wins, 12% draws, 76% losts
# Game  1250 |   573sec | MINI-MAX-5: 76% wins, 13% draws, 11% losts | RL-2X: 11% wins, 13% draws, 76% losts
# Game  1260 |   578sec | MINI-MAX-5: 76% wins, 12% draws, 12% losts | RL-2X: 12% wins, 12% draws, 76% losts
# Game  1270 |   584sec | MINI-MAX-5: 75% wins, 13% draws, 12% losts | RL-2X: 12% wins, 13% draws, 75% losts
# Game  1280 |   588sec | MINI-MAX-5: 74% wins, 14% draws, 12% losts | RL-2X: 12% wins, 14% draws, 74% losts
# Game  1290 |   592sec | MINI-MAX-5: 73% wins, 15% draws, 12% losts | RL-2X: 12% wins, 15% draws, 73% losts
# saved
# Game  1300 |   597sec | MINI-MAX-5: 74% wins, 16% draws, 10% losts | RL-2X: 10% wins, 16% draws, 74% losts
# Game  1310 |   601sec | MINI-MAX-5: 73% wins, 15% draws, 12% losts | RL-2X: 12% wins, 15% draws, 73% losts
# Game  1320 |   605sec | MINI-MAX-5: 76% wins, 14% draws, 10% losts | RL-2X: 10% wins, 14% draws, 76% losts
# Game  1330 |   609sec | MINI-MAX-5: 76% wins, 14% draws, 10% losts | RL-2X: 10% wins, 14% draws, 76% losts
# Game  1340 |   613sec | MINI-MAX-5: 73% wins, 15% draws, 12% losts | RL-2X: 12% wins, 15% draws, 73% losts
# Game  1350 |   617sec | MINI-MAX-5: 75% wins, 14% draws, 11% losts | RL-2X: 11% wins, 14% draws, 75% losts
# Game  1360 |   622sec | MINI-MAX-5: 74% wins, 16% draws, 10% losts | RL-2X: 10% wins, 16% draws, 74% losts
# Game  1370 |   626sec | MINI-MAX-5: 75% wins, 16% draws,  9% losts | RL-2X:  9% wins, 16% draws, 75% losts
# Game  1380 |   630sec | MINI-MAX-5: 79% wins, 14% draws,  7% losts | RL-2X:  7% wins, 14% draws, 79% losts
# Game  1390 |   634sec | MINI-MAX-5: 79% wins, 14% draws,  7% losts | RL-2X:  7% wins, 14% draws, 79% losts
# saved
# Game  1400 |   638sec | MINI-MAX-5: 81% wins, 12% draws,  7% losts | RL-2X:  7% wins, 12% draws, 81% losts
# Game  1410 |   643sec | MINI-MAX-5: 78% wins, 13% draws,  9% losts | RL-2X:  9% wins, 13% draws, 78% losts
# Game  1420 |   647sec | MINI-MAX-5: 74% wins, 15% draws, 11% losts | RL-2X: 11% wins, 15% draws, 74% losts
# Game  1430 |   651sec | MINI-MAX-5: 74% wins, 14% draws, 12% losts | RL-2X: 12% wins, 14% draws, 74% losts
# Game  1440 |   655sec | MINI-MAX-5: 76% wins, 14% draws, 10% losts | RL-2X: 10% wins, 14% draws, 76% losts
# Game  1450 |   659sec | MINI-MAX-5: 74% wins, 14% draws, 12% losts | RL-2X: 12% wins, 14% draws, 74% losts
# Game  1460 |   663sec | MINI-MAX-5: 74% wins, 12% draws, 14% losts | RL-2X: 14% wins, 12% draws, 74% losts
# Game  1470 |   668sec | MINI-MAX-5: 76% wins, 10% draws, 14% losts | RL-2X: 14% wins, 10% draws, 76% losts
# Game  1480 |   672sec | MINI-MAX-5: 75% wins, 10% draws, 15% losts | RL-2X: 15% wins, 10% draws, 75% losts
# Game  1490 |   677sec | MINI-MAX-5: 73% wins, 11% draws, 16% losts | RL-2X: 16% wins, 11% draws, 73% losts
# saved
# Game  1500 |   680sec | MINI-MAX-5: 72% wins, 12% draws, 16% losts | RL-2X: 16% wins, 12% draws, 72% losts
# Game  1510 |   685sec | MINI-MAX-5: 74% wins, 12% draws, 14% losts | RL-2X: 14% wins, 12% draws, 74% losts
# Game  1520 |   689sec | MINI-MAX-5: 76% wins, 10% draws, 14% losts | RL-2X: 14% wins, 10% draws, 76% losts
# Game  1530 |   693sec | MINI-MAX-5: 73% wins, 10% draws, 17% losts | RL-2X: 17% wins, 10% draws, 73% losts
# Game  1540 |   698sec | MINI-MAX-5: 68% wins, 12% draws, 20% losts | RL-2X: 20% wins, 12% draws, 68% losts
# Game  1550 |   702sec | MINI-MAX-5: 68% wins, 13% draws, 19% losts | RL-2X: 19% wins, 13% draws, 68% losts
# Game  1560 |   706sec | MINI-MAX-5: 66% wins, 16% draws, 18% losts | RL-2X: 18% wins, 16% draws, 66% losts
# Game  1570 |   710sec | MINI-MAX-5: 63% wins, 19% draws, 18% losts | RL-2X: 18% wins, 19% draws, 63% losts
# Game  1580 |   714sec | MINI-MAX-5: 61% wins, 20% draws, 19% losts | RL-2X: 19% wins, 20% draws, 61% losts
# Game  1590 |   718sec | MINI-MAX-5: 63% wins, 17% draws, 20% losts | RL-2X: 20% wins, 17% draws, 63% losts
# saved
# Game  1600 |   723sec | MINI-MAX-5: 61% wins, 18% draws, 21% losts | RL-2X: 21% wins, 18% draws, 61% losts
# Game  1610 |   727sec | MINI-MAX-5: 60% wins, 18% draws, 22% losts | RL-2X: 22% wins, 18% draws, 60% losts
# Game  1620 |   731sec | MINI-MAX-5: 58% wins, 22% draws, 20% losts | RL-2X: 20% wins, 22% draws, 58% losts
# Game  1630 |   735sec | MINI-MAX-5: 61% wins, 22% draws, 17% losts | RL-2X: 17% wins, 22% draws, 61% losts
# Game  1640 |   739sec | MINI-MAX-5: 66% wins, 20% draws, 14% losts | RL-2X: 14% wins, 20% draws, 66% losts
# Game  1650 |   744sec | MINI-MAX-5: 65% wins, 19% draws, 16% losts | RL-2X: 16% wins, 19% draws, 65% losts
# Game  1660 |   748sec | MINI-MAX-5: 65% wins, 19% draws, 16% losts | RL-2X: 16% wins, 19% draws, 65% losts
# Game  1670 |   752sec | MINI-MAX-5: 68% wins, 16% draws, 16% losts | RL-2X: 16% wins, 16% draws, 68% losts
# Game  1680 |   756sec | MINI-MAX-5: 65% wins, 16% draws, 19% losts | RL-2X: 19% wins, 16% draws, 65% losts
# Game  1690 |   760sec | MINI-MAX-5: 65% wins, 18% draws, 17% losts | RL-2X: 17% wins, 18% draws, 65% losts
# saved
# Game  1700 |   764sec | MINI-MAX-5: 65% wins, 17% draws, 18% losts | RL-2X: 18% wins, 17% draws, 65% losts
# Game  1710 |   768sec | MINI-MAX-5: 66% wins, 19% draws, 15% losts | RL-2X: 15% wins, 19% draws, 66% losts
# Game  1720 |   773sec | MINI-MAX-5: 67% wins, 17% draws, 16% losts | RL-2X: 16% wins, 17% draws, 67% losts
# Game  1730 |   777sec | MINI-MAX-5: 68% wins, 18% draws, 14% losts | RL-2X: 14% wins, 18% draws, 68% losts
# Game  1740 |   781sec | MINI-MAX-5: 67% wins, 18% draws, 15% losts | RL-2X: 15% wins, 18% draws, 67% losts
# Game  1750 |   785sec | MINI-MAX-5: 66% wins, 19% draws, 15% losts | RL-2X: 15% wins, 19% draws, 66% losts
# Game  1760 |   790sec | MINI-MAX-5: 66% wins, 18% draws, 16% losts | RL-2X: 16% wins, 18% draws, 66% losts
# Game  1770 |   794sec | MINI-MAX-5: 68% wins, 17% draws, 15% losts | RL-2X: 15% wins, 17% draws, 68% losts
# Game  1780 |   798sec | MINI-MAX-5: 74% wins, 15% draws, 11% losts | RL-2X: 11% wins, 15% draws, 74% losts
# Game  1790 |   803sec | MINI-MAX-5: 72% wins, 17% draws, 11% losts | RL-2X: 11% wins, 17% draws, 72% losts
# saved
# Game  1800 |   807sec | MINI-MAX-5: 71% wins, 19% draws, 10% losts | RL-2X: 10% wins, 19% draws, 71% losts
# Game  1810 |   811sec | MINI-MAX-5: 72% wins, 16% draws, 12% losts | RL-2X: 12% wins, 16% draws, 72% losts
# Game  1820 |   816sec | MINI-MAX-5: 71% wins, 17% draws, 12% losts | RL-2X: 12% wins, 17% draws, 71% losts
# Game  1830 |   821sec | MINI-MAX-5: 69% wins, 17% draws, 14% losts | RL-2X: 14% wins, 17% draws, 69% losts
# Game  1840 |   825sec | MINI-MAX-5: 70% wins, 17% draws, 13% losts | RL-2X: 13% wins, 17% draws, 70% losts
# Game  1850 |   830sec | MINI-MAX-5: 70% wins, 18% draws, 12% losts | RL-2X: 12% wins, 18% draws, 70% losts
# Game  1860 |   835sec | MINI-MAX-5: 72% wins, 17% draws, 11% losts | RL-2X: 11% wins, 17% draws, 72% losts
# Game  1870 |   839sec | MINI-MAX-5: 67% wins, 20% draws, 13% losts | RL-2X: 13% wins, 20% draws, 67% losts
# Game  1880 |   843sec | MINI-MAX-5: 67% wins, 21% draws, 12% losts | RL-2X: 12% wins, 21% draws, 67% losts
# Game  1890 |   848sec | MINI-MAX-5: 67% wins, 20% draws, 13% losts | RL-2X: 13% wins, 20% draws, 67% losts
# saved
# Game  1900 |   852sec | MINI-MAX-5: 68% wins, 19% draws, 13% losts | RL-2X: 13% wins, 19% draws, 68% losts
# Game  1910 |   856sec | MINI-MAX-5: 68% wins, 20% draws, 12% losts | RL-2X: 12% wins, 20% draws, 68% losts
# Game  1920 |   860sec | MINI-MAX-5: 71% wins, 18% draws, 11% losts | RL-2X: 11% wins, 18% draws, 71% losts
# Game  1930 |   864sec | MINI-MAX-5: 73% wins, 18% draws,  9% losts | RL-2X:  9% wins, 18% draws, 73% losts
# Game  1940 |   868sec | MINI-MAX-5: 72% wins, 18% draws, 10% losts | RL-2X: 10% wins, 18% draws, 72% losts
# Game  1950 |   872sec | MINI-MAX-5: 74% wins, 16% draws, 10% losts | RL-2X: 10% wins, 16% draws, 74% losts
# Game  1960 |   877sec | MINI-MAX-5: 73% wins, 16% draws, 11% losts | RL-2X: 11% wins, 16% draws, 73% losts
# Game  1970 |   880sec | MINI-MAX-5: 77% wins, 14% draws,  9% losts | RL-2X:  9% wins, 14% draws, 77% losts
# Game  1980 |   884sec | MINI-MAX-5: 76% wins, 15% draws,  9% losts | RL-2X:  9% wins, 15% draws, 76% losts
# Game  1990 |   888sec | MINI-MAX-5: 78% wins, 14% draws,  8% losts | RL-2X:  8% wins, 14% draws, 78% losts
# saved
# Game  2000 |   892sec | MINI-MAX-5: 80% wins, 12% draws,  8% losts | RL-2X:  8% wins, 12% draws, 80% losts
# Game  2010 |   896sec | MINI-MAX-5: 81% wins, 11% draws,  8% losts | RL-2X:  8% wins, 11% draws, 81% losts
# Game  2020 |   900sec | MINI-MAX-5: 80% wins, 12% draws,  8% losts | RL-2X:  8% wins, 12% draws, 80% losts
# Game  2030 |   905sec | MINI-MAX-5: 80% wins, 12% draws,  8% losts | RL-2X:  8% wins, 12% draws, 80% losts
# Game  2040 |   909sec | MINI-MAX-5: 80% wins, 11% draws,  9% losts | RL-2X:  9% wins, 11% draws, 80% losts
# Game  2050 |   913sec | MINI-MAX-5: 82% wins, 10% draws,  8% losts | RL-2X:  8% wins, 10% draws, 82% losts
# Game  2060 |   917sec | MINI-MAX-5: 85% wins,  9% draws,  6% losts | RL-2X:  6% wins,  9% draws, 85% losts
# Game  2070 |   921sec | MINI-MAX-5: 83% wins, 11% draws,  6% losts | RL-2X:  6% wins, 11% draws, 83% losts
# Game  2080 |   925sec | MINI-MAX-5: 83% wins, 11% draws,  6% losts | RL-2X:  6% wins, 11% draws, 83% losts
# Game  2090 |   929sec | MINI-MAX-5: 83% wins, 10% draws,  7% losts | RL-2X:  7% wins, 10% draws, 83% losts
# saved
# Game  2100 |   933sec | MINI-MAX-5: 81% wins, 12% draws,  7% losts | RL-2X:  7% wins, 12% draws, 81% losts
# Game  2110 |   937sec | MINI-MAX-5: 79% wins, 12% draws,  9% losts | RL-2X:  9% wins, 12% draws, 79% losts
# Game  2120 |   942sec | MINI-MAX-5: 78% wins, 10% draws, 12% losts | RL-2X: 12% wins, 10% draws, 78% losts
# Game  2130 |   947sec | MINI-MAX-5: 75% wins, 12% draws, 13% losts | RL-2X: 13% wins, 12% draws, 75% losts
# Game  2140 |   951sec | MINI-MAX-5: 75% wins, 13% draws, 12% losts | RL-2X: 12% wins, 13% draws, 75% losts
# Game  2150 |   955sec | MINI-MAX-5: 70% wins, 15% draws, 15% losts | RL-2X: 15% wins, 15% draws, 70% losts
# Game  2160 |   960sec | MINI-MAX-5: 68% wins, 15% draws, 17% losts | RL-2X: 17% wins, 15% draws, 68% losts
# Game  2170 |   964sec | MINI-MAX-5: 70% wins, 12% draws, 18% losts | RL-2X: 18% wins, 12% draws, 70% losts
# Game  2180 |   968sec | MINI-MAX-5: 70% wins, 11% draws, 19% losts | RL-2X: 19% wins, 11% draws, 70% losts
# Game  2190 |   972sec | MINI-MAX-5: 73% wins, 10% draws, 17% losts | RL-2X: 17% wins, 10% draws, 73% losts
# saved
# Game  2200 |   976sec | MINI-MAX-5: 75% wins,  9% draws, 16% losts | RL-2X: 16% wins,  9% draws, 75% losts
# Game  2210 |   980sec | MINI-MAX-5: 76% wins, 10% draws, 14% losts | RL-2X: 14% wins, 10% draws, 76% losts
# Game  2220 |   984sec | MINI-MAX-5: 78% wins, 11% draws, 11% losts | RL-2X: 11% wins, 11% draws, 78% losts
# Game  2230 |   987sec | MINI-MAX-5: 80% wins,  9% draws, 11% losts | RL-2X: 11% wins,  9% draws, 80% losts
# Game  2240 |   991sec | MINI-MAX-5: 80% wins, 10% draws, 10% losts | RL-2X: 10% wins, 10% draws, 80% losts
# Game  2250 |   995sec | MINI-MAX-5: 84% wins,  9% draws,  7% losts | RL-2X:  7% wins,  9% draws, 84% losts
# Game  2260 |  1000sec | MINI-MAX-5: 82% wins, 12% draws,  6% losts | RL-2X:  6% wins, 12% draws, 82% losts
# Game  2270 |  1004sec | MINI-MAX-5: 78% wins, 14% draws,  8% losts | RL-2X:  8% wins, 14% draws, 78% losts
# Game  2280 |  1008sec | MINI-MAX-5: 78% wins, 14% draws,  8% losts | RL-2X:  8% wins, 14% draws, 78% losts
# Game  2290 |  1012sec | MINI-MAX-5: 73% wins, 17% draws, 10% losts | RL-2X: 10% wins, 17% draws, 73% losts
# saved
# Game  2300 |  1016sec | MINI-MAX-5: 71% wins, 16% draws, 13% losts | RL-2X: 13% wins, 16% draws, 71% losts
# Game  2310 |  1020sec | MINI-MAX-5: 73% wins, 15% draws, 12% losts | RL-2X: 12% wins, 15% draws, 73% losts
# Game  2320 |  1025sec | MINI-MAX-5: 72% wins, 14% draws, 14% losts | RL-2X: 14% wins, 14% draws, 72% losts
# Game  2330 |  1029sec | MINI-MAX-5: 73% wins, 13% draws, 14% losts | RL-2X: 14% wins, 13% draws, 73% losts
# Game  2340 |  1033sec | MINI-MAX-5: 73% wins, 13% draws, 14% losts | RL-2X: 14% wins, 13% draws, 73% losts
# Game  2350 |  1037sec | MINI-MAX-5: 74% wins, 12% draws, 14% losts | RL-2X: 14% wins, 12% draws, 74% losts
# Game  2360 |  1041sec | MINI-MAX-5: 77% wins,  9% draws, 14% losts | RL-2X: 14% wins,  9% draws, 77% losts
# Game  2370 |  1045sec | MINI-MAX-5: 78% wins,  8% draws, 14% losts | RL-2X: 14% wins,  8% draws, 78% losts
# Game  2380 |  1049sec | MINI-MAX-5: 77% wins,  9% draws, 14% losts | RL-2X: 14% wins,  9% draws, 77% losts
# Game  2390 |  1054sec | MINI-MAX-5: 76% wins, 10% draws, 14% losts | RL-2X: 14% wins, 10% draws, 76% losts
# saved
# Game  2400 |  1057sec | MINI-MAX-5: 79% wins, 10% draws, 11% losts | RL-2X: 11% wins, 10% draws, 79% losts
# Game  2410 |  1061sec | MINI-MAX-5: 77% wins, 11% draws, 12% losts | RL-2X: 12% wins, 11% draws, 77% losts
# Game  2420 |  1065sec | MINI-MAX-5: 78% wins, 12% draws, 10% losts | RL-2X: 10% wins, 12% draws, 78% losts
# Game  2430 |  1069sec | MINI-MAX-5: 78% wins, 12% draws, 10% losts | RL-2X: 10% wins, 12% draws, 78% losts
# Game  2440 |  1074sec | MINI-MAX-5: 74% wins, 14% draws, 12% losts | RL-2X: 12% wins, 14% draws, 74% losts
# Game  2450 |  1078sec | MINI-MAX-5: 73% wins, 14% draws, 13% losts | RL-2X: 13% wins, 14% draws, 73% losts
# Game  2460 |  1082sec | MINI-MAX-5: 72% wins, 15% draws, 13% losts | RL-2X: 13% wins, 15% draws, 72% losts
# Game  2470 |  1086sec | MINI-MAX-5: 72% wins, 17% draws, 11% losts | RL-2X: 11% wins, 17% draws, 72% losts
# Game  2480 |  1090sec | MINI-MAX-5: 74% wins, 15% draws, 11% losts | RL-2X: 11% wins, 15% draws, 74% losts
# Game  2490 |  1093sec | MINI-MAX-5: 79% wins, 11% draws, 10% losts | RL-2X: 10% wins, 11% draws, 79% losts
# saved
# Game  2500 |  1097sec | MINI-MAX-5: 77% wins, 13% draws, 10% losts | RL-2X: 10% wins, 13% draws, 77% losts
# Game  2510 |  1102sec | MINI-MAX-5: 74% wins, 13% draws, 13% losts | RL-2X: 13% wins, 13% draws, 74% losts
# Game  2520 |  1106sec | MINI-MAX-5: 71% wins, 15% draws, 14% losts | RL-2X: 14% wins, 15% draws, 71% losts
# Game  2530 |  1110sec | MINI-MAX-5: 68% wins, 15% draws, 17% losts | RL-2X: 17% wins, 15% draws, 68% losts
# Game  2540 |  1114sec | MINI-MAX-5: 72% wins, 12% draws, 16% losts | RL-2X: 16% wins, 12% draws, 72% losts
# Game  2550 |  1119sec | MINI-MAX-5: 71% wins, 14% draws, 15% losts | RL-2X: 15% wins, 14% draws, 71% losts
# Game  2560 |  1123sec | MINI-MAX-5: 69% wins, 15% draws, 16% losts | RL-2X: 16% wins, 15% draws, 69% losts
# Game  2570 |  1127sec | MINI-MAX-5: 70% wins, 13% draws, 17% losts | RL-2X: 17% wins, 13% draws, 70% losts
# Game  2580 |  1131sec | MINI-MAX-5: 69% wins, 15% draws, 16% losts | RL-2X: 16% wins, 15% draws, 69% losts
# Game  2590 |  1136sec | MINI-MAX-5: 63% wins, 19% draws, 18% losts | RL-2X: 18% wins, 19% draws, 63% losts
# saved
# Game  2600 |  1141sec | MINI-MAX-5: 60% wins, 21% draws, 19% losts | RL-2X: 19% wins, 21% draws, 60% losts
# Game  2610 |  1145sec | MINI-MAX-5: 63% wins, 21% draws, 16% losts | RL-2X: 16% wins, 21% draws, 63% losts
# Game  2620 |  1149sec | MINI-MAX-5: 63% wins, 21% draws, 16% losts | RL-2X: 16% wins, 21% draws, 63% losts
# Game  2630 |  1153sec | MINI-MAX-5: 65% wins, 21% draws, 14% losts | RL-2X: 14% wins, 21% draws, 65% losts
# Game  2640 |  1157sec | MINI-MAX-5: 63% wins, 22% draws, 15% losts | RL-2X: 15% wins, 22% draws, 63% losts
# Game  2650 |  1161sec | MINI-MAX-5: 63% wins, 22% draws, 15% losts | RL-2X: 15% wins, 22% draws, 63% losts
# Game  2660 |  1165sec | MINI-MAX-5: 63% wins, 22% draws, 15% losts | RL-2X: 15% wins, 22% draws, 63% losts
# Game  2670 |  1169sec | MINI-MAX-5: 65% wins, 22% draws, 13% losts | RL-2X: 13% wins, 22% draws, 65% losts
# Game  2680 |  1172sec | MINI-MAX-5: 66% wins, 20% draws, 14% losts | RL-2X: 14% wins, 20% draws, 66% losts
# Game  2690 |  1176sec | MINI-MAX-5: 72% wins, 16% draws, 12% losts | RL-2X: 12% wins, 16% draws, 72% losts
# saved
# Game  2700 |  1180sec | MINI-MAX-5: 75% wins, 13% draws, 12% losts | RL-2X: 12% wins, 13% draws, 75% losts
# Game  2710 |  1184sec | MINI-MAX-5: 73% wins, 13% draws, 14% losts | RL-2X: 14% wins, 13% draws, 73% losts
# Game  2720 |  1188sec | MINI-MAX-5: 74% wins, 11% draws, 15% losts | RL-2X: 15% wins, 11% draws, 74% losts
# Game  2730 |  1192sec | MINI-MAX-5: 73% wins, 12% draws, 15% losts | RL-2X: 15% wins, 12% draws, 73% losts
# Game  2740 |  1195sec | MINI-MAX-5: 75% wins, 10% draws, 15% losts | RL-2X: 15% wins, 10% draws, 75% losts
# Game  2750 |  1199sec | MINI-MAX-5: 78% wins,  8% draws, 14% losts | RL-2X: 14% wins,  8% draws, 78% losts
# Game  2760 |  1203sec | MINI-MAX-5: 80% wins,  6% draws, 14% losts | RL-2X: 14% wins,  6% draws, 80% losts
# Game  2770 |  1206sec | MINI-MAX-5: 80% wins,  6% draws, 14% losts | RL-2X: 14% wins,  6% draws, 80% losts
# Game  2780 |  1210sec | MINI-MAX-5: 77% wins,  9% draws, 14% losts | RL-2X: 14% wins,  9% draws, 77% losts
# Game  2790 |  1214sec | MINI-MAX-5: 76% wins, 10% draws, 14% losts | RL-2X: 14% wins, 10% draws, 76% losts
# saved
# Game  2800 |  1218sec | MINI-MAX-5: 76% wins, 11% draws, 13% losts | RL-2X: 13% wins, 11% draws, 76% losts
# Game  2810 |  1221sec | MINI-MAX-5: 79% wins, 11% draws, 10% losts | RL-2X: 10% wins, 11% draws, 79% losts
# Game  2820 |  1224sec | MINI-MAX-5: 82% wins, 10% draws,  8% losts | RL-2X:  8% wins, 10% draws, 82% losts
# Game  2830 |  1230sec | MINI-MAX-5: 82% wins, 10% draws,  8% losts | RL-2X:  8% wins, 10% draws, 82% losts
# Game  2840 |  1236sec | MINI-MAX-5: 83% wins, 11% draws,  6% losts | RL-2X:  6% wins, 11% draws, 83% losts
# Game  2850 |  1241sec | MINI-MAX-5: 79% wins, 13% draws,  8% losts | RL-2X:  8% wins, 13% draws, 79% losts
# Game  2860 |  1246sec | MINI-MAX-5: 79% wins, 14% draws,  7% losts | RL-2X:  7% wins, 14% draws, 79% losts
# Game  2870 |  1251sec | MINI-MAX-5: 77% wins, 15% draws,  8% losts | RL-2X:  8% wins, 15% draws, 77% losts
# Game  2880 |  1256sec | MINI-MAX-5: 78% wins, 15% draws,  7% losts | RL-2X:  7% wins, 15% draws, 78% losts
# Game  2890 |  1260sec | MINI-MAX-5: 77% wins, 15% draws,  8% losts | RL-2X:  8% wins, 15% draws, 77% losts
# saved
# Game  2900 |  1265sec | MINI-MAX-5: 77% wins, 13% draws, 10% losts | RL-2X: 10% wins, 13% draws, 77% losts
# Game  2910 |  1270sec | MINI-MAX-5: 76% wins, 13% draws, 11% losts | RL-2X: 11% wins, 13% draws, 76% losts
# Game  2920 |  1275sec | MINI-MAX-5: 71% wins, 15% draws, 14% losts | RL-2X: 14% wins, 15% draws, 71% losts
# Game  2930 |  1287sec | MINI-MAX-5: 71% wins, 14% draws, 15% losts | RL-2X: 15% wins, 14% draws, 71% losts
# Game  2940 |  1299sec | MINI-MAX-5: 70% wins, 14% draws, 16% losts | RL-2X: 16% wins, 14% draws, 70% losts
# Game  2950 |  1311sec | MINI-MAX-5: 71% wins, 15% draws, 14% losts | RL-2X: 14% wins, 15% draws, 71% losts
# Game  2960 |  1325sec | MINI-MAX-5: 69% wins, 16% draws, 15% losts | RL-2X: 15% wins, 16% draws, 69% losts
# Game  2970 |  1337sec | MINI-MAX-5: 69% wins, 17% draws, 14% losts | RL-2X: 14% wins, 17% draws, 69% losts
# Game  2980 |  1349sec | MINI-MAX-5: 69% wins, 15% draws, 16% losts | RL-2X: 16% wins, 15% draws, 69% losts
# Game  2990 |  1361sec | MINI-MAX-5: 69% wins, 15% draws, 16% losts | RL-2X: 16% wins, 15% draws, 69% losts
# saved
# Game  3000 |  1373sec | MINI-MAX-5: 70% wins, 16% draws, 14% losts | RL-2X: 14% wins, 16% draws, 70% losts
# Game  3010 |  1386sec | MINI-MAX-5: 70% wins, 16% draws, 14% losts | RL-2X: 14% wins, 16% draws, 70% losts
# Game  3020 |  1397sec | MINI-MAX-5: 74% wins, 15% draws, 11% losts | RL-2X: 11% wins, 15% draws, 74% losts
# Game  3030 |  1406sec | MINI-MAX-5: 75% wins, 16% draws,  9% losts | RL-2X:  9% wins, 16% draws, 75% losts
# Game  3040 |  1412sec | MINI-MAX-5: 75% wins, 16% draws,  9% losts | RL-2X:  9% wins, 16% draws, 75% losts
# Game  3050 |  1416sec | MINI-MAX-5: 74% wins, 15% draws, 11% losts | RL-2X: 11% wins, 15% draws, 74% losts
# Game  3060 |  1420sec | MINI-MAX-5: 76% wins, 15% draws,  9% losts | RL-2X:  9% wins, 15% draws, 76% losts
# Game  3070 |  1424sec | MINI-MAX-5: 78% wins, 13% draws,  9% losts | RL-2X:  9% wins, 13% draws, 78% losts
# Game  3080 |  1428sec | MINI-MAX-5: 78% wins, 13% draws,  9% losts | RL-2X:  9% wins, 13% draws, 78% losts
# Game  3090 |  1432sec | MINI-MAX-5: 77% wins, 14% draws,  9% losts | RL-2X:  9% wins, 14% draws, 77% losts
# saved
# Game  3100 |  1436sec | MINI-MAX-5: 77% wins, 14% draws,  9% losts | RL-2X:  9% wins, 14% draws, 77% losts
# Game  3110 |  1440sec | MINI-MAX-5: 77% wins, 14% draws,  9% losts | RL-2X:  9% wins, 14% draws, 77% losts
# Game  3120 |  1444sec | MINI-MAX-5: 73% wins, 15% draws, 12% losts | RL-2X: 12% wins, 15% draws, 73% losts
# Game  3130 |  1449sec | MINI-MAX-5: 69% wins, 18% draws, 13% losts | RL-2X: 13% wins, 18% draws, 69% losts
# Game  3140 |  1453sec | MINI-MAX-5: 68% wins, 20% draws, 12% losts | RL-2X: 12% wins, 20% draws, 68% losts
# Game  3150 |  1458sec | MINI-MAX-5: 71% wins, 18% draws, 11% losts | RL-2X: 11% wins, 18% draws, 71% losts
# Game  3160 |  1462sec | MINI-MAX-5: 70% wins, 19% draws, 11% losts | RL-2X: 11% wins, 19% draws, 70% losts
# Game  3170 |  1466sec | MINI-MAX-5: 69% wins, 20% draws, 11% losts | RL-2X: 11% wins, 20% draws, 69% losts
# Game  3180 |  1470sec | MINI-MAX-5: 70% wins, 20% draws, 10% losts | RL-2X: 10% wins, 20% draws, 70% losts
# Game  3190 |  1475sec | MINI-MAX-5: 73% wins, 19% draws,  8% losts | RL-2X:  8% wins, 19% draws, 73% losts
# saved
# Game  3200 |  1479sec | MINI-MAX-5: 71% wins, 18% draws, 11% losts | RL-2X: 11% wins, 18% draws, 71% losts
# Game  3210 |  1485sec | MINI-MAX-5: 69% wins, 19% draws, 12% losts | RL-2X: 12% wins, 19% draws, 69% losts
# Game  3220 |  1489sec | MINI-MAX-5: 73% wins, 17% draws, 10% losts | RL-2X: 10% wins, 17% draws, 73% losts
# Game  3230 |  1494sec | MINI-MAX-5: 77% wins, 12% draws, 11% losts | RL-2X: 11% wins, 12% draws, 77% losts
# Game  3240 |  1498sec | MINI-MAX-5: 75% wins, 11% draws, 14% losts | RL-2X: 14% wins, 11% draws, 75% losts
# Game  3250 |  1503sec | MINI-MAX-5: 73% wins, 11% draws, 16% losts | RL-2X: 16% wins, 11% draws, 73% losts
# Game  3260 |  1507sec | MINI-MAX-5: 73% wins,  9% draws, 18% losts | RL-2X: 18% wins,  9% draws, 73% losts
# Game  3270 |  1511sec | MINI-MAX-5: 70% wins, 10% draws, 20% losts | RL-2X: 20% wins, 10% draws, 70% losts
# Game  3280 |  1516sec | MINI-MAX-5: 69% wins, 11% draws, 20% losts | RL-2X: 20% wins, 11% draws, 69% losts
# Game  3290 |  1520sec | MINI-MAX-5: 69% wins, 11% draws, 20% losts | RL-2X: 20% wins, 11% draws, 69% losts
# saved
# Game  3300 |  1524sec | MINI-MAX-5: 68% wins, 13% draws, 19% losts | RL-2X: 19% wins, 13% draws, 68% losts
# Game  3310 |  1528sec | MINI-MAX-5: 69% wins, 13% draws, 18% losts | RL-2X: 18% wins, 13% draws, 69% losts
# Game  3320 |  1532sec | MINI-MAX-5: 67% wins, 16% draws, 17% losts | RL-2X: 17% wins, 16% draws, 67% losts
