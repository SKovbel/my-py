# %%
import os
import json
import time
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import EarlyStopping, Callback

# %% [markdown]
# **MiniMax engine**

# %%
class TicTacToe:
    moves = []
    player = None
    game_status = None
    engine_X = None
    engine_0 = None
    RULES = [
        [0, 1, 2], [3, 4, 5], [6, 7, 8],  # horizontal
        [0, 3, 6], [1, 4, 7], [2, 5, 8],  # vertical
        [0, 4, 8], [2, 4, 6]  # diagonal
    ]

    def __init__(self):
        pass

    def new(self, engine_X, engine_0):
        self.player = 1
        self.moves = []
        self.game_status = None
        self.engine_X = engine_X
        self.engine_0 = engine_0

    # 1 if won <X>, -1 if won <0>, 0 if draw, None if game is not finished
    def status(self, board=None):
        if board is None:
            return self.game_status

        is_draw = True
        for rule in self.RULES:
            abs_sum = abs(board[rule[0]] + board[rule[1]] + board[rule[2]])
            if abs_sum == 3:
                return board[rule[0]]  # return player won (1, -1)
            if is_draw:
                sum_abs = abs(board[rule[0]]) + abs(board[rule[1]]) + abs(board[rule[2]])
                is_draw = False if abs_sum == sum_abs else is_draw
        return 0 if is_draw else None  # return draw or game is not finished

    def board(self, pos=None):
        board = 9 * [0.]
        pos = len(self.moves) if pos is None else pos
        last = pos if pos >= 0 else len(self.moves) + pos
        turn = 1
        for idx in self.moves[0:last]:
            board[idx] = float(turn)
            turn = -turn
        return board

    def timeseries(self):
        moves = 9 * [0.]
        time_series = [moves.copy()]
        turn = 1
        for move_idx in self.moves:
            moves[move_idx] = 1. if turn == 1 else -1.
            time_series.append(moves.copy())
            turn = -turn
        return time_series

    def is_tie(self, status=None):
        status = status if status else self.game_status
        return status is None

    def is_game_over(self, status=None):
        return not self.is_tie(status)

    def remove_illegal_moves(self, Y, moves = None):
        moves = moves if moves else self.moves
        for pos in moves:
            Y[pos] = -1
        return Y

    def auto_play(self, player_X, player_0):
        self.new(player_X, player_0)
        for i in range(0, 9):
            self.auto_move()
            self.engine_X.train(self)
            self.engine_0.train(self)
            if self.is_game_over():
                break

    def auto_move(self):
        if self.is_tie():  # game is not finished
            best_move = self.engine_X.move(self) if self.player == 1 else self.engine_0.move(self)
            if best_move in self.moves:
                print('!!!!!!!!!! Wrong move')
                exit(0)
            self.moves.append(best_move)
        # update status
        self.game_status = self.status(self.board())
        if self.is_tie():  # game is continue we change player, else left winner or last moved as is
            self.player = -self.player

    def print(self):
        board = self.board()
        print(board)
        print("\n", self.engine_X.code, self.engine_0.code)
        for r in range(0, 3):
            for c in range(0, 3):
                mark = ' '
                mark = 'X' if board[3*r + c] == 1 else mark
                mark = '0' if board[3 * r + c] == -1 else mark
                print(mark, end='')
            print()

# %%
class Stats:
    STEP = 10
    WINDOW = 100

    def __init__(self, engines):
        self.counter = 0
        self.start_time = int(time.time() * 1000)
        self.engines = engines
        self.statuses = []

    def add(self, game):
        self.counter += 1

        won = game.status()
        code_x = game.engine_X.code
        code_0 = game.engine_0.code

        stats = {
            code_x: {'g': 1, 'w': 0, 'd': 0, 'l': 0},
            code_0: {'g': 1, 'w': 0, 'd': 0, 'l': 0}
        }

        if won:
            win, lost = (code_x, code_0) if won == 1 else (code_0, code_x)
            stats[win]['w'] = 1
            stats[lost]['l'] = 1
        else:
            stats[code_x]['d'] = 1
            stats[code_0]['d'] = 1

        self.statuses.append(stats)
        self.pop()

        if self.counter == 1:
            self.header()
        if self.counter % self.STEP == 0:
            self.print()

    def pop(self):
        if len(self.statuses) > self.WINDOW:
            self.statuses.pop(0)

    def header(self):
        print(f"Stats config: STEP = {self.STEP}, WINDOW = {self.WINDOW}")

    def print(self):
        loop = int(time.time() * 1000)
        p = lambda x, c: round(100*x/c)
        print(f"Game {self.counter:>5} | {int((loop - self.start_time) / 1000):>5}sec", end=' | ')
        stats_str = []
        for item in self.engines:
            engine = item.code
            cnt = win = drw = lst = 0
            for row in self.statuses:
                if engine in row:
                    cnt += row[engine]['g']
                    win += row[engine]['w']
                    drw += row[engine]['d']
                    lst += row[engine]['l']
            stats_str.append(
                f"{engine.upper()}: {p(win,cnt):>2}% wins, {p(drw,cnt):>2}% draws, {p(lst,cnt):>2}% losts")
        print(' | '.join(stats_str))

# %%
class EngineMiniMax:
    INF = 1000

    def __init__(self, code='MinMax', max_depth=5):
        self.code = f"{code}-{max_depth}"
        self.max_depth = max_depth
        
    def move(self, game):
        best_moves = self.__minimax(game, game.board())
        moves = self.__legal_moves(best_moves)
        return moves.index(max(moves))

    def train(self, game):
        pass

    def __legal_moves(self, best_moves):
        y = 9 * [0]
        for move in best_moves:
            y[move] = 1 + random.uniform(-0.5, 0.5)
        y = game.remove_illegal_moves(y)
        #print('MM legal', y)
        return y

    def __minimax(self, game, board, turn=1, depth=0):
        if depth:
            status = game.status(board)
            if game.is_game_over(status):
                return status / depth   # win

            if depth >= self.max_depth:
                return 0

        best_score = -self.INF if turn > 0 else self.INF
        best_moves = []

        for i in range(len(board)):
            if board[i] != 0:  # skip zero squares
                continue
            # only 1 and -1
            board[i] = turn
            score = self.__minimax(game, board, -turn, depth + 1)
            if turn > 0 and score >= best_score:
                if best_score != score:
                    best_moves = []
                best_score = score
                if depth == 0:
                    best_moves.append(i)
            elif turn < 0 and score <= best_score:
                if best_score != score:
                    best_moves = []
                best_score = score
                if depth == 0:
                    best_moves.append(i)
            board[i] = 0

        return best_score if depth else best_moves

# %%
class EngineDenseRL2x:
    unique_ids = {}
    EPOCHS = 30
    SAVE_EACH_TRAINS = 100

    REWARD_LR = 0.2
    REWARD_ALP = 0.9
    REWARD_WIN = 1.00
    REWARD_DRW = 0.30
    REWARD_LST = 0.00

    def __init__(self, code='EngineDenseRL2x', unique=False):
        self.counter = 0
        self.code = code
        self.unique_ids = {} if unique else False
        self.model_file = f"../tmp/ttt/{self.code}.keras"
        self.extra_file = f"../tmp/ttt/{self.code}.extra.json"
        os.makedirs(os.path.dirname(self.model_file), exist_ok=True)
        self.__init_model()

    def __init_model(self):
        self.model = self.__load()
        if not self.model:
            self.model = Sequential([
                layers.ReLU(72, input_shape=(18,)),    #  2*9 as split X and 0 to separate cells
                #layers.Normalization(),
                layers.ReLU(72),
                layers.Dropout(0.2),
                layers.Normalization(),
                layers.Dense(9, activation='sigmoid')
            ])
            self.model.compile(optimizer='adam', loss='mse')   # binary_crossentropy

    def __save(self):
        if self.counter % self.SAVE_EACH_TRAINS == 0:
            self.model.save(self.model_file)
            extra = {'counter': self.counter}
            with open(self.extra_file, 'w') as extra_file:
                json.dump(extra, extra_file)
            print('saved')

    def __load(self):
        if os.path.exists(self.model_file):
            with open(self.extra_file, 'r') as extra_file:
                params = json.load(extra_file)
                self.counter = params['counter']
            print(f'loaded {self.code}, last game number is {self.counter}')
            return load_model(self.model_file)
        return False


    def __check_uniq(self, game):
        if self.unique_ids:
            game_id = ''.join(str(item) for item in game.moves)
            if game_id in self.unique_ids:
                return True
            self.unique_ids[game_id] = True
        return False

    def __board2x(self, game):
        board = game.board()
        board2x = 9 * [1, 0]
        # if empty cell then first is 1 to decrase count of 0 values. And 0 if cell is X moved
        for i in range(len(board)):
            if board[i] == 1:
                board2x[2 * i] = 0
            if board[i] == -1:
                board2x[2 * i + 1] = 1
        return board2x

    def __timeseries2x(self, game):
        board = game.board()
        series = 9 * [1, 0]
        timeseries2x = []
        for i in game.moves:
            if board[i] == 1:
                series[2 * i] = 0
            if board[i] == -1:
                series[2 * i + 1] = 1
            timeseries2x.append(series.copy())
        return timeseries2x

    def __legal_moves(self, game, Y):
        for i in range(len(Y)):
            Y[i] = game.remove_illegal_moves(Y[i], game.moves[:i])
        #print('NN legal', Y)
        return Y

    def move(self, game):
        X = [self.__board2x(game)]
        Y = self.model.predict(X, verbose=0)
        y = game.remove_illegal_moves(Y[0])
        return np.argmax(Y[0])

    def train(self, game):
        # this engine trains only on the end of game
        if game.is_tie():
            return

        if self.__check_uniq(game):
            return

        self.counter += 1

        X = self.__timeseries2x(game)[:-1]     # skip last series
        Y = self.model.predict(X, verbose=0)
        Y = self.__legal_moves(game, Y)

        turn_a = True
        reward_a = self.REWARD_WIN if game.status() else self.REWARD_DRW
        reward_b = self.REWARD_LST if game.status() else self.REWARD_DRW

        for t in range(len(Y) - 1, -1, -1):
            move = game.moves[t+1]
            # print(t, move, game.moves, X[t], Y[t])
            if turn_a:
                reward_a = Y[t][move] + self.REWARD_LR * (self.REWARD_ALP * reward_a - Y[t][move])
                Y[t][move] = reward_a
            else:
                reward_b = Y[t][move] + self.REWARD_LR * (self.REWARD_ALP * reward_b - Y[t][move])
                Y[t][move] = reward_b
            turn_a = not turn_a
        early_stopping = EarlyStopping(monitor='loss', patience=1, restore_best_weights=True)
        self.model.fit(np.array(X), np.array(Y), epochs=self.EPOCHS, batch_size=10, verbose=0, callbacks=[early_stopping])

        self.__save()

# %%
class EngineDenseRL3x:
    unique_ids = {}

    EPOCHS = 300

    REWARD_LR = 0.2
    REWARD_ALP = 0.9
    REWARD_WIN = 1.00
    REWARD_DRW = 0.30
    REWARD_LST = 0.00

    def __init__(self, code='EngineDenseRL3x', unique=False):
        self.code = code
        self.unique_ids = {} if unique else False
        self.model = Sequential([
            layers.ReLU(81, input_shape=(27,)),    #  2*9 as split X and 0 to separate cells
            #layers.Normalization(),
            layers.ReLU(243),
            layers.Normalization(),
            layers.Dropout(0.2),
            layers.Dense(9, activation='sigmoid')
        ])
        self.model.compile(optimizer='adam', loss='binary_crossentropy')   # binary_crossentropy
                        
    def __check_uniq(self, game):
        if self.unique_ids:
            game_id = ''.join(str(item) for item in game.moves)
            if game_id in self.unique_ids:
                return True
            self.unique_ids[game_id] = True
        return False

    def __board3x(self, game):
        board = game.board()
        board3x = 9 * [0, 0, 0]
        for i in range(len(board)):
            if board[i] == 1:
                board3x[3 * i] = 1
            if board[i] == -1:
                board3x[3 * i + 1] = 1
            if board[i] == 0:
                board3x[3 * i + 2] = 1
        return board3x

    def __timeseries3x(self, game):
        board = game.board()
        series = 9 * [0, 0, 0]
        timeseries3x = []
        for i in game.moves:
            if board[i] == 1:
                series[3 * i] = 1
            if board[i] == -1:
                series[3 * i + 1] = 1
            if board[i] == 0:
                series[3 * i + 2] = 1
            timeseries3x.append(series.copy())
        return timeseries3x

    def __legal_moves(self, game, Y):
        for i in range(len(Y)):
            Y[i] = game.remove_illegal_moves(Y[i], game.moves[:i])
        #print('NN legal', Y)
        return Y

    def move(self, game):
        X = [self.__board3x(game)]
        Y = self.model.predict(X, verbose=0)
        y = game.remove_illegal_moves(Y[0])
        return np.argmax(Y[0])

    def train(self, game):
        # this engine trains only on the end of game
        if game.is_tie():
            return

        if self.__check_uniq(game):
            return
        #print(game.timeseries())
        X = self.__timeseries3x(game)[:-1]     # skip last series
        Y = self.model.predict(X, verbose=0)
        Y = self.__legal_moves(game, Y)

        is_win = game.status()
        #print(game.status(), game.moves)
        turn_a = True
        reward_a = self.REWARD_WIN if game.status() else self.REWARD_DRW
        reward_b = self.REWARD_LST if game.status() else self.REWARD_DRW
        reward_learn = self.REWARD_LR

        for t in range(len(Y) - 1, -1, -1):
            move = game.moves[t+1]
            if turn_a:
                reward_a = Y[t][move] + self.REWARD_LR * (self.REWARD_ALP * reward_a - Y[t][move])
                Y[t][move] = reward_a
            else:
                reward_b = Y[t][move] + self.REWARD_LR * (self.REWARD_ALP * reward_b - Y[t][move])
                Y[t][move] = reward_b
            turn_a = not turn_a
            reward_learn *= self.REWARD_LR

        early_stopping = EarlyStopping(monitor='loss', patience=1, restore_best_weights=True)
        self.model.fit(np.array(X), np.array(Y), epochs=self.EPOCHS, batch_size=10, verbose=0, callbacks=[early_stopping])

# %%
a = EngineDenseRL2x('RL-2x', unique=True)
b = EngineDenseRL3x('RL-3x', unique=True)
c = EngineMiniMax('Mini-Max', max_depth=5)


enginesA = [b, c]

game = TicTacToe()

stats = Stats(enginesA)
for game_num in range(1, 10000):
    engine_X, engine_0 = random.sample(enginesA, k=2)
    game.auto_play(engine_X, engine_0)
    stats.add(game)
# Out:
# loaded RL-2x, last game number is 300
# Stats config: STEP = 10, WINDOW = 100
# Game    10 |     6sec | RL-3X:  0% wins, 20% draws, 80% losts | MINI-MAX-5: 80% wins, 20% draws,  0% losts
# Game    20 |    10sec | RL-3X: 15% wins, 25% draws, 60% losts | MINI-MAX-5: 60% wins, 25% draws, 15% losts
# Game    30 |    14sec | RL-3X: 10% wins, 20% draws, 70% losts | MINI-MAX-5: 70% wins, 20% draws, 10% losts
# Game    40 |    18sec | RL-3X: 10% wins, 25% draws, 65% losts | MINI-MAX-5: 65% wins, 25% draws, 10% losts
# Game    50 |    22sec | RL-3X:  8% wins, 28% draws, 64% losts | MINI-MAX-5: 64% wins, 28% draws,  8% losts
# Game    60 |    26sec | RL-3X:  8% wins, 27% draws, 65% losts | MINI-MAX-5: 65% wins, 27% draws,  8% losts
# Game    70 |    31sec | RL-3X: 10% wins, 27% draws, 63% losts | MINI-MAX-5: 63% wins, 27% draws, 10% losts
# Game    80 |    35sec | RL-3X: 11% wins, 26% draws, 62% losts | MINI-MAX-5: 62% wins, 26% draws, 11% losts
# Game    90 |    39sec | RL-3X: 11% wins, 29% draws, 60% losts | MINI-MAX-5: 60% wins, 29% draws, 11% losts
# Game   100 |    43sec | RL-3X: 10% wins, 29% draws, 61% losts | MINI-MAX-5: 61% wins, 29% draws, 10% losts
# Game   110 |    47sec | RL-3X: 10% wins, 28% draws, 62% losts | MINI-MAX-5: 62% wins, 28% draws, 10% losts
# Game   120 |    51sec | RL-3X:  9% wins, 27% draws, 64% losts | MINI-MAX-5: 64% wins, 27% draws,  9% losts
# Game   130 |    55sec | RL-3X:  9% wins, 29% draws, 62% losts | MINI-MAX-5: 62% wins, 29% draws,  9% losts
# Game   140 |    59sec | RL-3X:  9% wins, 27% draws, 64% losts | MINI-MAX-5: 64% wins, 27% draws,  9% losts
# Game   150 |    63sec | RL-3X:  9% wins, 24% draws, 67% losts | MINI-MAX-5: 67% wins, 24% draws,  9% losts
# Game   160 |    67sec | RL-3X:  8% wins, 25% draws, 67% losts | MINI-MAX-5: 67% wins, 25% draws,  8% losts
# Game   170 |    71sec | RL-3X:  7% wins, 25% draws, 68% losts | MINI-MAX-5: 68% wins, 25% draws,  7% losts
# Game   180 |    75sec | RL-3X:  5% wins, 27% draws, 68% losts | MINI-MAX-5: 68% wins, 27% draws,  5% losts
# Game   190 |    79sec | RL-3X:  6% wins, 23% draws, 71% losts | MINI-MAX-5: 71% wins, 23% draws,  6% losts
# Game   200 |    83sec | RL-3X:  6% wins, 23% draws, 71% losts | MINI-MAX-5: 71% wins, 23% draws,  6% losts
# Game   210 |    87sec | RL-3X:  8% wins, 24% draws, 68% losts | MINI-MAX-5: 68% wins, 24% draws,  8% losts
# Game   220 |    91sec | RL-3X:  6% wins, 26% draws, 68% losts | MINI-MAX-5: 68% wins, 26% draws,  6% losts
# Game   230 |    96sec | RL-3X:  6% wins, 30% draws, 64% losts | MINI-MAX-5: 64% wins, 30% draws,  6% losts
# Game   240 |   100sec | RL-3X:  6% wins, 32% draws, 62% losts | MINI-MAX-5: 62% wins, 32% draws,  6% losts
# Game   250 |   104sec | RL-3X:  7% wins, 34% draws, 59% losts | MINI-MAX-5: 59% wins, 34% draws,  7% losts
# Game   260 |   108sec | RL-3X:  7% wins, 34% draws, 59% losts | MINI-MAX-5: 59% wins, 34% draws,  7% losts
# Game   270 |   112sec | RL-3X:  6% wins, 35% draws, 59% losts | MINI-MAX-5: 59% wins, 35% draws,  6% losts
# Game   280 |   116sec | RL-3X:  6% wins, 33% draws, 61% losts | MINI-MAX-5: 61% wins, 33% draws,  6% losts
# Game   290 |   120sec | RL-3X:  4% wins, 34% draws, 62% losts | MINI-MAX-5: 62% wins, 34% draws,  4% losts
# Game   300 |   124sec | RL-3X:  4% wins, 34% draws, 62% losts | MINI-MAX-5: 62% wins, 34% draws,  4% losts
# Game   310 |   127sec | RL-3X:  2% wins, 32% draws, 66% losts | MINI-MAX-5: 66% wins, 32% draws,  2% losts
# Game   320 |   131sec | RL-3X:  3% wins, 30% draws, 67% losts | MINI-MAX-5: 67% wins, 30% draws,  3% losts
# Game   330 |   135sec | RL-3X:  4% wins, 23% draws, 73% losts | MINI-MAX-5: 73% wins, 23% draws,  4% losts
# Game   340 |   139sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game   350 |   143sec | RL-3X:  3% wins, 21% draws, 76% losts | MINI-MAX-5: 76% wins, 21% draws,  3% losts
# Game   360 |   147sec | RL-3X:  5% wins, 22% draws, 73% losts | MINI-MAX-5: 73% wins, 22% draws,  5% losts
# Game   370 |   151sec | RL-3X:  5% wins, 20% draws, 75% losts | MINI-MAX-5: 75% wins, 20% draws,  5% losts
# Game   380 |   155sec | RL-3X:  5% wins, 19% draws, 76% losts | MINI-MAX-5: 76% wins, 19% draws,  5% losts
# Game   390 |   159sec | RL-3X:  5% wins, 20% draws, 75% losts | MINI-MAX-5: 75% wins, 20% draws,  5% losts
# Game   400 |   163sec | RL-3X:  6% wins, 19% draws, 75% losts | MINI-MAX-5: 75% wins, 19% draws,  6% losts
# Game   410 |   167sec | RL-3X:  6% wins, 23% draws, 71% losts | MINI-MAX-5: 71% wins, 23% draws,  6% losts
# Game   420 |   171sec | RL-3X:  5% wins, 24% draws, 71% losts | MINI-MAX-5: 71% wins, 24% draws,  5% losts
# Game   430 |   175sec | RL-3X:  6% wins, 26% draws, 68% losts | MINI-MAX-5: 68% wins, 26% draws,  6% losts
# Game   440 |   179sec | RL-3X:  6% wins, 25% draws, 69% losts | MINI-MAX-5: 69% wins, 25% draws,  6% losts
# Game   450 |   183sec | RL-3X:  5% wins, 23% draws, 72% losts | MINI-MAX-5: 72% wins, 23% draws,  5% losts
# Game   460 |   186sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game   470 |   190sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game   480 |   195sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game   490 |   206sec | RL-3X:  4% wins, 20% draws, 76% losts | MINI-MAX-5: 76% wins, 20% draws,  4% losts
# Game   500 |   218sec | RL-3X:  5% wins, 21% draws, 74% losts | MINI-MAX-5: 74% wins, 21% draws,  5% losts
# Game   510 |   229sec | RL-3X:  5% wins, 18% draws, 77% losts | MINI-MAX-5: 77% wins, 18% draws,  5% losts
# Game   520 |   241sec | RL-3X:  6% wins, 16% draws, 78% losts | MINI-MAX-5: 78% wins, 16% draws,  6% losts
# Game   530 |   253sec | RL-3X:  4% wins, 14% draws, 82% losts | MINI-MAX-5: 82% wins, 14% draws,  4% losts
# Game   540 |   263sec | RL-3X:  4% wins, 13% draws, 83% losts | MINI-MAX-5: 83% wins, 13% draws,  4% losts
# Game   550 |   275sec | RL-3X:  4% wins, 15% draws, 81% losts | MINI-MAX-5: 81% wins, 15% draws,  4% losts
# Game   560 |   287sec | RL-3X:  4% wins, 15% draws, 81% losts | MINI-MAX-5: 81% wins, 15% draws,  4% losts
# Game   570 |   299sec | RL-3X:  4% wins, 14% draws, 82% losts | MINI-MAX-5: 82% wins, 14% draws,  4% losts
# Game   580 |   310sec | RL-3X:  4% wins, 17% draws, 79% losts | MINI-MAX-5: 79% wins, 17% draws,  4% losts
# Game   590 |   322sec | RL-3X:  3% wins, 17% draws, 80% losts | MINI-MAX-5: 80% wins, 17% draws,  3% losts
# Game   600 |   334sec | RL-3X:  1% wins, 17% draws, 82% losts | MINI-MAX-5: 82% wins, 17% draws,  1% losts
# Game   610 |   345sec | RL-3X:  1% wins, 17% draws, 82% losts | MINI-MAX-5: 82% wins, 17% draws,  1% losts
# Game   620 |   357sec | RL-3X:  1% wins, 17% draws, 82% losts | MINI-MAX-5: 82% wins, 17% draws,  1% losts
# Game   630 |   368sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game   640 |   381sec | RL-3X:  1% wins, 20% draws, 79% losts | MINI-MAX-5: 79% wins, 20% draws,  1% losts
# Game   650 |   393sec | RL-3X:  1% wins, 20% draws, 79% losts | MINI-MAX-5: 79% wins, 20% draws,  1% losts
# Game   660 |   406sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game   670 |   418sec | RL-3X:  2% wins, 24% draws, 74% losts | MINI-MAX-5: 74% wins, 24% draws,  2% losts
# Game   680 |   430sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game   690 |   443sec | RL-3X:  4% wins, 22% draws, 74% losts | MINI-MAX-5: 74% wins, 22% draws,  4% losts
# Game   700 |   454sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game   710 |   467sec | RL-3X:  4% wins, 24% draws, 72% losts | MINI-MAX-5: 72% wins, 24% draws,  4% losts
# Game   720 |   478sec | RL-3X:  4% wins, 24% draws, 72% losts | MINI-MAX-5: 72% wins, 24% draws,  4% losts
# Game   730 |   490sec | RL-3X:  4% wins, 25% draws, 71% losts | MINI-MAX-5: 71% wins, 25% draws,  4% losts
# Game   740 |   502sec | RL-3X:  4% wins, 24% draws, 72% losts | MINI-MAX-5: 72% wins, 24% draws,  4% losts
# Game   750 |   513sec | RL-3X:  4% wins, 23% draws, 73% losts | MINI-MAX-5: 73% wins, 23% draws,  4% losts
# Game   760 |   525sec | RL-3X:  3% wins, 21% draws, 76% losts | MINI-MAX-5: 76% wins, 21% draws,  3% losts
# Game   770 |   537sec | RL-3X:  3% wins, 19% draws, 78% losts | MINI-MAX-5: 78% wins, 19% draws,  3% losts
# Game   780 |   549sec | RL-3X:  3% wins, 19% draws, 78% losts | MINI-MAX-5: 78% wins, 19% draws,  3% losts
# Game   790 |   560sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game   800 |   572sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game   810 |   584sec | RL-3X:  4% wins, 19% draws, 77% losts | MINI-MAX-5: 77% wins, 19% draws,  4% losts
# Game   820 |   595sec | RL-3X:  3% wins, 18% draws, 79% losts | MINI-MAX-5: 79% wins, 18% draws,  3% losts
# Game   830 |   606sec | RL-3X:  3% wins, 17% draws, 80% losts | MINI-MAX-5: 80% wins, 17% draws,  3% losts
# Game   840 |   617sec | RL-3X:  4% wins, 15% draws, 81% losts | MINI-MAX-5: 81% wins, 15% draws,  4% losts
# Game   850 |   629sec | RL-3X:  5% wins, 19% draws, 76% losts | MINI-MAX-5: 76% wins, 19% draws,  5% losts
# Game   860 |   642sec | RL-3X:  6% wins, 18% draws, 76% losts | MINI-MAX-5: 76% wins, 18% draws,  6% losts
# Game   870 |   654sec | RL-3X:  7% wins, 17% draws, 76% losts | MINI-MAX-5: 76% wins, 17% draws,  7% losts
# Game   880 |   665sec | RL-3X:  6% wins, 16% draws, 78% losts | MINI-MAX-5: 78% wins, 16% draws,  6% losts
# Game   890 |   676sec | RL-3X:  6% wins, 14% draws, 80% losts | MINI-MAX-5: 80% wins, 14% draws,  6% losts
# Game   900 |   688sec | RL-3X:  6% wins, 14% draws, 80% losts | MINI-MAX-5: 80% wins, 14% draws,  6% losts
# Game   910 |   701sec | RL-3X:  5% wins, 14% draws, 81% losts | MINI-MAX-5: 81% wins, 14% draws,  5% losts
# Game   920 |   713sec | RL-3X:  5% wins, 15% draws, 80% losts | MINI-MAX-5: 80% wins, 15% draws,  5% losts
# Game   930 |   726sec | RL-3X:  5% wins, 16% draws, 79% losts | MINI-MAX-5: 79% wins, 16% draws,  5% losts
# Game   940 |   736sec | RL-3X:  4% wins, 17% draws, 79% losts | MINI-MAX-5: 79% wins, 17% draws,  4% losts
# Game   950 |   747sec | RL-3X:  3% wins, 13% draws, 84% losts | MINI-MAX-5: 84% wins, 13% draws,  3% losts
# Game   960 |   760sec | RL-3X:  2% wins, 15% draws, 83% losts | MINI-MAX-5: 83% wins, 15% draws,  2% losts
# Game   970 |   771sec | RL-3X:  3% wins, 14% draws, 83% losts | MINI-MAX-5: 83% wins, 14% draws,  3% losts
# Game   980 |   782sec | RL-3X:  3% wins, 14% draws, 83% losts | MINI-MAX-5: 83% wins, 14% draws,  3% losts
# Game   990 |   794sec | RL-3X:  4% wins, 15% draws, 81% losts | MINI-MAX-5: 81% wins, 15% draws,  4% losts
# Game  1000 |   806sec | RL-3X:  4% wins, 14% draws, 82% losts | MINI-MAX-5: 82% wins, 14% draws,  4% losts
# Game  1010 |   819sec | RL-3X:  4% wins, 15% draws, 81% losts | MINI-MAX-5: 81% wins, 15% draws,  4% losts
# Game  1020 |   831sec | RL-3X:  4% wins, 17% draws, 79% losts | MINI-MAX-5: 79% wins, 17% draws,  4% losts
# Game  1030 |   843sec | RL-3X:  4% wins, 17% draws, 79% losts | MINI-MAX-5: 79% wins, 17% draws,  4% losts
# Game  1040 |   856sec | RL-3X:  4% wins, 19% draws, 77% losts | MINI-MAX-5: 77% wins, 19% draws,  4% losts
# Game  1050 |   867sec | RL-3X:  4% wins, 19% draws, 77% losts | MINI-MAX-5: 77% wins, 19% draws,  4% losts
# Game  1060 |   878sec | RL-3X:  4% wins, 17% draws, 79% losts | MINI-MAX-5: 79% wins, 17% draws,  4% losts
# Game  1070 |   889sec | RL-3X:  2% wins, 17% draws, 81% losts | MINI-MAX-5: 81% wins, 17% draws,  2% losts
# Game  1080 |   901sec | RL-3X:  2% wins, 19% draws, 79% losts | MINI-MAX-5: 79% wins, 19% draws,  2% losts
# Game  1090 |   914sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  1100 |   925sec | RL-3X:  3% wins, 19% draws, 78% losts | MINI-MAX-5: 78% wins, 19% draws,  3% losts
# Game  1110 |   936sec | RL-3X:  2% wins, 16% draws, 82% losts | MINI-MAX-5: 82% wins, 16% draws,  2% losts
# Game  1120 |   948sec | RL-3X:  3% wins, 14% draws, 83% losts | MINI-MAX-5: 83% wins, 14% draws,  3% losts
# Game  1130 |   960sec | RL-3X:  4% wins, 13% draws, 83% losts | MINI-MAX-5: 83% wins, 13% draws,  4% losts
# Game  1140 |   972sec | RL-3X:  4% wins, 11% draws, 85% losts | MINI-MAX-5: 85% wins, 11% draws,  4% losts
# Game  1150 |   984sec | RL-3X:  4% wins, 13% draws, 83% losts | MINI-MAX-5: 83% wins, 13% draws,  4% losts
# Game  1160 |   995sec | RL-3X:  4% wins, 13% draws, 83% losts | MINI-MAX-5: 83% wins, 13% draws,  4% losts
# Game  1170 |  1008sec | RL-3X:  4% wins, 16% draws, 80% losts | MINI-MAX-5: 80% wins, 16% draws,  4% losts
# Game  1180 |  1018sec | RL-3X:  4% wins, 13% draws, 83% losts | MINI-MAX-5: 83% wins, 13% draws,  4% losts
# Game  1190 |  1029sec | RL-3X:  4% wins, 11% draws, 85% losts | MINI-MAX-5: 85% wins, 11% draws,  4% losts
# Game  1200 |  1041sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  1210 |  1053sec | RL-3X:  3% wins, 15% draws, 82% losts | MINI-MAX-5: 82% wins, 15% draws,  3% losts
# Game  1220 |  1063sec | RL-3X:  2% wins, 14% draws, 84% losts | MINI-MAX-5: 84% wins, 14% draws,  2% losts
# Game  1230 |  1074sec | RL-3X:  1% wins, 14% draws, 85% losts | MINI-MAX-5: 85% wins, 14% draws,  1% losts
# Game  1240 |  1086sec | RL-3X:  1% wins, 15% draws, 84% losts | MINI-MAX-5: 84% wins, 15% draws,  1% losts
# Game  1250 |  1099sec | RL-3X:  1% wins, 13% draws, 86% losts | MINI-MAX-5: 86% wins, 13% draws,  1% losts
# Game  1260 |  1110sec | RL-3X:  1% wins, 15% draws, 84% losts | MINI-MAX-5: 84% wins, 15% draws,  1% losts
# Game  1270 |  1122sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  1280 |  1134sec | RL-3X:  2% wins, 15% draws, 83% losts | MINI-MAX-5: 83% wins, 15% draws,  2% losts
# Game  1290 |  1145sec | RL-3X:  2% wins, 15% draws, 83% losts | MINI-MAX-5: 83% wins, 15% draws,  2% losts
# Game  1300 |  1157sec | RL-3X:  2% wins, 14% draws, 84% losts | MINI-MAX-5: 84% wins, 14% draws,  2% losts
# Game  1310 |  1168sec | RL-3X:  1% wins, 13% draws, 86% losts | MINI-MAX-5: 86% wins, 13% draws,  1% losts
# Game  1320 |  1179sec | RL-3X:  1% wins, 14% draws, 85% losts | MINI-MAX-5: 85% wins, 14% draws,  1% losts
# Game  1330 |  1191sec | RL-3X:  1% wins, 16% draws, 83% losts | MINI-MAX-5: 83% wins, 16% draws,  1% losts
# Game  1340 |  1203sec | RL-3X:  1% wins, 17% draws, 82% losts | MINI-MAX-5: 82% wins, 17% draws,  1% losts
# Game  1350 |  1215sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  1360 |  1226sec | RL-3X:  1% wins, 15% draws, 84% losts | MINI-MAX-5: 84% wins, 15% draws,  1% losts
# Game  1370 |  1239sec | RL-3X:  0% wins, 18% draws, 82% losts | MINI-MAX-5: 82% wins, 18% draws,  0% losts
# Game  1380 |  1250sec | RL-3X:  0% wins, 18% draws, 82% losts | MINI-MAX-5: 82% wins, 18% draws,  0% losts
# Game  1390 |  1262sec | RL-3X:  0% wins, 20% draws, 80% losts | MINI-MAX-5: 80% wins, 20% draws,  0% losts
# Game  1400 |  1274sec | RL-3X:  0% wins, 19% draws, 81% losts | MINI-MAX-5: 81% wins, 19% draws,  0% losts
# Game  1410 |  1285sec | RL-3X:  0% wins, 20% draws, 80% losts | MINI-MAX-5: 80% wins, 20% draws,  0% losts
# Game  1420 |  1297sec | RL-3X:  1% wins, 22% draws, 77% losts | MINI-MAX-5: 77% wins, 22% draws,  1% losts
# Game  1430 |  1309sec | RL-3X:  1% wins, 21% draws, 78% losts | MINI-MAX-5: 78% wins, 21% draws,  1% losts
# Game  1440 |  1321sec | RL-3X:  1% wins, 20% draws, 79% losts | MINI-MAX-5: 79% wins, 20% draws,  1% losts
# Game  1450 |  1332sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  1460 |  1343sec | RL-3X:  2% wins, 19% draws, 79% losts | MINI-MAX-5: 79% wins, 19% draws,  2% losts
# Game  1470 |  1356sec | RL-3X:  2% wins, 20% draws, 78% losts | MINI-MAX-5: 78% wins, 20% draws,  2% losts
# Game  1480 |  1367sec | RL-3X:  2% wins, 19% draws, 79% losts | MINI-MAX-5: 79% wins, 19% draws,  2% losts
# Game  1490 |  1378sec | RL-3X:  2% wins, 17% draws, 81% losts | MINI-MAX-5: 81% wins, 17% draws,  2% losts
# Game  1500 |  1390sec | RL-3X:  2% wins, 17% draws, 81% losts | MINI-MAX-5: 81% wins, 17% draws,  2% losts
# Game  1510 |  1402sec | RL-3X:  2% wins, 19% draws, 79% losts | MINI-MAX-5: 79% wins, 19% draws,  2% losts
# Game  1520 |  1413sec | RL-3X:  1% wins, 17% draws, 82% losts | MINI-MAX-5: 82% wins, 17% draws,  1% losts
# Game  1530 |  1425sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  1540 |  1437sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  1550 |  1447sec | RL-3X:  1% wins, 17% draws, 82% losts | MINI-MAX-5: 82% wins, 17% draws,  1% losts
# Game  1560 |  1459sec | RL-3X:  0% wins, 19% draws, 81% losts | MINI-MAX-5: 81% wins, 19% draws,  0% losts
# Game  1570 |  1471sec | RL-3X:  0% wins, 16% draws, 84% losts | MINI-MAX-5: 84% wins, 16% draws,  0% losts
# Game  1580 |  1483sec | RL-3X:  0% wins, 17% draws, 83% losts | MINI-MAX-5: 83% wins, 17% draws,  0% losts
# Game  1590 |  1494sec | RL-3X:  0% wins, 19% draws, 81% losts | MINI-MAX-5: 81% wins, 19% draws,  0% losts
# Game  1600 |  1506sec | RL-3X:  0% wins, 20% draws, 80% losts | MINI-MAX-5: 80% wins, 20% draws,  0% losts
# Game  1610 |  1517sec | RL-3X:  0% wins, 17% draws, 83% losts | MINI-MAX-5: 83% wins, 17% draws,  0% losts
# Game  1620 |  1529sec | RL-3X:  0% wins, 18% draws, 82% losts | MINI-MAX-5: 82% wins, 18% draws,  0% losts
# Game  1630 |  1541sec | RL-3X:  1% wins, 16% draws, 83% losts | MINI-MAX-5: 83% wins, 16% draws,  1% losts
# Game  1640 |  1552sec | RL-3X:  1% wins, 16% draws, 83% losts | MINI-MAX-5: 83% wins, 16% draws,  1% losts
# Game  1650 |  1565sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  1660 |  1577sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  1670 |  1590sec | RL-3X:  1% wins, 20% draws, 79% losts | MINI-MAX-5: 79% wins, 20% draws,  1% losts
# Game  1680 |  1601sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  1690 |  1614sec | RL-3X:  1% wins, 20% draws, 79% losts | MINI-MAX-5: 79% wins, 20% draws,  1% losts
# Game  1700 |  1625sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  1710 |  1637sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  1720 |  1648sec | RL-3X:  1% wins, 17% draws, 82% losts | MINI-MAX-5: 82% wins, 17% draws,  1% losts
# Game  1730 |  1659sec | RL-3X:  0% wins, 16% draws, 84% losts | MINI-MAX-5: 84% wins, 16% draws,  0% losts
# Game  1740 |  1670sec | RL-3X:  0% wins, 15% draws, 85% losts | MINI-MAX-5: 85% wins, 15% draws,  0% losts
# Game  1750 |  1682sec | RL-3X:  0% wins, 14% draws, 86% losts | MINI-MAX-5: 86% wins, 14% draws,  0% losts
# Game  1760 |  1693sec | RL-3X:  0% wins, 14% draws, 86% losts | MINI-MAX-5: 86% wins, 14% draws,  0% losts
# Game  1770 |  1705sec | RL-3X:  0% wins, 13% draws, 87% losts | MINI-MAX-5: 87% wins, 13% draws,  0% losts
# Game  1780 |  1717sec | RL-3X:  0% wins, 14% draws, 86% losts | MINI-MAX-5: 86% wins, 14% draws,  0% losts
# Game  1790 |  1729sec | RL-3X:  0% wins, 13% draws, 87% losts | MINI-MAX-5: 87% wins, 13% draws,  0% losts
# Game  1800 |  1741sec | RL-3X:  1% wins, 13% draws, 86% losts | MINI-MAX-5: 86% wins, 13% draws,  1% losts
# Game  1810 |  1752sec | RL-3X:  1% wins, 13% draws, 86% losts | MINI-MAX-5: 86% wins, 13% draws,  1% losts
# Game  1820 |  1764sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  1830 |  1775sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  1840 |  1786sec | RL-3X:  2% wins, 12% draws, 86% losts | MINI-MAX-5: 86% wins, 12% draws,  2% losts
# Game  1850 |  1798sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  1860 |  1810sec | RL-3X:  2% wins, 14% draws, 84% losts | MINI-MAX-5: 84% wins, 14% draws,  2% losts
# Game  1870 |  1820sec | RL-3X:  2% wins, 11% draws, 87% losts | MINI-MAX-5: 87% wins, 11% draws,  2% losts
# Game  1880 |  1832sec | RL-3X:  2% wins, 10% draws, 88% losts | MINI-MAX-5: 88% wins, 10% draws,  2% losts
# Game  1890 |  1843sec | RL-3X:  2% wins,  9% draws, 89% losts | MINI-MAX-5: 89% wins,  9% draws,  2% losts
# Game  1900 |  1855sec | RL-3X:  1% wins, 11% draws, 88% losts | MINI-MAX-5: 88% wins, 11% draws,  1% losts
# Game  1910 |  1867sec | RL-3X:  1% wins, 13% draws, 86% losts | MINI-MAX-5: 86% wins, 13% draws,  1% losts
# Game  1920 |  1878sec | RL-3X:  0% wins, 13% draws, 87% losts | MINI-MAX-5: 87% wins, 13% draws,  0% losts
# Game  1930 |  1890sec | RL-3X:  0% wins, 15% draws, 85% losts | MINI-MAX-5: 85% wins, 15% draws,  0% losts
# Game  1940 |  1902sec | RL-3X:  0% wins, 17% draws, 83% losts | MINI-MAX-5: 83% wins, 17% draws,  0% losts
# Game  1950 |  1915sec | RL-3X:  0% wins, 16% draws, 84% losts | MINI-MAX-5: 84% wins, 16% draws,  0% losts
# Game  1960 |  1928sec | RL-3X:  1% wins, 16% draws, 83% losts | MINI-MAX-5: 83% wins, 16% draws,  1% losts
# Game  1970 |  1939sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  1980 |  1950sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  1990 |  1963sec | RL-3X:  1% wins, 20% draws, 79% losts | MINI-MAX-5: 79% wins, 20% draws,  1% losts
# Game  2000 |  1975sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  2010 |  1987sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  2020 |  1999sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game  2030 |  2011sec | RL-3X:  3% wins, 21% draws, 76% losts | MINI-MAX-5: 76% wins, 21% draws,  3% losts
# Game  2040 |  2023sec | RL-3X:  3% wins, 21% draws, 76% losts | MINI-MAX-5: 76% wins, 21% draws,  3% losts
# Game  2050 |  2034sec | RL-3X:  3% wins, 19% draws, 78% losts | MINI-MAX-5: 78% wins, 19% draws,  3% losts
# Game  2060 |  2045sec | RL-3X:  2% wins, 20% draws, 78% losts | MINI-MAX-5: 78% wins, 20% draws,  2% losts
# Game  2070 |  2056sec | RL-3X:  2% wins, 20% draws, 78% losts | MINI-MAX-5: 78% wins, 20% draws,  2% losts
# Game  2080 |  2067sec | RL-3X:  2% wins, 19% draws, 79% losts | MINI-MAX-5: 79% wins, 19% draws,  2% losts
# Game  2090 |  2078sec | RL-3X:  2% wins, 17% draws, 81% losts | MINI-MAX-5: 81% wins, 17% draws,  2% losts
# Game  2100 |  2090sec | RL-3X:  2% wins, 17% draws, 81% losts | MINI-MAX-5: 81% wins, 17% draws,  2% losts
# Game  2110 |  2101sec | RL-3X:  2% wins, 16% draws, 82% losts | MINI-MAX-5: 82% wins, 16% draws,  2% losts
# Game  2120 |  2113sec | RL-3X:  1% wins, 15% draws, 84% losts | MINI-MAX-5: 84% wins, 15% draws,  1% losts
# Game  2130 |  2124sec | RL-3X:  0% wins, 14% draws, 86% losts | MINI-MAX-5: 86% wins, 14% draws,  0% losts
# Game  2140 |  2135sec | RL-3X:  0% wins, 13% draws, 87% losts | MINI-MAX-5: 87% wins, 13% draws,  0% losts
# Game  2150 |  2147sec | RL-3X:  1% wins, 16% draws, 83% losts | MINI-MAX-5: 83% wins, 16% draws,  1% losts
# Game  2160 |  2160sec | RL-3X:  1% wins, 17% draws, 82% losts | MINI-MAX-5: 82% wins, 17% draws,  1% losts
# Game  2170 |  2171sec | RL-3X:  1% wins, 16% draws, 83% losts | MINI-MAX-5: 83% wins, 16% draws,  1% losts
# Game  2180 |  2183sec | RL-3X:  3% wins, 16% draws, 81% losts | MINI-MAX-5: 81% wins, 16% draws,  3% losts
# Game  2190 |  2195sec | RL-3X:  3% wins, 19% draws, 78% losts | MINI-MAX-5: 78% wins, 19% draws,  3% losts
# Game  2200 |  2205sec | RL-3X:  3% wins, 17% draws, 80% losts | MINI-MAX-5: 80% wins, 17% draws,  3% losts
# Game  2210 |  2217sec | RL-3X:  3% wins, 18% draws, 79% losts | MINI-MAX-5: 79% wins, 18% draws,  3% losts
# Game  2220 |  2230sec | RL-3X:  4% wins, 20% draws, 76% losts | MINI-MAX-5: 76% wins, 20% draws,  4% losts
# Game  2230 |  2242sec | RL-3X:  5% wins, 21% draws, 74% losts | MINI-MAX-5: 74% wins, 21% draws,  5% losts
# Game  2240 |  2253sec | RL-3X:  5% wins, 21% draws, 74% losts | MINI-MAX-5: 74% wins, 21% draws,  5% losts
# Game  2250 |  2265sec | RL-3X:  4% wins, 19% draws, 77% losts | MINI-MAX-5: 77% wins, 19% draws,  4% losts
# Game  2260 |  2276sec | RL-3X:  4% wins, 16% draws, 80% losts | MINI-MAX-5: 80% wins, 16% draws,  4% losts
# Game  2270 |  2286sec | RL-3X:  4% wins, 15% draws, 81% losts | MINI-MAX-5: 81% wins, 15% draws,  4% losts
# Game  2280 |  2299sec | RL-3X:  2% wins, 17% draws, 81% losts | MINI-MAX-5: 81% wins, 17% draws,  2% losts
# Game  2290 |  2311sec | RL-3X:  2% wins, 16% draws, 82% losts | MINI-MAX-5: 82% wins, 16% draws,  2% losts
# Game  2300 |  2323sec | RL-3X:  2% wins, 19% draws, 79% losts | MINI-MAX-5: 79% wins, 19% draws,  2% losts
# Game  2310 |  2336sec | RL-3X:  2% wins, 22% draws, 76% losts | MINI-MAX-5: 76% wins, 22% draws,  2% losts
# Game  2320 |  2347sec | RL-3X:  1% wins, 20% draws, 79% losts | MINI-MAX-5: 79% wins, 20% draws,  1% losts
# Game  2330 |  2360sec | RL-3X:  0% wins, 23% draws, 77% losts | MINI-MAX-5: 77% wins, 23% draws,  0% losts
# Game  2340 |  2371sec | RL-3X:  0% wins, 24% draws, 76% losts | MINI-MAX-5: 76% wins, 24% draws,  0% losts
# Game  2350 |  2384sec | RL-3X:  0% wins, 26% draws, 74% losts | MINI-MAX-5: 74% wins, 26% draws,  0% losts
# Game  2360 |  2396sec | RL-3X:  0% wins, 28% draws, 72% losts | MINI-MAX-5: 72% wins, 28% draws,  0% losts
# Game  2370 |  2408sec | RL-3X:  0% wins, 31% draws, 69% losts | MINI-MAX-5: 69% wins, 31% draws,  0% losts
# Game  2380 |  2420sec | RL-3X:  0% wins, 30% draws, 70% losts | MINI-MAX-5: 70% wins, 30% draws,  0% losts
# Game  2390 |  2432sec | RL-3X:  0% wins, 28% draws, 72% losts | MINI-MAX-5: 72% wins, 28% draws,  0% losts
# Game  2400 |  2444sec | RL-3X:  1% wins, 28% draws, 71% losts | MINI-MAX-5: 71% wins, 28% draws,  1% losts
# Game  2410 |  2454sec | RL-3X:  1% wins, 24% draws, 75% losts | MINI-MAX-5: 75% wins, 24% draws,  1% losts
# Game  2420 |  2466sec | RL-3X:  1% wins, 24% draws, 75% losts | MINI-MAX-5: 75% wins, 24% draws,  1% losts
# Game  2430 |  2478sec | RL-3X:  1% wins, 21% draws, 78% losts | MINI-MAX-5: 78% wins, 21% draws,  1% losts
# Game  2440 |  2490sec | RL-3X:  1% wins, 23% draws, 76% losts | MINI-MAX-5: 76% wins, 23% draws,  1% losts
# Game  2450 |  2502sec | RL-3X:  2% wins, 22% draws, 76% losts | MINI-MAX-5: 76% wins, 22% draws,  2% losts
# Game  2460 |  2514sec | RL-3X:  3% wins, 21% draws, 76% losts | MINI-MAX-5: 76% wins, 21% draws,  3% losts
# Game  2470 |  2525sec | RL-3X:  4% wins, 20% draws, 76% losts | MINI-MAX-5: 76% wins, 20% draws,  4% losts
# Game  2480 |  2538sec | RL-3X:  5% wins, 20% draws, 75% losts | MINI-MAX-5: 75% wins, 20% draws,  5% losts
# Game  2490 |  2549sec | RL-3X:  5% wins, 21% draws, 74% losts | MINI-MAX-5: 74% wins, 21% draws,  5% losts
# Game  2500 |  2559sec | RL-3X:  4% wins, 18% draws, 78% losts | MINI-MAX-5: 78% wins, 18% draws,  4% losts
# Game  2510 |  2570sec | RL-3X:  4% wins, 17% draws, 79% losts | MINI-MAX-5: 79% wins, 17% draws,  4% losts
# Game  2520 |  2582sec | RL-3X:  4% wins, 17% draws, 79% losts | MINI-MAX-5: 79% wins, 17% draws,  4% losts
# Game  2530 |  2593sec | RL-3X:  4% wins, 16% draws, 80% losts | MINI-MAX-5: 80% wins, 16% draws,  4% losts
# Game  2540 |  2605sec | RL-3X:  4% wins, 15% draws, 81% losts | MINI-MAX-5: 81% wins, 15% draws,  4% losts
# Game  2550 |  2618sec | RL-3X:  3% wins, 16% draws, 81% losts | MINI-MAX-5: 81% wins, 16% draws,  3% losts
# Game  2560 |  2629sec | RL-3X:  2% wins, 15% draws, 83% losts | MINI-MAX-5: 83% wins, 15% draws,  2% losts
# Game  2570 |  2640sec | RL-3X:  1% wins, 13% draws, 86% losts | MINI-MAX-5: 86% wins, 13% draws,  1% losts
# Game  2580 |  2652sec | RL-3X:  1% wins, 14% draws, 85% losts | MINI-MAX-5: 85% wins, 14% draws,  1% losts
# Game  2590 |  2664sec | RL-3X:  1% wins, 17% draws, 82% losts | MINI-MAX-5: 82% wins, 17% draws,  1% losts
# Game  2600 |  2676sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  2610 |  2689sec | RL-3X:  3% wins, 21% draws, 76% losts | MINI-MAX-5: 76% wins, 21% draws,  3% losts
# Game  2620 |  2702sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game  2630 |  2715sec | RL-3X:  4% wins, 23% draws, 73% losts | MINI-MAX-5: 73% wins, 23% draws,  4% losts
# Game  2640 |  2726sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  2650 |  2738sec | RL-3X:  5% wins, 21% draws, 74% losts | MINI-MAX-5: 74% wins, 21% draws,  5% losts
# Game  2660 |  2750sec | RL-3X:  5% wins, 24% draws, 71% losts | MINI-MAX-5: 71% wins, 24% draws,  5% losts
# Game  2670 |  2762sec | RL-3X:  5% wins, 26% draws, 69% losts | MINI-MAX-5: 69% wins, 26% draws,  5% losts
# Game  2680 |  2775sec | RL-3X:  5% wins, 24% draws, 71% losts | MINI-MAX-5: 71% wins, 24% draws,  5% losts
# Game  2690 |  2788sec | RL-3X:  5% wins, 24% draws, 71% losts | MINI-MAX-5: 71% wins, 24% draws,  5% losts
# Game  2700 |  2799sec | RL-3X:  5% wins, 24% draws, 71% losts | MINI-MAX-5: 71% wins, 24% draws,  5% losts
# Game  2710 |  2812sec | RL-3X:  4% wins, 23% draws, 73% losts | MINI-MAX-5: 73% wins, 23% draws,  4% losts
# Game  2720 |  2823sec | RL-3X:  4% wins, 22% draws, 74% losts | MINI-MAX-5: 74% wins, 22% draws,  4% losts
# Game  2730 |  2835sec | RL-3X:  3% wins, 23% draws, 74% losts | MINI-MAX-5: 74% wins, 23% draws,  3% losts
# Game  2740 |  2847sec | RL-3X:  4% wins, 24% draws, 72% losts | MINI-MAX-5: 72% wins, 24% draws,  4% losts
# Game  2750 |  2859sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game  2760 |  2871sec | RL-3X:  3% wins, 23% draws, 74% losts | MINI-MAX-5: 74% wins, 23% draws,  3% losts
# Game  2770 |  2883sec | RL-3X:  3% wins, 24% draws, 73% losts | MINI-MAX-5: 73% wins, 24% draws,  3% losts
# Game  2780 |  2897sec | RL-3X:  2% wins, 29% draws, 69% losts | MINI-MAX-5: 69% wins, 29% draws,  2% losts
# Game  2790 |  2910sec | RL-3X:  2% wins, 29% draws, 69% losts | MINI-MAX-5: 69% wins, 29% draws,  2% losts
# Game  2800 |  2920sec | RL-3X:  2% wins, 28% draws, 70% losts | MINI-MAX-5: 70% wins, 28% draws,  2% losts
# Game  2810 |  2931sec | RL-3X:  1% wins, 27% draws, 72% losts | MINI-MAX-5: 72% wins, 27% draws,  1% losts
# Game  2820 |  2944sec | RL-3X:  1% wins, 27% draws, 72% losts | MINI-MAX-5: 72% wins, 27% draws,  1% losts
# Game  2830 |  2955sec | RL-3X:  1% wins, 24% draws, 75% losts | MINI-MAX-5: 75% wins, 24% draws,  1% losts
# Game  2840 |  2967sec | RL-3X:  1% wins, 23% draws, 76% losts | MINI-MAX-5: 76% wins, 23% draws,  1% losts
# Game  2850 |  2980sec | RL-3X:  1% wins, 26% draws, 73% losts | MINI-MAX-5: 73% wins, 26% draws,  1% losts
# Game  2860 |  2991sec | RL-3X:  1% wins, 21% draws, 78% losts | MINI-MAX-5: 78% wins, 21% draws,  1% losts
# Game  2870 |  3002sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  2880 |  3013sec | RL-3X:  2% wins, 12% draws, 86% losts | MINI-MAX-5: 86% wins, 12% draws,  2% losts
# Game  2890 |  3026sec | RL-3X:  3% wins, 11% draws, 86% losts | MINI-MAX-5: 86% wins, 11% draws,  3% losts
# Game  2900 |  3037sec | RL-3X:  3% wins, 13% draws, 84% losts | MINI-MAX-5: 84% wins, 13% draws,  3% losts
# Game  2910 |  3048sec | RL-3X:  3% wins, 14% draws, 83% losts | MINI-MAX-5: 83% wins, 14% draws,  3% losts
# Game  2920 |  3058sec | RL-3X:  3% wins, 13% draws, 84% losts | MINI-MAX-5: 84% wins, 13% draws,  3% losts
# Game  2930 |  3069sec | RL-3X:  3% wins, 13% draws, 84% losts | MINI-MAX-5: 84% wins, 13% draws,  3% losts
# Game  2940 |  3080sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  2950 |  3091sec | RL-3X:  2% wins, 12% draws, 86% losts | MINI-MAX-5: 86% wins, 12% draws,  2% losts
# Game  2960 |  3102sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  2970 |  3114sec | RL-3X:  3% wins, 15% draws, 82% losts | MINI-MAX-5: 82% wins, 15% draws,  3% losts
# Game  2980 |  3126sec | RL-3X:  2% wins, 17% draws, 81% losts | MINI-MAX-5: 81% wins, 17% draws,  2% losts
# Game  2990 |  3138sec | RL-3X:  1% wins, 15% draws, 84% losts | MINI-MAX-5: 84% wins, 15% draws,  1% losts
# Game  3000 |  3149sec | RL-3X:  2% wins, 14% draws, 84% losts | MINI-MAX-5: 84% wins, 14% draws,  2% losts
# Game  3010 |  3160sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  3020 |  3172sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  3030 |  3183sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  3040 |  3195sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  3050 |  3207sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  3060 |  3218sec | RL-3X:  3% wins, 13% draws, 84% losts | MINI-MAX-5: 84% wins, 13% draws,  3% losts
# Game  3070 |  3231sec | RL-3X:  2% wins, 14% draws, 84% losts | MINI-MAX-5: 84% wins, 14% draws,  2% losts
# Game  3080 |  3242sec | RL-3X:  3% wins, 13% draws, 84% losts | MINI-MAX-5: 84% wins, 13% draws,  3% losts
# Game  3090 |  3253sec | RL-3X:  3% wins, 13% draws, 84% losts | MINI-MAX-5: 84% wins, 13% draws,  3% losts
# Game  3100 |  3266sec | RL-3X:  2% wins, 16% draws, 82% losts | MINI-MAX-5: 82% wins, 16% draws,  2% losts
# Game  3110 |  3277sec | RL-3X:  2% wins, 17% draws, 81% losts | MINI-MAX-5: 81% wins, 17% draws,  2% losts
# Game  3120 |  3289sec | RL-3X:  2% wins, 16% draws, 82% losts | MINI-MAX-5: 82% wins, 16% draws,  2% losts
# Game  3130 |  3301sec | RL-3X:  2% wins, 18% draws, 80% losts | MINI-MAX-5: 80% wins, 18% draws,  2% losts
# Game  3140 |  3312sec | RL-3X:  2% wins, 18% draws, 80% losts | MINI-MAX-5: 80% wins, 18% draws,  2% losts
# Game  3150 |  3324sec | RL-3X:  3% wins, 15% draws, 82% losts | MINI-MAX-5: 82% wins, 15% draws,  3% losts
# Game  3160 |  3336sec | RL-3X:  3% wins, 15% draws, 82% losts | MINI-MAX-5: 82% wins, 15% draws,  3% losts
# Game  3170 |  3348sec | RL-3X:  4% wins, 14% draws, 82% losts | MINI-MAX-5: 82% wins, 14% draws,  4% losts
# Game  3180 |  3360sec | RL-3X:  3% wins, 15% draws, 82% losts | MINI-MAX-5: 82% wins, 15% draws,  3% losts
# Game  3190 |  3371sec | RL-3X:  3% wins, 16% draws, 81% losts | MINI-MAX-5: 81% wins, 16% draws,  3% losts
# Game  3200 |  3383sec | RL-3X:  4% wins, 13% draws, 83% losts | MINI-MAX-5: 83% wins, 13% draws,  4% losts
# Game  3210 |  3394sec | RL-3X:  4% wins, 11% draws, 85% losts | MINI-MAX-5: 85% wins, 11% draws,  4% losts
# Game  3220 |  3404sec | RL-3X:  4% wins, 12% draws, 84% losts | MINI-MAX-5: 84% wins, 12% draws,  4% losts
# Game  3230 |  3416sec | RL-3X:  4% wins, 10% draws, 86% losts | MINI-MAX-5: 86% wins, 10% draws,  4% losts
# Game  3240 |  3427sec | RL-3X:  6% wins,  9% draws, 85% losts | MINI-MAX-5: 85% wins,  9% draws,  6% losts
# Game  3250 |  3439sec | RL-3X:  5% wins, 13% draws, 82% losts | MINI-MAX-5: 82% wins, 13% draws,  5% losts
# Game  3260 |  3450sec | RL-3X:  4% wins, 13% draws, 83% losts | MINI-MAX-5: 83% wins, 13% draws,  4% losts
# Game  3270 |  3462sec | RL-3X:  5% wins, 13% draws, 82% losts | MINI-MAX-5: 82% wins, 13% draws,  5% losts
# Game  3280 |  3474sec | RL-3X:  6% wins, 12% draws, 82% losts | MINI-MAX-5: 82% wins, 12% draws,  6% losts
# Game  3290 |  3486sec | RL-3X:  6% wins, 13% draws, 81% losts | MINI-MAX-5: 81% wins, 13% draws,  6% losts
# Game  3300 |  3498sec | RL-3X:  5% wins, 14% draws, 81% losts | MINI-MAX-5: 81% wins, 14% draws,  5% losts
# Game  3310 |  3509sec | RL-3X:  5% wins, 15% draws, 80% losts | MINI-MAX-5: 80% wins, 15% draws,  5% losts
# Game  3320 |  3521sec | RL-3X:  6% wins, 15% draws, 79% losts | MINI-MAX-5: 79% wins, 15% draws,  6% losts
# Game  3330 |  3533sec | RL-3X:  6% wins, 18% draws, 76% losts | MINI-MAX-5: 76% wins, 18% draws,  6% losts
# Game  3340 |  3543sec | RL-3X:  4% wins, 18% draws, 78% losts | MINI-MAX-5: 78% wins, 18% draws,  4% losts
# Game  3350 |  3554sec | RL-3X:  4% wins, 14% draws, 82% losts | MINI-MAX-5: 82% wins, 14% draws,  4% losts
# Game  3360 |  3567sec | RL-3X:  6% wins, 14% draws, 80% losts | MINI-MAX-5: 80% wins, 14% draws,  6% losts
# Game  3370 |  3578sec | RL-3X:  4% wins, 12% draws, 84% losts | MINI-MAX-5: 84% wins, 12% draws,  4% losts
# Game  3380 |  3590sec | RL-3X:  3% wins, 15% draws, 82% losts | MINI-MAX-5: 82% wins, 15% draws,  3% losts
# Game  3390 |  3602sec | RL-3X:  3% wins, 15% draws, 82% losts | MINI-MAX-5: 82% wins, 15% draws,  3% losts
# Game  3400 |  3614sec | RL-3X:  4% wins, 15% draws, 81% losts | MINI-MAX-5: 81% wins, 15% draws,  4% losts
# Game  3410 |  3626sec | RL-3X:  5% wins, 15% draws, 80% losts | MINI-MAX-5: 80% wins, 15% draws,  5% losts
# Game  3420 |  3638sec | RL-3X:  4% wins, 20% draws, 76% losts | MINI-MAX-5: 76% wins, 20% draws,  4% losts
# Game  3430 |  3651sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  3440 |  3662sec | RL-3X:  5% wins, 21% draws, 74% losts | MINI-MAX-5: 74% wins, 21% draws,  5% losts
# Game  3450 |  3674sec | RL-3X:  5% wins, 25% draws, 70% losts | MINI-MAX-5: 70% wins, 25% draws,  5% losts
# Game  3460 |  3684sec | RL-3X:  3% wins, 24% draws, 73% losts | MINI-MAX-5: 73% wins, 24% draws,  3% losts
# Game  3470 |  3697sec | RL-3X:  4% wins, 26% draws, 70% losts | MINI-MAX-5: 70% wins, 26% draws,  4% losts
# Game  3480 |  3709sec | RL-3X:  5% wins, 23% draws, 72% losts | MINI-MAX-5: 72% wins, 23% draws,  5% losts
# Game  3490 |  3720sec | RL-3X:  5% wins, 22% draws, 73% losts | MINI-MAX-5: 73% wins, 22% draws,  5% losts
# Game  3500 |  3732sec | RL-3X:  5% wins, 20% draws, 75% losts | MINI-MAX-5: 75% wins, 20% draws,  5% losts
# Game  3510 |  3745sec | RL-3X:  5% wins, 22% draws, 73% losts | MINI-MAX-5: 73% wins, 22% draws,  5% losts
# Game  3520 |  3757sec | RL-3X:  6% wins, 18% draws, 76% losts | MINI-MAX-5: 76% wins, 18% draws,  6% losts
# Game  3530 |  3769sec | RL-3X:  7% wins, 15% draws, 78% losts | MINI-MAX-5: 78% wins, 15% draws,  7% losts
# Game  3540 |  3781sec | RL-3X:  7% wins, 17% draws, 76% losts | MINI-MAX-5: 76% wins, 17% draws,  7% losts
# Game  3550 |  3792sec | RL-3X:  7% wins, 15% draws, 78% losts | MINI-MAX-5: 78% wins, 15% draws,  7% losts
# Game  3560 |  3804sec | RL-3X:  7% wins, 17% draws, 76% losts | MINI-MAX-5: 76% wins, 17% draws,  7% losts
# Game  3570 |  3816sec | RL-3X:  6% wins, 15% draws, 79% losts | MINI-MAX-5: 79% wins, 15% draws,  6% losts
# Game  3580 |  3828sec | RL-3X:  5% wins, 16% draws, 79% losts | MINI-MAX-5: 79% wins, 16% draws,  5% losts
# Game  3590 |  3839sec | RL-3X:  6% wins, 14% draws, 80% losts | MINI-MAX-5: 80% wins, 14% draws,  6% losts
# Game  3600 |  3850sec | RL-3X:  5% wins, 15% draws, 80% losts | MINI-MAX-5: 80% wins, 15% draws,  5% losts
# Game  3610 |  3862sec | RL-3X:  5% wins, 14% draws, 81% losts | MINI-MAX-5: 81% wins, 14% draws,  5% losts
# Game  3620 |  3875sec | RL-3X:  4% wins, 16% draws, 80% losts | MINI-MAX-5: 80% wins, 16% draws,  4% losts
# Game  3630 |  3887sec | RL-3X:  3% wins, 18% draws, 79% losts | MINI-MAX-5: 79% wins, 18% draws,  3% losts
# Game  3640 |  3899sec | RL-3X:  4% wins, 18% draws, 78% losts | MINI-MAX-5: 78% wins, 18% draws,  4% losts
# Game  3650 |  3910sec | RL-3X:  4% wins, 16% draws, 80% losts | MINI-MAX-5: 80% wins, 16% draws,  4% losts
# Game  3660 |  3922sec | RL-3X:  4% wins, 16% draws, 80% losts | MINI-MAX-5: 80% wins, 16% draws,  4% losts
# Game  3670 |  3933sec | RL-3X:  4% wins, 17% draws, 79% losts | MINI-MAX-5: 79% wins, 17% draws,  4% losts
# Game  3680 |  3945sec | RL-3X:  4% wins, 18% draws, 78% losts | MINI-MAX-5: 78% wins, 18% draws,  4% losts
# Game  3690 |  3956sec | RL-3X:  3% wins, 20% draws, 77% losts | MINI-MAX-5: 77% wins, 20% draws,  3% losts
# Game  3700 |  3968sec | RL-3X:  3% wins, 21% draws, 76% losts | MINI-MAX-5: 76% wins, 21% draws,  3% losts
# Game  3710 |  3979sec | RL-3X:  2% wins, 19% draws, 79% losts | MINI-MAX-5: 79% wins, 19% draws,  2% losts
# Game  3720 |  3991sec | RL-3X:  2% wins, 18% draws, 80% losts | MINI-MAX-5: 80% wins, 18% draws,  2% losts
# Game  3730 |  4004sec | RL-3X:  3% wins, 18% draws, 79% losts | MINI-MAX-5: 79% wins, 18% draws,  3% losts
# Game  3740 |  4016sec | RL-3X:  2% wins, 20% draws, 78% losts | MINI-MAX-5: 78% wins, 20% draws,  2% losts
# Game  3750 |  4028sec | RL-3X:  2% wins, 22% draws, 76% losts | MINI-MAX-5: 76% wins, 22% draws,  2% losts
# Game  3760 |  4040sec | RL-3X:  2% wins, 24% draws, 74% losts | MINI-MAX-5: 74% wins, 24% draws,  2% losts
# Game  3770 |  4051sec | RL-3X:  3% wins, 23% draws, 74% losts | MINI-MAX-5: 74% wins, 23% draws,  3% losts
# Game  3780 |  4062sec | RL-3X:  4% wins, 20% draws, 76% losts | MINI-MAX-5: 76% wins, 20% draws,  4% losts
# Game  3790 |  4074sec | RL-3X:  6% wins, 19% draws, 75% losts | MINI-MAX-5: 75% wins, 19% draws,  6% losts
# Game  3800 |  4086sec | RL-3X:  6% wins, 19% draws, 75% losts | MINI-MAX-5: 75% wins, 19% draws,  6% losts
# Game  3810 |  4097sec | RL-3X:  6% wins, 21% draws, 73% losts | MINI-MAX-5: 73% wins, 21% draws,  6% losts
# Game  3820 |  4109sec | RL-3X:  6% wins, 19% draws, 75% losts | MINI-MAX-5: 75% wins, 19% draws,  6% losts
# Game  3830 |  4120sec | RL-3X:  5% wins, 16% draws, 79% losts | MINI-MAX-5: 79% wins, 16% draws,  5% losts
# Game  3840 |  4131sec | RL-3X:  5% wins, 14% draws, 81% losts | MINI-MAX-5: 81% wins, 14% draws,  5% losts
# Game  3850 |  4143sec | RL-3X:  5% wins, 14% draws, 81% losts | MINI-MAX-5: 81% wins, 14% draws,  5% losts
# Game  3860 |  4155sec | RL-3X:  5% wins, 11% draws, 84% losts | MINI-MAX-5: 84% wins, 11% draws,  5% losts
# Game  3870 |  4166sec | RL-3X:  4% wins, 12% draws, 84% losts | MINI-MAX-5: 84% wins, 12% draws,  4% losts
# Game  3880 |  4178sec | RL-3X:  3% wins, 14% draws, 83% losts | MINI-MAX-5: 83% wins, 14% draws,  3% losts
# Game  3890 |  4190sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  3900 |  4201sec | RL-3X:  2% wins, 12% draws, 86% losts | MINI-MAX-5: 86% wins, 12% draws,  2% losts
# Game  3910 |  4211sec | RL-3X:  2% wins, 10% draws, 88% losts | MINI-MAX-5: 88% wins, 10% draws,  2% losts
# Game  3920 |  4222sec | RL-3X:  2% wins, 10% draws, 88% losts | MINI-MAX-5: 88% wins, 10% draws,  2% losts
# Game  3930 |  4233sec | RL-3X:  3% wins, 11% draws, 86% losts | MINI-MAX-5: 86% wins, 11% draws,  3% losts
# Game  3940 |  4245sec | RL-3X:  3% wins, 10% draws, 87% losts | MINI-MAX-5: 87% wins, 10% draws,  3% losts
# Game  3950 |  4256sec | RL-3X:  4% wins, 10% draws, 86% losts | MINI-MAX-5: 86% wins, 10% draws,  4% losts
# Game  3960 |  4269sec | RL-3X:  6% wins, 10% draws, 84% losts | MINI-MAX-5: 84% wins, 10% draws,  6% losts
# Game  3970 |  4282sec | RL-3X:  7% wins, 12% draws, 81% losts | MINI-MAX-5: 81% wins, 12% draws,  7% losts
# Game  3980 |  4293sec | RL-3X:  7% wins, 11% draws, 82% losts | MINI-MAX-5: 82% wins, 11% draws,  7% losts
# Game  3990 |  4305sec | RL-3X:  6% wins, 15% draws, 79% losts | MINI-MAX-5: 79% wins, 15% draws,  6% losts
# Game  4000 |  4317sec | RL-3X:  6% wins, 16% draws, 78% losts | MINI-MAX-5: 78% wins, 16% draws,  6% losts
# Game  4010 |  4329sec | RL-3X:  7% wins, 18% draws, 75% losts | MINI-MAX-5: 75% wins, 18% draws,  7% losts
# Game  4020 |  4340sec | RL-3X:  7% wins, 17% draws, 76% losts | MINI-MAX-5: 76% wins, 17% draws,  7% losts
# Game  4030 |  4352sec | RL-3X:  7% wins, 17% draws, 76% losts | MINI-MAX-5: 76% wins, 17% draws,  7% losts
# Game  4040 |  4364sec | RL-3X:  7% wins, 19% draws, 74% losts | MINI-MAX-5: 74% wins, 19% draws,  7% losts
# Game  4050 |  4375sec | RL-3X:  6% wins, 19% draws, 75% losts | MINI-MAX-5: 75% wins, 19% draws,  6% losts
# Game  4060 |  4386sec | RL-3X:  4% wins, 18% draws, 78% losts | MINI-MAX-5: 78% wins, 18% draws,  4% losts
# Game  4070 |  4397sec | RL-3X:  3% wins, 16% draws, 81% losts | MINI-MAX-5: 81% wins, 16% draws,  3% losts
# Game  4080 |  4408sec | RL-3X:  3% wins, 15% draws, 82% losts | MINI-MAX-5: 82% wins, 15% draws,  3% losts
# Game  4090 |  4420sec | RL-3X:  4% wins, 12% draws, 84% losts | MINI-MAX-5: 84% wins, 12% draws,  4% losts
# Game  4100 |  4431sec | RL-3X:  4% wins, 10% draws, 86% losts | MINI-MAX-5: 86% wins, 10% draws,  4% losts
# Game  4110 |  4442sec | RL-3X:  3% wins, 10% draws, 87% losts | MINI-MAX-5: 87% wins, 10% draws,  3% losts
# Game  4120 |  4453sec | RL-3X:  3% wins, 12% draws, 85% losts | MINI-MAX-5: 85% wins, 12% draws,  3% losts
# Game  4130 |  4465sec | RL-3X:  2% wins, 13% draws, 85% losts | MINI-MAX-5: 85% wins, 13% draws,  2% losts
# Game  4140 |  4478sec | RL-3X:  1% wins, 15% draws, 84% losts | MINI-MAX-5: 84% wins, 15% draws,  1% losts
# Game  4150 |  4489sec | RL-3X:  1% wins, 14% draws, 85% losts | MINI-MAX-5: 85% wins, 14% draws,  1% losts
# Game  4160 |  4501sec | RL-3X:  1% wins, 15% draws, 84% losts | MINI-MAX-5: 84% wins, 15% draws,  1% losts
# Game  4170 |  4513sec | RL-3X:  2% wins, 16% draws, 82% losts | MINI-MAX-5: 82% wins, 16% draws,  2% losts
# Game  4180 |  4525sec | RL-3X:  2% wins, 18% draws, 80% losts | MINI-MAX-5: 80% wins, 18% draws,  2% losts
# Game  4190 |  4536sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  4200 |  4548sec | RL-3X:  1% wins, 20% draws, 79% losts | MINI-MAX-5: 79% wins, 20% draws,  1% losts
# Game  4210 |  4560sec | RL-3X:  1% wins, 21% draws, 78% losts | MINI-MAX-5: 78% wins, 21% draws,  1% losts
# Game  4220 |  4572sec | RL-3X:  2% wins, 20% draws, 78% losts | MINI-MAX-5: 78% wins, 20% draws,  2% losts
# Game  4230 |  4583sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game  4240 |  4596sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game  4250 |  4607sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game  4260 |  4618sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game  4270 |  4630sec | RL-3X:  1% wins, 22% draws, 77% losts | MINI-MAX-5: 77% wins, 22% draws,  1% losts
# Game  4280 |  4642sec | RL-3X:  1% wins, 23% draws, 76% losts | MINI-MAX-5: 76% wins, 23% draws,  1% losts
# Game  4290 |  4653sec | RL-3X:  1% wins, 23% draws, 76% losts | MINI-MAX-5: 76% wins, 23% draws,  1% losts
# Game  4300 |  4664sec | RL-3X:  1% wins, 23% draws, 76% losts | MINI-MAX-5: 76% wins, 23% draws,  1% losts
# Game  4310 |  4675sec | RL-3X:  1% wins, 21% draws, 78% losts | MINI-MAX-5: 78% wins, 21% draws,  1% losts
# Game  4320 |  4687sec | RL-3X:  0% wins, 21% draws, 79% losts | MINI-MAX-5: 79% wins, 21% draws,  0% losts
# Game  4330 |  4698sec | RL-3X:  0% wins, 21% draws, 79% losts | MINI-MAX-5: 79% wins, 21% draws,  0% losts
# Game  4340 |  4711sec | RL-3X:  1% wins, 18% draws, 81% losts | MINI-MAX-5: 81% wins, 18% draws,  1% losts
# Game  4350 |  4721sec | RL-3X:  1% wins, 20% draws, 79% losts | MINI-MAX-5: 79% wins, 20% draws,  1% losts
# Game  4360 |  4729sec | RL-3X:  1% wins, 23% draws, 76% losts | MINI-MAX-5: 76% wins, 23% draws,  1% losts
# Game  4370 |  4733sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game  4380 |  4738sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game  4390 |  4743sec | RL-3X:  3% wins, 25% draws, 72% losts | MINI-MAX-5: 72% wins, 25% draws,  3% losts
# Game  4400 | 16064sec | RL-3X:  4% wins, 26% draws, 70% losts | MINI-MAX-5: 70% wins, 26% draws,  4% losts
# Game  4410 | 16079sec | RL-3X:  4% wins, 32% draws, 64% losts | MINI-MAX-5: 64% wins, 32% draws,  4% losts
# Game  4420 | 16090sec | RL-3X:  4% wins, 34% draws, 62% losts | MINI-MAX-5: 62% wins, 34% draws,  4% losts
# Game  4430 | 16101sec | RL-3X:  5% wins, 31% draws, 64% losts | MINI-MAX-5: 64% wins, 31% draws,  5% losts
# Game  4440 | 16114sec | RL-3X:  5% wins, 30% draws, 65% losts | MINI-MAX-5: 65% wins, 30% draws,  5% losts
# Game  4450 | 16126sec | RL-3X:  5% wins, 29% draws, 66% losts | MINI-MAX-5: 66% wins, 29% draws,  5% losts
# Game  4460 | 16138sec | RL-3X:  6% wins, 27% draws, 67% losts | MINI-MAX-5: 67% wins, 27% draws,  6% losts
# Game  4470 | 16151sec | RL-3X:  5% wins, 29% draws, 66% losts | MINI-MAX-5: 66% wins, 29% draws,  5% losts
# Game  4480 | 16162sec | RL-3X:  6% wins, 25% draws, 69% losts | MINI-MAX-5: 69% wins, 25% draws,  6% losts
# Game  4490 | 16174sec | RL-3X:  6% wins, 23% draws, 71% losts | MINI-MAX-5: 71% wins, 23% draws,  6% losts
# Game  4500 | 16186sec | RL-3X:  7% wins, 21% draws, 72% losts | MINI-MAX-5: 72% wins, 21% draws,  7% losts
# Game  4510 | 16198sec | RL-3X:  8% wins, 15% draws, 77% losts | MINI-MAX-5: 77% wins, 15% draws,  8% losts
# Game  4520 | 16211sec | RL-3X:  8% wins, 17% draws, 75% losts | MINI-MAX-5: 75% wins, 17% draws,  8% losts
# Game  4530 | 16223sec | RL-3X:  7% wins, 20% draws, 73% losts | MINI-MAX-5: 73% wins, 20% draws,  7% losts
# Game  4540 | 16234sec | RL-3X:  6% wins, 20% draws, 74% losts | MINI-MAX-5: 74% wins, 20% draws,  6% losts
# Game  4550 | 16239sec | RL-3X:  7% wins, 20% draws, 73% losts | MINI-MAX-5: 73% wins, 20% draws,  7% losts
# Game  4560 | 16245sec | RL-3X:  6% wins, 21% draws, 73% losts | MINI-MAX-5: 73% wins, 21% draws,  6% losts
# Game  4570 | 16249sec | RL-3X:  7% wins, 20% draws, 73% losts | MINI-MAX-5: 73% wins, 20% draws,  7% losts
# Game  4580 | 16254sec | RL-3X:  5% wins, 21% draws, 74% losts | MINI-MAX-5: 74% wins, 21% draws,  5% losts
# Game  4590 | 16262sec | RL-3X:  5% wins, 24% draws, 71% losts | MINI-MAX-5: 71% wins, 24% draws,  5% losts
# Game  4600 | 16267sec | RL-3X:  4% wins, 24% draws, 72% losts | MINI-MAX-5: 72% wins, 24% draws,  4% losts
# Game  4610 | 16271sec | RL-3X:  4% wins, 25% draws, 71% losts | MINI-MAX-5: 71% wins, 25% draws,  4% losts
# Game  4620 | 16275sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  4630 | 16280sec | RL-3X:  5% wins, 21% draws, 74% losts | MINI-MAX-5: 74% wins, 21% draws,  5% losts
# Game  4640 | 16284sec | RL-3X:  5% wins, 21% draws, 74% losts | MINI-MAX-5: 74% wins, 21% draws,  5% losts
# Game  4650 | 16289sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  4660 | 16293sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  4670 | 16297sec | RL-3X:  3% wins, 21% draws, 76% losts | MINI-MAX-5: 76% wins, 21% draws,  3% losts
# Game  4680 | 16301sec | RL-3X:  3% wins, 24% draws, 73% losts | MINI-MAX-5: 73% wins, 24% draws,  3% losts
# Game  4690 | 16305sec | RL-3X:  3% wins, 21% draws, 76% losts | MINI-MAX-5: 76% wins, 21% draws,  3% losts
# Game  4700 | 16309sec | RL-3X:  2% wins, 24% draws, 74% losts | MINI-MAX-5: 74% wins, 24% draws,  2% losts
# Game  4710 | 16313sec | RL-3X:  3% wins, 24% draws, 73% losts | MINI-MAX-5: 73% wins, 24% draws,  3% losts
# Game  4720 | 16317sec | RL-3X:  3% wins, 23% draws, 74% losts | MINI-MAX-5: 74% wins, 23% draws,  3% losts
# Game  4730 | 16320sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game  4740 | 16324sec | RL-3X:  2% wins, 23% draws, 75% losts | MINI-MAX-5: 75% wins, 23% draws,  2% losts
# Game  4750 | 16328sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  4760 | 16332sec | RL-3X:  4% wins, 20% draws, 76% losts | MINI-MAX-5: 76% wins, 20% draws,  4% losts
# Game  4770 | 16336sec | RL-3X:  4% wins, 20% draws, 76% losts | MINI-MAX-5: 76% wins, 20% draws,  4% losts
# Game  4780 | 16340sec | RL-3X:  4% wins, 16% draws, 80% losts | MINI-MAX-5: 80% wins, 16% draws,  4% losts
# Game  4790 | 16343sec | RL-3X:  5% wins, 15% draws, 80% losts | MINI-MAX-5: 80% wins, 15% draws,  5% losts
# Game  4800 | 16347sec | RL-3X:  6% wins, 13% draws, 81% losts | MINI-MAX-5: 81% wins, 13% draws,  6% losts
# Game  4810 | 16351sec | RL-3X:  4% wins, 13% draws, 83% losts | MINI-MAX-5: 83% wins, 13% draws,  4% losts
# Game  4820 | 16356sec | RL-3X:  4% wins, 19% draws, 77% losts | MINI-MAX-5: 77% wins, 19% draws,  4% losts
# Game  4830 | 16360sec | RL-3X:  4% wins, 20% draws, 76% losts | MINI-MAX-5: 76% wins, 20% draws,  4% losts
# Game  4840 | 16365sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  4850 | 16369sec | RL-3X:  2% wins, 23% draws, 75% losts | MINI-MAX-5: 75% wins, 23% draws,  2% losts
# Game  4860 | 16373sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game  4870 | 16377sec | RL-3X:  3% wins, 23% draws, 74% losts | MINI-MAX-5: 74% wins, 23% draws,  3% losts
# Game  4880 | 16381sec | RL-3X:  3% wins, 26% draws, 71% losts | MINI-MAX-5: 71% wins, 26% draws,  3% losts
# Game  4890 | 16385sec | RL-3X:  2% wins, 28% draws, 70% losts | MINI-MAX-5: 70% wins, 28% draws,  2% losts
# Game  4900 | 16389sec | RL-3X:  2% wins, 27% draws, 71% losts | MINI-MAX-5: 71% wins, 27% draws,  2% losts
# Game  4910 | 16393sec | RL-3X:  2% wins, 26% draws, 72% losts | MINI-MAX-5: 72% wins, 26% draws,  2% losts
# Game  4920 | 16397sec | RL-3X:  2% wins, 23% draws, 75% losts | MINI-MAX-5: 75% wins, 23% draws,  2% losts
# Game  4930 | 16401sec | RL-3X:  2% wins, 23% draws, 75% losts | MINI-MAX-5: 75% wins, 23% draws,  2% losts
# Game  4940 | 16406sec | RL-3X:  3% wins, 23% draws, 74% losts | MINI-MAX-5: 74% wins, 23% draws,  3% losts
# Game  4950 | 16410sec | RL-3X:  4% wins, 22% draws, 74% losts | MINI-MAX-5: 74% wins, 22% draws,  4% losts
# Game  4960 | 16414sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game  4970 | 16420sec | RL-3X:  3% wins, 22% draws, 75% losts | MINI-MAX-5: 75% wins, 22% draws,  3% losts
# Game  4980 | 16431sec | RL-3X:  5% wins, 20% draws, 75% losts | MINI-MAX-5: 75% wins, 20% draws,  5% losts
# Game  4990 | 16442sec | RL-3X:  5% wins, 20% draws, 75% losts | MINI-MAX-5: 75% wins, 20% draws,  5% losts
# Game  5000 | 16452sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  5010 | 16462sec | RL-3X:  4% wins, 20% draws, 76% losts | MINI-MAX-5: 76% wins, 20% draws,  4% losts
# Game  5020 | 16474sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  5030 | 16485sec | RL-3X:  4% wins, 21% draws, 75% losts | MINI-MAX-5: 75% wins, 21% draws,  4% losts
# Game  5040 | 16496sec | RL-3X:  3% wins, 20% draws, 77% losts | MINI-MAX-5: 77% wins, 20% draws,  3% losts
# Game  5050 | 16508sec | RL-3X:  2% wins, 23% draws, 75% losts | MINI-MAX-5: 75% wins, 23% draws,  2% losts
# Game  5060 | 16518sec | RL-3X:  2% wins, 23% draws, 75% losts | MINI-MAX-5: 75% wins, 23% draws,  2% losts
# Game  5070 | 16528sec | RL-3X:  2% wins, 21% draws, 77% losts | MINI-MAX-5: 77% wins, 21% draws,  2% losts
# Game  5080 | 16539sec | RL-3X:  0% wins, 22% draws, 78% losts | MINI-MAX-5: 78% wins, 22% draws,  0% losts
# Game  5090 | 16551sec | RL-3X:  0% wins, 22% draws, 78% losts | MINI-MAX-5: 78% wins, 22% draws,  0% losts
# Game  5100 | 16563sec | RL-3X:  0% wins, 25% draws, 75% losts | MINI-MAX-5: 75% wins, 25% draws,  0% losts
# Game  5110 | 16573sec | RL-3X:  0% wins, 25% draws, 75% losts | MINI-MAX-5: 75% wins, 25% draws,  0% losts
# Game  5120 | 16585sec | RL-3X:  0% wins, 24% draws, 76% losts | MINI-MAX-5: 76% wins, 24% draws,  0% losts
# Game  5130 | 16597sec | RL-3X:  0% wins, 24% draws, 76% losts | MINI-MAX-5: 76% wins, 24% draws,  0% losts
# Game  5140 | 16607sec | RL-3X:  1% wins, 22% draws, 77% losts | MINI-MAX-5: 77% wins, 22% draws,  1% losts
# Game  5150 | 16611sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  5160 | 16616sec | RL-3X:  1% wins, 21% draws, 78% losts | MINI-MAX-5: 78% wins, 21% draws,  1% losts
# Game  5170 | 16621sec | RL-3X:  1% wins, 21% draws, 78% losts | MINI-MAX-5: 78% wins, 21% draws,  1% losts
# Game  5180 | 16625sec | RL-3X:  1% wins, 21% draws, 78% losts | MINI-MAX-5: 78% wins, 21% draws,  1% losts
# Game  5190 | 16629sec | RL-3X:  1% wins, 19% draws, 80% losts | MINI-MAX-5: 80% wins, 19% draws,  1% losts
# Game  5200 | 16633sec | RL-3X:  2% wins, 19% draws, 79% losts | MINI-MAX-5: 79% wins, 19% draws,  2% losts
# Game  5210 | 16638sec | RL-3X:  2% wins, 24% draws, 74% losts | MINI-MAX-5: 74% wins, 24% draws,  2% losts
# Game  5220 | 16643sec | RL-3X:  4% wins, 24% draws, 72% losts | MINI-MAX-5: 72% wins, 24% draws,  4% losts
# Game  5230 | 16648sec | RL-3X:  4% wins, 26% draws, 70% losts | MINI-MAX-5: 70% wins, 26% draws,  4% losts
# Game  5240 | 16652sec | RL-3X:  4% wins, 26% draws, 70% losts | MINI-MAX-5: 70% wins, 26% draws,  4% losts
# Game  5250 | 16657sec | RL-3X:  5% wins, 27% draws, 68% losts | MINI-MAX-5: 68% wins, 27% draws,  5% losts
# Game  5260 | 16662sec | RL-3X:  5% wins, 27% draws, 68% losts | MINI-MAX-5: 68% wins, 27% draws,  5% losts
# Game  5270 | 16665sec | RL-3X:  5% wins, 28% draws, 67% losts | MINI-MAX-5: 67% wins, 28% draws,  5% losts
# Game  5280 | 16669sec | RL-3X:  5% wins, 26% draws, 69% losts | MINI-MAX-5: 69% wins, 26% draws,  5% losts
# Game  5290 | 16672sec | RL-3X:  5% wins, 27% draws, 68% losts | MINI-MAX-5: 68% wins, 27% draws,  5% losts
# Game  5300 | 16677sec | RL-3X:  4% wins, 24% draws, 72% losts | MINI-MAX-5: 72% wins, 24% draws,  4% losts
# Game  5310 | 16685sec | RL-3X:  4% wins, 22% draws, 74% losts | MINI-MAX-5: 74% wins, 22% draws,  4% losts
# Game  5320 | 16697sec | RL-3X:  2% wins, 24% draws, 74% losts | MINI-MAX-5: 74% wins, 24% draws,  2% losts
# Game  5330 | 16702sec | RL-3X:  2% wins, 22% draws, 76% losts | MINI-MAX-5: 76% wins, 22% draws,  2% losts
# Game  5340 | 16707sec | RL-3X:  1% wins, 24% draws, 75% losts | MINI-MAX-5: 75% wins, 24% draws,  1% losts
# Game  5350 | 16712sec | RL-3X:  0% wins, 27% draws, 73% losts | MINI-MAX-5: 73% wins, 27% draws,  0% losts
# Game  5360 | 16716sec | RL-3X:  0% wins, 27% draws, 73% losts | MINI-MAX-5: 73% wins, 27% draws,  0% losts
# Game  5370 | 16720sec | RL-3X:  0% wins, 29% draws, 71% losts | MINI-MAX-5: 71% wins, 29% draws,  0% losts
# Game  5380 | 16724sec | RL-3X:  0% wins, 31% draws, 69% losts | MINI-MAX-5: 69% wins, 31% draws,  0% losts
# Game  5390 | 16728sec | RL-3X:  0% wins, 31% draws, 69% losts | MINI-MAX-5: 69% wins, 31% draws,  0% losts
# Game  5400 | 16733sec | RL-3X:  0% wins, 30% draws, 70% losts | MINI-MAX-5: 70% wins, 30% draws,  0% losts
# Game  5410 | 16737sec | RL-3X:  0% wins, 30% draws, 70% losts | MINI-MAX-5: 70% wins, 30% draws,  0% losts
# Game  5420 | 16741sec | RL-3X:  2% wins, 30% draws, 68% losts | MINI-MAX-5: 68% wins, 30% draws,  2% losts
# Game  5430 | 16745sec | RL-3X:  2% wins, 30% draws, 68% losts | MINI-MAX-5: 68% wins, 30% draws,  2% losts
# Game  5440 | 16749sec | RL-3X:  2% wins, 29% draws, 69% losts | MINI-MAX-5: 69% wins, 29% draws,  2% losts
# Game  5450 | 16753sec | RL-3X:  2% wins, 27% draws, 71% losts | MINI-MAX-5: 71% wins, 27% draws,  2% losts
# Game  5460 | 16757sec | RL-3X:  2% wins, 28% draws, 70% losts | MINI-MAX-5: 70% wins, 28% draws,  2% losts
# Game  5470 | 16761sec | RL-3X:  2% wins, 28% draws, 70% losts | MINI-MAX-5: 70% wins, 28% draws,  2% losts
# Game  5480 | 16766sec | RL-3X:  2% wins, 32% draws, 66% losts | MINI-MAX-5: 66% wins, 32% draws,  2% losts
# Game  5490 | 16773sec | RL-3X:  2% wins, 34% draws, 64% losts | MINI-MAX-5: 64% wins, 34% draws,  2% losts
# Game  5500 | 16779sec | RL-3X:  2% wins, 35% draws, 63% losts | MINI-MAX-5: 63% wins, 35% draws,  2% losts
# Game  5510 | 16783sec | RL-3X:  2% wins, 34% draws, 64% losts | MINI-MAX-5: 64% wins, 34% draws,  2% losts
# Game  5520 | 16787sec | RL-3X:  0% wins, 30% draws, 70% losts | MINI-MAX-5: 70% wins, 30% draws,  0% losts
# Game  5530 | 16791sec | RL-3X:  0% wins, 30% draws, 70% losts | MINI-MAX-5: 70% wins, 30% draws,  0% losts

# %% [markdown]
# **Game loop**
